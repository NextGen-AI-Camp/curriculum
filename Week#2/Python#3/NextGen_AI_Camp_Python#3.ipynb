# %% [markdown]
# <a href="https://colab.research.google.com/github/NextGen-AI-Camp/curriculum/blob/main/Week%232/Python%233/NextGen_AI_Camp_Python%233.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Python Programming ตอนที่ 3

# %% [markdown]
# ## List
#
# - List เป็นโครงสร้างข้อมูลของ Python ที่สามารถเก็บข้อมูลได้หลายข้อมูล โดยเป็นข้อมูลชนิดเดียวกัน หรือ ข้อมูลต่างชนิดกันก็ได้
# - List จะใช้เครื่องหมาย [ ] ในการกำหนดขอบเขตของ List
# - อาจเรียก List ว่าชุดข้อมูลก็ได้
# - เราสามารถสร้าง List จากข้อมูลชนิดอื่นได้ โดยใช้คำสั่ง list

# %%
list0 = []
list2 = [1, 2, 3, 4, 5 ]
list3 = ["a", "b", "c", "d"]
list4 = [1, 2, 3, 4, 'Foo', 5, 'Bar']
weekDays = ["Monday","Tuesday","Wednesday","Thursday","Friday","Saturday","Sunday"]
list5 = list('abcde') # => ['a', 'b', 'c', 'd', 'e']
list5
# Out:
# ['a', 'b', 'c', 'd', 'e']

# %% [markdown]
# ### การเข้าถึงข้อมูลใน List
#
# List ทั้งชุดจะชี้โดยตัวแปรเดียวกัน โดยหมายถึงข้อมูลทั้งชุด
#
# สำหรับการอ้างถึงข้อมูลแต่ละตัว สามารถทำได้โดยการอ้าง Index โดยข้อมูลตัวแรก จะอยู่ที่ Index 0 เช่น
#
#
# ```
# lst = ['a','b','c']
# ```
#
# <img src="https://web.stanford.edu/class/archive/cs/cs106a/cs106a.1202/handouts/python-listabc.png" width="400">

# %%
lst = ['a','b','c']
print(lst[0])
print(lst[1])
print(lst[2])

list4 = [1, 2, 3, 4, 'Foo', 5, 'Bar']
list4[4]
# Out:
# a
# b
# c
# 'Foo'

# %% [markdown]
# Index สามารถใช้เป็นลบได้ด้วย โดย -1 จะหมายถึง สมาชิกตัวสุดท้ายของ List และ -2 หมายถึงสมาชิกตัวรองสุดท้ายของ List พูดง่ายๆ คือ การนับจากหลังมาข้างหน้า แต่สิ่งที่แตกต่างกัน คือ หากนับจากข้างหน้ามาข้างหลังจะเริ่มจาก 0 แต่หากนับจากข้างหลังมาข้างหน้าจะเริ่มจาก -1
#
# <br>
# <img src="https://media.geeksforgeeks.org/wp-content/uploads/List-Slicing.jpg" width="500">

# %%
list1 = ['physics', 'chemistry', 'calculus', 'biology'];
list2 = [1, 2, 3, 4, 5, 6, 7];
print("list1[0]:", list1[0])
print("list1[-1]:", list1[-1])
print("list2[3]:", list2[3])
print("list2[-4]:", list2[-4])
# Out:
# list1[0]: physics
# list1[-1]: biology
# list2[3]: 4
# list2[-4]: 4

# %% [markdown]
# ### Slicing
#
# Python มีความสามารถในการระบุสมาชิกเป็นช่วง เรียกว่า Slicing ซึ่งมีการใช้งานมากใน Machine Learning โดยเฉพาะ Computer Vision หรือ Image Processing ดังนั้นหากจะเอาดีทางนี้ ควรฝึกฝนการทำ Slicing
#
# ในการ Slicing จะมีตัวเลข 3 ตัว คือ start, stop, step
# - start คือ ตำแหน่งเริ่มต้น จะใช้แบบเลขบวก หรือ เลขลบก็ได้
# - stop คือ ไม่เกินตำแหน่งนี้ ดังนั้นตำแหน่งสุดท้ายจริงคือ stop -1
# - step คือ การกระโดด

# %%
list2 = [1, 2, 3, 4, 5, 6, 7];
print("list2[1:5]:", list2[1:5])
print("list2[::2]:", list2[::2])
print("list2[2::2]:", list2[2::2])
print("list2[2:7:2]:", list2[2:7:2])
print("list2[:7]:", list2[:7])        # from begin
print("list2[4:]:", list2[4:])        # to end
# Out:
# list2[1:5]: [2, 3, 4, 5]
# list2[::2]: [1, 3, 5, 7]
# list2[2::2]: [3, 5, 7]
# list2[2:7:2]: [3, 5, 7]
# list2[:7]: [1, 2, 3, 4, 5, 6, 7]
# list2[4:]: [5, 6, 7]

# %%
lst = [40, 50, 20, 30, 90, 80, 70]
print(lst[1:3])
print(lst[2:6])
print(lst[0:8:3])
print(lst[-2])
print(lst[:-2:2])
print(lst[::4])
print(lst[2:-2])
print(lst[::-1])
print(lst[::-2])
print(lst[:-2:-2])
# Out:
# [50, 20]
# [20, 30, 90, 80]
# [40, 30, 70]
# 80
# [40, 20, 90]
# [40, 90]
# [20, 30, 90]
# [70, 80, 90, 30, 20, 50, 40]
# [70, 90, 20, 40]
# [70]

# %% [markdown]
# ### การเพิ่มข้อมูลใน List
#
# สามารถทำได้หลายวิธี
#
# - ใช้เครื่องหมาย + โดยข้อมูลที่จะนำมา + ต้องเป็น list

# %%
flowers = ['Rose', 'Lily', 'Tulip', 'Carnation', 'Poppy', 'Sunflower']
flowers += ['Magnolia']
print(flowers)
# Out:
# ['Rose', 'Lily', 'Tulip', 'Carnation', 'Poppy', 'Sunflower', 'Magnolia']

# %% [markdown]
# - ใช้ฟังก์ชัน append หรือ extend

# %%
flowers = ['Rose', 'Lily', 'Tulip', 'Carnation', 'Poppy', 'Sunflower']
flowers.append(['Iris'])
print(flowers)
flowers.extend(['Violet','Forget me not'])
print(flowers)
flowers.append('Jasmine')
print(flowers)
flowers.extend('Lavender')
print(flowers)
flowers.append('Jasmine')
print(flowers)
# Out:
# ['Rose', 'Lily', 'Tulip', 'Carnation', 'Poppy', 'Sunflower', ['Iris']]
# ['Rose', 'Lily', 'Tulip', 'Carnation', 'Poppy', 'Sunflower', ['Iris'], 'Violet', 'Forget me not']
# ['Rose', 'Lily', 'Tulip', 'Carnation', 'Poppy', 'Sunflower', ['Iris'], 'Violet', 'Forget me not', 'Jasmine']
# ['Rose', 'Lily', 'Tulip', 'Carnation', 'Poppy', 'Sunflower', ['Iris'], 'Violet', 'Forget me not', 'Jasmine', 'L', 'a', 'v', 'e', 'n', 'd', 'e', 'r']
# ['Rose', 'Lily', 'Tulip', 'Carnation', 'Poppy', 'Sunflower', ['Iris'], 'Violet', 'Forget me not', 'Jasmine', 'L', 'a', 'v', 'e', 'n', 'd', 'e', 'r', 'Jasmine']

# %%
flowers = ['Rose', 'Lily', 'Tulip', 'Carnation', 'Poppy', 'Sunflower']
flowers += 'Rosemary'
print(flowers)
# Out:
# ['Rose', 'Lily', 'Tulip', 'Carnation', 'Poppy', 'Sunflower', 'R', 'o', 's', 'e', 'm', 'a', 'r', 'y']

# %% [markdown]
# ### การแก้ไขข้อมูลใน List
#
# การแก้ไขข้อมูลใน List จะเป็นการกำหนดค่าใหม่ให้กับแต่ละตำแหน่งที่อยู่ใน List โดยตรง

# %%
list1 = ['physics', 'chemistry', 'calculus', 'biology'];
print("Old value available at index 2 : ", list1[2])
list1[2] = 'programming';
print("New value available at index 2 : ", list1[2])
print(list1)
# Out:
# Old value available at index 2 :  calculus
# New value available at index 2 :  programming
# ['physics', 'chemistry', 'programming', 'biology']

# %% [markdown]
# สามารถกำหนดค่าโดยใช้ slicing ได้ด้วย

# %%
odd = [2,4,6,8]
odd[1:4] = [3,5,6,7,8]
odd
# Out:
# [2, 3, 5, 6, 7, 8]

# %% [markdown]
# ### การแทรกข้อมูล
#
# การแทรกข้อมูลใน List จะใช้คำสั่ง insert โดยระบุตำแหน่งที่ insert
#
# insert(position, value)

# %%
motorcycles = []
motorcycles.append('honda')
motorcycles.append('yamaha')
motorcycles.append('suzuki')
print(motorcycles)
motorcycles.insert(0, 'ducati')
print(motorcycles)
# Out:
# ['honda', 'yamaha', 'suzuki']
# ['ducati', 'honda', 'yamaha', 'suzuki']

# %% [markdown]
# ### การลบข้อมูลใน List
#
# การลบข้อมูลใน List สามารถทำได้หลายวิธี
# - ใช้คำสั่ง clear เป็นการลบ list ทั้งหมด
# - ใช้คำสั่ง remove เป็นการลบโดยอ้างถึงข้อมูลที่ต้องการลบ
# - ใช้คำสั่ง del เป็นการลบโดยอ้างถึงตำแหน่งที่ต้องการลบ
# - ใช้คำสั่ง pop หากไม่ระบุตำแหน่ง จะเป็นการลบข้อมูลท้ายสุด แต่ถ้าระบุตำแหน่งจะเป็นการลบในตำแหน่งที่ระบุ

# %%
motorcycles = ['honda', 'yamaha', 'suzuki', 'ducati']

print(motorcycles)
del motorcycles[2]
print(motorcycles)
motorcycles.pop()
print(motorcycles)
# Out:
# ['honda', 'yamaha', 'suzuki', 'ducati']
# ['honda', 'yamaha', 'ducati']
# ['honda', 'yamaha']

# %%
motorcycles = ['honda', 'yamaha', 'suzuki', 'ducati']

print(motorcycles)
del motorcycles[2]
print(motorcycles)
motorcycles.pop(0)
print(motorcycles)
motorcycles.remove('ducati')
print(motorcycles)
motorcycles.clear()
print(motorcycles)
# Out:
# ['honda', 'yamaha', 'suzuki', 'ducati']
# ['honda', 'yamaha', 'ducati']
# ['yamaha', 'ducati']
# ['yamaha']
# []

# %% [markdown]
# ### การตรวจสอบการเป็นสมาชิก (Membership)
#
# - เราสามารถตรวจสอบว่า มีข้อมูล หรือ ไม่มีข้อมูลใน list หรือไม่ โดยใช้ in

# %%
motorcycles = ['honda', 'yamaha', 'suzuki', 'ducati']
print('ducati' in motorcycles)
print('toyata' not in motorcycles)
# Out:
# True
# True

# %% [markdown]
# ### การเปรียบเทียบ List
#
# - list สามารถ เปรียบเทียบได้ด้วย โดยการเปรียบเทียบจะเปรียบเทียบเรียงตามลำดับ
#  ดังนั้น [1,2] จะไม่เท่ากับ [2,1]

# %%
lst1 = [9, 2, 3, 4, 5]
lst2 = [9, 1, 7, 6, 5]
lst3 = [9, 8, 7, 6, 5]
lst4 = [8, 7]
print("lst1 < lst2 :", lst1 < lst2)
print("lst1 > lst2 :", lst1 > lst2)
print("lst2 >= lst1 :", lst2 >= lst1)
print("lst2 == lst3 :", lst2 == lst3)
# Out:
# lst1 < lst2 : False
# lst1 > lst2 : True
# lst2 >= lst1 : False
# lst2 == lst3 : False

# %% [markdown]
# ### การสร้าง List ชนิดลำดับตัวเลข
#
# - กรณีที่ต้องการสร้างข้อมูลตัวเลขที่มีลำดับที่แน่นอน เราสามารถใช้คำสั่ง range(start, stop, step)
# - start = เริ่ม, stop = สิ้นสุด (ไม่รวม stop), step = กระโดดครั้งละ

# %%
even_numbers = list(range(2, 11, 2))
print(even_numbers)

numbers = list(range(1, 6))
print(numbers)
# Out:
# [2, 4, 6, 8, 10]
# [1, 2, 3, 4, 5]

# %% [markdown]
# ### ฟังก์ชันที่เกี่ยวกับ List อื่นๆ
# - x.sort() ทำให้ข้อมูลในลิสต์ x เรียงจากน้อยไปมาก คำสั่งนี้ไม่มี return คืนกลับมา
# - sorted(x) คืนลิสต์ที่มีค่าเหมือนกับใน x แต่เรียงลำดับข้อมูลจากน้อยไปมากให้
# (x ไม่เปลี่ยนแปลง)
# - sum(x) คืนผลรวม (summary) ของตัวเลขที่อยู่ในลิสต์ x
# - max(x) คืนค่ามากสุดในลิสต์ x, min(x) คืนค่าน้อยสุดในลิสต์ x
# - x.count(e) คืนจำนวนครั้งที่ e ปรากฏในลิสต์ x

# %% [markdown]
# ### Nested List
#
# List สามารถซ้อนใน List อื่นได้อีกที ยกตัวอย่างเช่น ใน List matrix จะประกอบด้วย List จำนวน 3 List โดยแต่ละ List จะมีสมาชิก 3 ตัว ซึ่งรูปแบบ matrix นี้จะมีการใช้งานมากใน machine learning
#
# การอ้างถึงสมาชิกใน matrix มีดังนี้
#
#
# ```
# matrix[1] คือ [4,5,6]
# matrix[1][2] คือ [6]
# ```
#
#
# <br>
# <img src="https://pythonmorsels.s3.amazonaws.com/medialibrary/2022/02/data-structures-diagram.png" width="500">

# %%
matrix = [[1,2,3],[4,5,6],[7,8,9]]
row = matrix[1]
print(row)
print(matrix[1][2])
# Out:
# [4, 5, 6]
# 6

# %% [markdown]
# ### การใช้ Slicing ใน String
#
# เราอาจมอง String คล้ายกับ List ได้ เช่น สามารถทำ Slicing ได้ แต่ไม่สามารถเปลี่ยนแปลงข้อมูลใน String ได้

# %%
str = "Computer"
print(str[0])
print(str[2:5])
print(str[2:-3])
print(str[::2])
print(str[::-1])
# Out:
# C
# mpu
# mpu
# Cmue
# retupmoC

# %% [markdown]
# ### ฟังก์ชันอื่นๆ ของ String
#
# String มี Function ให้ใช้มากมาย วิธีการใช้ Function ของ String จะใช้ .function หลังตัวแปร

# %%
name = "Ada Lovelace"
print(name.upper())
print(name.lower())
print(name.title())
print(name.split())

language = " Python "
print(language.strip())
print(language.lstrip(),":")
print(language.rstrip())
# Out:
# ADA LOVELACE
# ada lovelace
# Ada Lovelace
# ['Ada', 'Lovelace']
# Python
# Python  :
#  Python

# %% [markdown]
# ### ฟังก์ชันอื่นๆ
#
# - isupper	ตัวใหญ่หรือไม่
# - islower	ตัวเล็กหรือไม่
# - isnumeric	ตัวเลขหรือไม่
# - isalpha	ตัวอักษรหรือไม่
# - isalnum	Alphanumeric หรือไม่
# - count	นับจำนวนของอักษร
# - find	หาตำแหน่งตัวอักษรหรือชุด (หาตัวที่ n ได้ด้วย)
# - startswith	เริ่มต้นด้วย
# - endswith	ปิดท้ายด้วย
# - replace	เปลี่ยนข้อความ
