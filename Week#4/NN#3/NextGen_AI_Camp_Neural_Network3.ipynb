# %% [markdown]
# <a href="https://colab.research.google.com/github/NextGen-AI-Camp/curriculum/blob/main/Week%234/NN%233/NextGen_AI_Camp_Neural_Network3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Deep Learning with PyTorch

# %% [markdown]
# ## Appriximate Sine Function with PyTorch
#
# เราจะเริ่ม Neural Network ตอนที่ 3 ด้วยการนำเอาโจทย์เดิม คือ การประมาณค่า sine (Sine Approximation) มาเขียนใหม่ด้วย PyTorch เพื่อทบทวนกระบวนการสร้าง Model และเพื่อให้คุ้นเคยกับคำสั่งใน Library Pytorch
#
# จะเริ่มจาก ส่วนของ import library ตามโค้ดด้านล่าง จะเห็นว่าเราคงยังใช้ Numpy อยู่
# - คำสั่ง import torch เพื่อใช้คำสั่งในการประมวลผล matrix
# - คำสั่ง import torch.nn as nn เพื่อเรียกใช้ส่วนของ Neural Network
# - คำสั่ง import torch.optim as optim เพื่อเรียกใช้ส่วนของ optimization

# %%
import numpy as np
import torch
import torch.nn as nn
import torch.optim as optim
import matplotlib.pyplot as plt

# %% [markdown]
# จากนั้นก็เป็นฟังก์ชันในการสร้างข้อมูล sine เหมือนเดิม

# %%
def generate_points(start=0, end=10, step=0.1):
    x_values = np.arange(start, end + step, step)
    num_points = len(x_values)
    y_values = np.sin(x_values)
    noise = np.random.randn(num_points) * 0.1
    noisy_y_values = y_values + noise
    points = list(zip(x_values, noisy_y_values))
    return points

# %% [markdown]
# สร้างข้อมูลด้วย numpy และแปลงเป็น tensor ของ torch และ ตรวจสอบว่าหากมี GPU (cuda) ก็ให้นำข้อมูลขึ้นไปรันใน GPU

# %%
# Check for CUDA
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

# Generate the dataset
points = generate_points()

# Prepare the data
x = np.array([point[0] for point in points]).reshape(-1, 1)
y = np.array([point[1] for point in points]).reshape(-1, 1)

# Convert data to PyTorch tensors
x = torch.tensor(x, dtype=torch.float32).to(device)
y = torch.tensor(y, dtype=torch.float32).to(device)

# %% [markdown]
# กำหนดโครงสร้างของ Model ดังนี้
# - ชั้นที่ 1 เป็น Hidden Layer ชั้นที่ 1 ประกอบด้วย Input = 1 และ Output = 16 เพื่อนำไปเข้า Hidden Layer ในชั้นถัดไป
# - ชั้นที่ 2 เป็น Activation Function ของชั้นที่ 1 โดยเลือกใช้ TanH
# - ชั้นที่ 3 เป็น Hidden Layer ชั้นที่ 2 ประกอบด้วย Input = 16 และ Output = 20 เพื่อนำไปเข้า Output Layer
# - ชั้นที่ 4 เป็น Activation Function ของชั้นที่ 2 โดยเลือกใช้ TanH เช่นกัน
# - ชั้นที่ 5 เป็น Output Layer ประกอบด้วย Input 20 และ Output 1
#
# สังเกตว่ามิติ (Dimension) ของชั้นที่อยู่ติดกันจะต้องมิติที่เข้ากันได้

# %%
# Define model using nn.Sequential
model = nn.Sequential(
    nn.Linear(1, 16),
    nn.Tanh(),
    nn.Linear(16, 20),
    nn.Tanh(),
    nn.Linear(20, 1)
).to(device)

# %% [markdown]
# กำหนด loss function และอัลกอรึทึมในการทำ Gradient Descent ในที่นี้จะใช้ Mean Squere Error เป็น Loss Function และ Stochastic Gradient Descent ในการหาจุดต่ำสุด

# %%
# Define loss function and optimizer
criterion = nn.MSELoss()
optimizer = optim.SGD(model.parameters(), lr=0.001, momentum=0.9)

# %%
# Train the model
num_epochs = 20000
loss_history = []

model.train() # train mode      # It's the training time
for epoch in range(num_epochs): # for epoch in range

    outputs = model(x)          # do the forward pass
    loss = criterion(outputs, y)# calculate the loss
    optimizer.zero_grad()       # optimize a zero grad
    loss.backward()             # loss backward (do backward pass)
    optimizer.step()            # optimize step (adjust model parameter)

    loss_history.append(loss.item())


    if epoch % 1000 == 0:
        print(f"Loss after iteration {epoch}: {loss.item():.6f}")
# Out:
# Loss after iteration 0: 0.481761
# Loss after iteration 1000: 0.286924
# Loss after iteration 2000: 0.191843
# Loss after iteration 3000: 0.169187
# Loss after iteration 4000: 0.155562
# Loss after iteration 5000: 0.145224
# Loss after iteration 6000: 0.136997
# Loss after iteration 7000: 0.129822
# Loss after iteration 8000: 0.119504
# Loss after iteration 9000: 0.063260
# Loss after iteration 10000: 0.035693
# Loss after iteration 11000: 0.021045
# Loss after iteration 12000: 0.014608
# Loss after iteration 13000: 0.012027
# Loss after iteration 14000: 0.010968
# Loss after iteration 15000: 0.010478
# Loss after iteration 16000: 0.010209
# Loss after iteration 17000: 0.010037
# Loss after iteration 18000: 0.009913
# Loss after iteration 19000: 0.009818

# %% [markdown]
# ส่วนของการ Train จะทำทั้งหมด 20,000 รอบ
# - บรรทัด optimizer.zero_grad() คือการรีเซ็ทค่า gradient ให้เป็น 0 เพื่อจะได้เก็บค่า Loss ใหม่ตั้งแต่ 0 ของแต่ละ epoch
# - บรรทัด outputs = model(x) เป็นสั่งให้ทำงานใน forward pass
# - บรรทัด loss = criterion(outputs, y) เป็นการนำค่าผลลัพธ์จาก forward pass มาหา Loss
# - บรรทัด loss.backward() เป็นการสั่งให้ทำ backward pass ซึ่งจะได้ค่า gradient ของแต่ละ neuron
# - บรรทัด optimizer.step() คือ การสั่งให้ปรับ weight และ bias ของ training loop นี้
#
# จะเห็นได้ว่า ไม่ว่าจะเป็นการเขียนโปรแกรมเป็นภาษา Python หรือ การทำงานผ่าน Library Pytorch ขั้นตอนการทำงานยังคงเหมือนเดิม และเหมือนกับรูปนี้ เพียงแต่ Pytorch ทำให้โปรแกรมสั้นลงและสะดวกขึ้น แต่การเขียนโปรแกรมยังต้องมีความเข้าใจอย่างดี
#
# <div>
# <br>
# <img src="https://www.oreilly.com/api/v2/epubs/9781492045519/files/assets/dlcf_0108.png" width="600"/>
#
# </div>
# <br>

# %% [markdown]
# จากนั้นจะเป็นส่วนของการแสดงผล

# %%
def plot_output(points, model, loss, device):
    x_values, noisy_y_values = zip(*points)
    x_values = torch.tensor(x_values, dtype=torch.float32).reshape(-1, 1).to(device)
    noisy_y_values = np.array(noisy_y_values)
    y_values = np.sin(x_values.cpu().numpy()).flatten()

    model.eval()
    with torch.no_grad():
        predicted_y_values = model(x_values).cpu().numpy().flatten()

    plt.figure(figsize=(14, 6))
    plt.subplot(1, 2, 1)
    plt.scatter(x_values.cpu().numpy(), noisy_y_values, label='Noisy Data', color='blue', s=10)
    plt.plot(x_values.cpu().numpy(), y_values, label='True Sine', color='red', linestyle='--')
    plt.plot(x_values.cpu().numpy(), predicted_y_values, label='Model Prediction', color='green')
    plt.xlabel('x')
    plt.ylabel('y')
    plt.title('Model Predictions vs True Sine and Noisy Data')
    plt.legend()  # Add this line to ensure legend is created
    plt.grid(True)

    plt.subplot(1, 2, 2)
    plt.plot(loss, label='Loss')  # Add label for the loss plot
    plt.title('Loss over time')
    plt.xlabel('Epoch')
    plt.ylabel('Loss')
    plt.legend()  # Add this line to ensure legend is created
    plt.grid(True)
    plt.show()

# Plot the output
plot_output(points, model, loss_history, device)

# %% [markdown]
# จะเห็นได้ว่าผลลัพธ์การทำงานออกมาคล้ายเดิม

# %% [markdown]
# ## Generative AI และ Discriminative AI
#
# ในการใช้งาน AI ปัจจุบัน อาจแยกการใช้งานออกเป็น 2 แบบใหญ่ๆ
# - แบบแรกเรียกว่า Discriminative AI หรือ ปัญญาประดิษฐ์เชิงจำแนก ซึ่งมุ่งเน้นการจำแนกหรือการทำนายผลลัพธ์จากข้อมูลที่มีอยู่ โดยเน้นการแยกแยะความแตกต่างระหว่างข้อมูลในกลุ่มหรือประเภทต่างๆ หรือตัวแปรเป้าหมายจากข้อมูลอินพุต ซึ่งสิ่งที่เราเรียนไปจะอยู่ในกลุ่มนี้
# - แบบที่สองเรียกว่า Generative AI หรือ ปัญญาประดิษฐ์เชิงกำเนิด ซึ่งมุ่งเน้นในการสร้างข้อมูลใหม่ที่มีลักษณะคล้ายคลึงกับข้อมูลต้นแบบ เช่น การสร้างภาพ, ข้อความ, หรือเสียงใหม่จากการเรียนรู้จากชุดข้อมูลที่มีอยู่ ซึ่ง AI แบบหลังนี่เองที่สร้างความตื่นตัวขึ้นมาอย่างมาก เช่น Midjourney, DELL-E, ChatGPT, Gemini หรืออื่นๆ ถือว่าเป็น AI ในกลุ่มนี้

# %% [markdown]
# ## ประเภทของปัญญาประดิษฐ์เชิงจำแนก
#
# ใน Discriminative AI หรือ ปัญญาประดิษฐ์เชิงจำแนกนั้น ยังสามารถจำแนกประเภทได้เป็น 2 แบบ คือ
# - Regression คือ AI ที่สร้างขึ้นมาเพื่อทำนายค่าของตัวแปรเป้าหมาย  จากค่าของตัวแปรที่ป้อนให้ ตัวอย่างของ AI ประเภทนี้ เช่น การประมาณค่าในสมการเส้นตรง การประมาณค่าของฟังก์ชัน Sine ที่เราทำมาแล้ว หรืออาจจะเป็นการทำนายราคาบ้านจากขนาดและทำเลที่ตั้ง หรือการทำนายผลการขายจากงบประมาณการโฆษณา หรือ การทำนายราคารถยนต์ หรืออื่นๆ ซึ่งเป้าหมายของ Regression คือการหาความสัมพันธ์และการทำนายค่าที่แม่นยำที่สุดจากข้อมูลที่มีอยู่ โดยข้อมูลที่ทำนายมักจะมีลักษณะเป็นตัวเลข
# - Classification ซึ่งแปลว่าจำแนก ดังนั้นสิ่งที่ AI กลุ่มนี้ทำ คือ การจำแนกข้อมูลออกเป็นกลุ่มๆ ซึ่งเรามักเรียกว่า Class เช่น จำแนกว่าเป็นหมาหรือเป็นแมว หรือ จำแนกว่าเป็นวัตถุอะไร (เรียกว่า Object Detection) หรือ จำแนกใบหน้าคน (Face Recognition) หรือ จำแนกว่า เมล์นี้เป็น SPAM หรือไม่ หรือ เป็นโรคหรือไม่เป็นโรค หรือ จำแนกอารมณ์จากหน้า หรืออื่นๆ ที่สามารถกำหนดค่าเป้าหมายออกเป็นกลุ่มๆ ได้ ซึ่ง AI กลุ่มนี้ยังแบ่งออกเป็น ประเภทย่อย เช่น
# >- Binary Classification ก็คือ การแยกออกเป็นแค่ 2 กลุ่ม (class) เช่น เป็นหมาหรือเป็นแมว เป็น SPAM หรือไม่ SPAM เป็นโรคหรือไม่เป็นโรค
# >- Multiclass Classification คือ การแยกออกมากกว่า 2 กลุ่ม (class) เช่น แยกประเภทพันธ์สุนัข
# >- Multilabel Classification คือ ผลลัพธ์อาจมีหลายกลุ่ม เช่น การ Tag บทความด้วยประเภท
# >- ประเภทอื่นๆ ที่ไม่กล่าวในที่นี้ เพราะมีรายละะเอียดมาก และ ยังไม่จำเป็นต้องรู้ เช่น Imbalanced Classification, Ordinal Classification, Hierarchical Classification, ฯลฯ
#
# <div>
# <br>
# <img src="https://cdn-images-1.medium.com/max/1600/1*xs6Jr4iAPvoqszF9JgDWOA.png" width="600"/>
#
# </div>

# %% [markdown]
# ### ความแตกต่างของ Classification จาก Regression
#
# ในการเรียนที่ผ่านมา เรากล่าวถึงเฉพาะการทำงานในแบบ Regression ไม่ว่าจะเป็นการประมาณค่าสมการเส้นตรง หรือ การประมาณสมการค่า Sine แต่สำหรับวิธีการของ Classification จะมีความแตกต่างออกไปเล็กน้อย การทำงานของ Input Layer และ Hidden Layer จะเหมือนเดิม แต่สิ่งที่แตกต่างออกไป คือ Output Layer โดยแทนที่ จะมีการทำงานดังรูป (กรณี regrssion) ซึ่งจะเห็นได้ว่า ใน Output Layer จะมีเพียง Neuron เดียว เพราะต้องการข้อมูลออกมาเป็นตัวเลขเท่านั้น
#
# <div>
# <br>
# <img src="https://miro.medium.com/v2/resize:fit:1400/1*Gh5PS4R_A5drl5ebd_gNrg@2x.png" width="400"/>
# </div>
# <br>
#
# แต่สำหรับการทำงานแบบ Classification จะใช้ Output Layer หลาย Neuron
#
# <div>
# <br>
# <img src="https://editor.analyticsvidhya.com/uploads/30541010.png" width="400"/>
# </div>
# <br>
#
# อย่างไรก็ตามยังมีกรณีพิเศษ คือ กรณีของ Binary Classification เราสามารถใช้ Output Layer แบบ Neuron เดียวก็ได้ เนื่องจาก หากกำหนดให้ Output เป็น 0 หรือ 1 ก็สามารถใช้โมเดลแบบที่มี Output Layer แบบ Neuron เดียวมาทำเป็น Binary Classification ก็ได้ หรือจะใช้แบบมี Output Layer 2 Neuron ก็ได้
#
# <div>
# <br>
# <img src="https://www.researchgate.net/publication/330120030/figure/fig1/AS:735637925797888@1552401157053/Deep-Neural-Network-architecture.ppm" width="400"/>
# </div>
# <br>

# %% [markdown]
# ### Logistic Regression
#
# ในกรณีที่ต้องการคำตอบแบบ 2 ค่า เช่น “เกิด” กับ “ไม่เกิด” หรือ “เสี่ยง” กับ “ไม่เสี่ยง” หรือ “เป็น” กับ “ไม่เป็น” หรือที่เรียกกันว่า Binary Classification เราจะใช้วิธีการที่เรียกว่า Logistic Regression โดยจะใช้วิธีการคำนวณแบบตัวเลขเหมือนเดิม แต่จะมีกรรมวิธีที่จะตีความตัวเลขที่ได้ ว่าอยู่ในกลุ่มไหน เช่น สมมติมีข้อมูลต่อไปนี้
#
# | ลำดับที่  | ตัวเลขวิเคราะห์การเป็น Spam | เป็น Spam หรือไม่ | ความน่าจะเป็น (Logistic Regression)  |
# | ----- | ----- | ----- | ----- |
# |1	| 1.8 |	Y	| 0.8581 |
# |2	| -0.8 |	N	| 0.3100 |
# |3	| 2.2	| Y	| 0.9002 |
# |4	| -1.7	 | N	| 0.1545 |
# |5	| 0.4	| Y	| 0.5987 |
#
# - ตัวเลขในคอลัมน์ที่ 2 เป็นผลลัพธ์ (Raw Output) ที่ได้จาก Model
# - ข้อมูลในคอลัมน์ที่ 3 เป็น Label หรือคำตอบจริงว่าเป็น Spam หรือไม่เป็น
#
# หน้าที่อย่างแรก คือ จะต้องแปลงข้อมูลที่เป็นตัวเลขในคอลัมน์ที่ 2 ให้เป็น ความน่าจะเป็นคือให้ได้ตามคอลัมน์ที่ 4 ซึ่งความน่าจะเป็นจะมีค่าอยู่ระหว่าง 0-1
#
# ถ้ายังพอจำกันได้ ในเรื่องของ Activation Function มีฟังก์ชันหนึ่งที่ให้ Output อยู่ระหว่าง 0-1 ใช่แล้วครับ เรากำลังพูดถึง Sigmoid นั่นเอง ดังนั้นแปลว่า ถ้าเราจะนำเอาข้อมูลในคอลัมน์ที่ 2 เช่น 1.8 มาคำนวณด้วย Sigmoid ก็จะได้เป็นความน่าจะเป็น 0.85
#
# จากนั้นก็ใช้ค่าคงที่เพื่อบอกว่าเป็น หรือ ไม่เป็นต่อไป เช่น ถ้า > 0.5 ก็เป็น Spam แต่ < 0.5 ก็ไม่เป็น Spam

# %% [markdown]
# ### สร้าง Model Neural Network สำหรับ Logistic Classification
#
# เอาละ! เราจะมาลองใช้ Sigmoid เพื่อทำ Binary Classification กันดู แต่ก่อนอื่น เราจะมาสร้างโมเดล Neural Network กัน โดยการสร้าง Model เราจะไม่ใช้ `nn.Sequential` ตามแบบก่อนหน้านี้ แต่จะใช้วิธีการสร้าง Subclass ของ `nn.Model` ซึ่งแสดงตามโปรแกรมด้านล่าง
#
# ความแตกต่างของการสร้าง Model ในแบบ `nn.Sequential` กับแบบที่สร้าง Subclass ของ `nn.Model` คือ การสร้าง Model โดยใช้ `nn.Sequential` นั้นจะสั้น เหมาะกับโมเดลที่ไม่ซับซ้อน แต่ Model ที่สร้างจาก Subclass ของ `nn.Model` จะยาวกว่า แต่สามารถใส่รายละเอียดปลีกย่อยได้ ทำให้เหมาะสมกับโมเดลที่มีความซับซ้อน
#
# เนื่องจากต่อไปเราจะใช้โมเดลที่มีความซับซ้อนมากขึ้นเรื่อยๆ ดังนั้นต่อไปเราจะใช้แบบที่สร้าง Subclass ของ `nn.Model` เป็นหลัก

# %%
# Create a Logistic Regression model class

import torch
import torch.nn as nn

class LogisticRegressionModel(nn.Module): # <- almost everything in PyTorch is a nn.Module
    def __init__(self):
        super().__init__()
        # Create 2 nn.Linear layers capable of handling X and y input and output shapes
        self.layer_1 = nn.Linear(in_features=2, out_features=5) # takes in 2 features (X), produces 5 features
        self.layer_2 = nn.Linear(in_features=5, out_features=1) # takes in 5 features, produces 1 feature (y)

    def forward(self, x: torch.Tensor) -> torch.Tensor:
        return self.layer_2(self.layer_1(x)) # computation goes through layer_1 first then the output of layer_1 goes through layer_2

# %% [markdown]
# - ในบรรทัด `self.layer_1 = nn.Linear(in_features=2, out_features=5)` จะเป็นการสร้าง Layer ของ Neuron โดยกำหนดให้ Layer นี้มี 2 Input และมี 5 Output ซึ่งหมายความว่า Layer นี้จะมี Neuron จำนวน 5 ตัว
# - ในบรรทัด `self.layer_2 = nn.Linear(in_features=5, out_features=1)` จะเป็นการสร้าง Layer ของ Neuron โดยกำหนดให้ Layer นี้มี 5 Input และมี 1 Output ซึ่งหมายความว่า Layer นี้จะมี Neuron จำนวน 1 ตัว
#
# ซึ่งหากใช้ [tensorflow playground](https://playground.tensorflow.org) วาด ก็จะได้ Neuron Network ประมาณนี้
#
# <div>
# <br>
# <img src="https://github.com/khthana/AI_resource/blob/main/TF1.JPG?raw=true" width="900"/><div>
# <br>

# %% [markdown]
# - สำหรับใน `forward` ซึ่งมี `return self.layer_2(self.layer_1(x))` ก็คือการนำผลลัพธ์ของ Layer 1 ส่งต่อให้ Layer 2 และส่งผลกลับมาเท่านั้น

# %% [markdown]
# ### การสุ่มและความสำคัญของ Seed
#
# ก่อนจะไปทดสอบการทำงานของ Model ขออธิบายเรื่องการสุ่มในระบบคอมพิวเตอร์ซักเล็กน้อย
#
# การสุ่ม (Random) ในคอมพิวเตอร์จะต่างจากการสุ่มในโลกความเป็นจริง เพราะการสุ่มในโลกความเป็นจริง เช่น โยนหัวก้อย ผลที่เกิดขึ้นจะคาดเดาไม่ได้เลย แต่การสุ่มในคอมพิวเตอร์นั้นไม่ใช่การสุ่มจริง โดยจะมีชื่อเรียกเต็มๆ ว่า pseudo random หรือแปลว่าการสุ่มเทียม เพราะคอมพิวเตอร์ไม่สามารถโยนหัวก้อยได้ จึงต้องใช้ Algorithm ในการสร้างเลขสุ่มขึ้นมา ลองดูโปรแกรมต่อไปนี้

# %%
import torch

# กรณีไม่มี manual_seed
print("ไม่มี manual_seed 1:")
for i in range(3):
    print(torch.rand(3))
print("ไม่มี manual_seed 2:")
for i in range(3):
    print(torch.rand(3))
print("มี manual_seed 1:")
# กำหนด manual_seed = 12
torch.manual_seed(12)
for i in range(3):
    print(torch.rand(3))
print("มี manual_seed 2:")
torch.manual_seed(12)
for i in range(3):
    print(torch.rand(3))
# Out:
# ไม่มี manual_seed 1:
# tensor([0.5606, 0.1416, 0.9074])
# tensor([0.6254, 0.3713, 0.4473])
# tensor([0.3786, 0.6076, 0.2492])
# ไม่มี manual_seed 2:
# tensor([0.8418, 0.8725, 0.6560])
# tensor([0.0808, 0.4922, 0.4400])
# tensor([0.6630, 0.6516, 0.2026])
# มี manual_seed 1:
# tensor([0.4657, 0.2328, 0.4527])
# tensor([0.5871, 0.4086, 0.1272])
# tensor([0.6373, 0.2421, 0.7312])
# มี manual_seed 2:
# tensor([0.4657, 0.2328, 0.4527])
# tensor([0.5871, 0.4086, 0.1272])
# tensor([0.6373, 0.2421, 0.7312])

# %% [markdown]
# จะเห็นได้ว่ากรณีที่ไม่ได้ใช้ manual seed (บางทีเรียก random seed) ค่าสุ่มที่ได้จะเปลี่ยนไปเรื่อยๆ แต่หากใช้ manual seed แล้วค่าที่ได้จะเป็นค่าชุดเดิม
#
# **ถามว่า สำคัญอย่างไร**
#
# เนื่องจากค่า parameter ของ Model ล้วนแต่เกิดจากการ random ทั้งสิ้น สมมติว่าเราทำงานไปรอบที่ 1 กำหนดค่า hyperparameter ต่างๆ (learning rate, epoch, จำนวน node ในแต่ละ layer แล้วพบว่าได้ผลดี แต่พอมารันในรอบที่ 2 แล้วผลเปลี่ยนไปจากเดิม เราก็คงไม่พอใจใช่มั้ยครับ ดังนั้นเพื่อให้ผลการรันยังเหมือนเดิมทุกครั้ง การกำหนด manual_seed เอาไว้ก็จะทำให้ผลการทำงานเหมือนเดิมเสมอ ทำให้ในการปรับค่า hyperparameter สามารถทำได้อย่างเป็นระบบ เหมือนกับการควบคุมสภาพแวดล้อมของการทดลอง

# %% [markdown]
# ### ทดสอบการทำงานของ Logistic Regression
#
# หลังจากนอกเรื่องไปพูดถึงเรื่อง manual seed คราวนี้เรากลับมาเข้าเรื่องเดิม คือ หลังจากที่กำหนด Model แล้วก็มาดูข้อมูลภายใน Model กันดูบ้าง
#
# โปรแกรมด้านล่างนี้ เริ่มจากการกำหนด manual_seed ขึ้นมาค่าหนึ่ง
# จากนั้นกำหนด Model
# และนำ Model parameter เข้าไปที่ list และสั่งพิมพ์ parameter ออกมาดู จะเห็นว่ามี parameter ดังนี้
# 1.  ค่า weight จำนวน 10 ตัว ซึ่งเก็บอยู่ที่ hidden layer จำนวน 5 node โดยมี node ละ 2 ตัว (ตาม input)
# 2. ค่า bias ของ neuron ของ hidden layer จำนวน 5 ตัว
# 3. ค่า weight จำนวน 5 ตัว ซึ่งเก็บอยู่ที่ output layer
# 4. ค่า bias ของ neuron ของ output layer
#
# และ ถ้าสังเกตให้ดีจะมีคำว่า requires_grad=True ซึ่งแปลว่า ข้อมูลที่เก็บใน tensor นี้ จะเก็บค่า gradient เอาไว้ด้วยเพื่อใช้ในการคำนวณ

# %%
# Set manual seed since nn.Parameter are randomly initialzied
torch.manual_seed(42)

# Create an instance of the model (this is a subclass of nn.Module that contains nn.Parameter(s))
model_0 = LogisticRegressionModel()

# Check the nn.Parameter(s) within the nn.Module subclass we created
list(model_0.parameters())
# Out:
# [Parameter containing:
#  tensor([[ 0.5406,  0.5869],
#          [-0.1657,  0.6496],
#          [-0.1549,  0.1427],
#          [-0.3443,  0.4153],
#          [ 0.6233, -0.5188]], requires_grad=True),
#  Parameter containing:
#  tensor([0.6146, 0.1323, 0.5224, 0.0958, 0.3410], requires_grad=True),
#  Parameter containing:
#  tensor([[-0.0631,  0.3448,  0.0661, -0.2088,  0.1140]], requires_grad=True),
#  Parameter containing:
#  tensor([-0.2060], requires_grad=True)]

# %% [markdown]
# การแสดงข้อมูลสามารถทำได้อีกวิธี คือ ใช้ `.state_dict()` ซึ่งจะมีชื่อของข้อมูลแสดงให้เห็นด้วย

# %%
model_0.state_dict()
# Out:
# OrderedDict([('layer_1.weight',
#               tensor([[ 0.5406,  0.5869],
#                       [-0.1657,  0.6496],
#                       [-0.1549,  0.1427],
#                       [-0.3443,  0.4153],
#                       [ 0.6233, -0.5188]])),
#              ('layer_1.bias',
#               tensor([0.6146, 0.1323, 0.5224, 0.0958, 0.3410])),
#              ('layer_2.weight',
#               tensor([[-0.0631,  0.3448,  0.0661, -0.2088,  0.1140]])),
#              ('layer_2.bias', tensor([-0.2060]))])

# %% [markdown]
# คราวนี้เราจะสมมติข้อมูล เพื่อทดลองนำไปเข้า Model โดยสมมติว่ามี 5 ข้อมูลตามโปรแกรม ซึ่งตามปกติข้อมูล Input ที่เป็น Classification นอกจากจะมีข้อมูลดิบ แล้วยังต้องมีผลเฉลย หรือที่มักเรียกกันว่า Label
#
# จากนั้นนำ data แปลงเป็น Tensor แล้วเก็บในตัวแปร X จากนั้น feed เข้าสู่ Model และเก็บไว้ที่ตัวแปร untrain_preds

# %%
data= [[0.7542, 0.2315],
        [-0.7562, 0.1533],
        [-0.8154, 0.1733],
        [-0.3937, 0.6929],
        [0.4422, -0.8967]]
X = torch.tensor(data)  # Input features

label = [1., 1., 1., 1., 0.]
y = torch.tensor(label)  # Target labels

untrained_preds = model_0(X)  # Feed data to Model and output prediction

print(f"Length of predictions: {len(untrained_preds)}, Shape: {untrained_preds.shape}")
# Assuming y_test has the same length and format as y
print(f"Length of test samples: {len(y)}, Shape: {y.shape}")  # Use y instead of y_test
print(f"\nPredictions:\n{untrained_preds}")
print(f"\nTest labels: {y}")
# Out:
# Length of predictions: 5, Shape: torch.Size([5, 1])
# Length of test samples: 5, Shape: torch.Size([5])
#
# Predictions:
# tensor([[-0.1029],
#         [-0.1694],
#         [-0.1709],
#         [-0.1272],
#         [-0.1728]], grad_fn=<AddmmBackward0>)
#
# Test labels: tensor([1., 1., 1., 1., 0.])

# %% [markdown]
# จะเห็นว่าข้อมูลที่ทำนาย (Prediction) ออกมาจะเป็นตัวเลขที่มีขนาดไม่จำกัด
# แต่ Label หรือผลทำนาย เป็นตัวเลข 1 หรือ 0 ดังนั้น จะต้องทำ 2 ขั้นตอน คือ
# 1. ต้องแปลง ตัวเลข ให้อยู่ในรูปแบบของความน่าจะเป็นระหว่าง 0-1 ก่อน
# 2. สร้างจุดตัด เช่น 0.5 เพื่อเปลี่ยนเป็น 0 กับ 1
#
# การเปลี่ยนตัวเลขใดๆ ให้เป็นความน่าจะเป็น 0-1 โดยใช้ sigmoid
#
# >$
# \text{Sigmoid} = \log\left(\frac{p}{1 - p}\right)
# $
#
# ดังนั้นเราก็เพียงเอาตัวเลขไปผ่าน Sigmoid ก็จะได้ความน่าจะเป็นออกมา จากนั้นนำมาผ่าน round อีกชั้น ก็จะได้เป็น 1 หรือ 0

# %%
# View the outputs of the forward pass on the test data
y_logits = model_0(X)
print(f"Logit : \n{y_logits}\n")

# Use sigmoid on model logits
y_pred_probs = torch.sigmoid(y_logits)
print(f"Probability of prediction : \n{y_pred_probs}\n")

print(f"Prediction : \n{torch.round(y_pred_probs)}")
# Out:
# Logit :
# tensor([[-0.1029],
#         [-0.1694],
#         [-0.1709],
#         [-0.1272],
#         [-0.1728]], grad_fn=<AddmmBackward0>)
#
# Probability of prediction :
# tensor([[0.4743],
#         [0.4577],
#         [0.4574],
#         [0.4683],
#         [0.4569]], grad_fn=<SigmoidBackward0>)
#
# Prediction :
# tensor([[0.],
#         [0.],
#         [0.],
#         [0.],
#         [0.]], grad_fn=<RoundBackward0>)

# %% [markdown]
# ### Multiclass Classification
#
# คือกระบวนการจำแนกประเภทของข้อมูลออกเป็นหลายคลาส (มากกว่า 2 คลาส) โดยที่แต่ละตัวอย่างข้อมูลจะถูกจัดให้อยู่ในคลาสใดคลาสหนึ่งจากหลายคลาสที่มีอยู่ โดยอาจใช้งานได้หลากหลาย เช่น
#
# 1. การจำแนกประเภทของดอกไม้: เช่น การจำแนกดอกไม้เป็นสายพันธุ์ต่างๆ เช่น Setosa, Versicolor, Virginica
# 2. การรู้จำภาพ: เช่น การจำแนกภาพเป็นประเภทต่างๆ เช่น แมว, สุนัข, รถยนต์, ต้นไม้
# 3. การวิเคราะห์ข้อความ: เช่น การจำแนกประเภทของอีเมลเป็นหมวดหมู่ต่างๆ เช่น งาน, ส่วนตัว, สแปม
#
# การทำงานใน Multiclass Classification จะมีขั้นตอนเพิ่มมากกว่า Binary Classification หลายอย่าง ได้แก่
#
# 1. การเตรียมข้อมูล Input หรือ การแปลงข้อมูล Input เนื่องจากในกระบวนการทำงานทุกอย่างจะต้องเป็นตัวเลขเสมอ ดังนั้น สมมติว่าจะสร้าง AI ที่แยะแยะระหว่าง กระเพรา โหระพา และ แมงลัก ก็จะต้องมีการทำ Label Encoding หรือ แปลงคลาสต่างๆ ให้เป็นค่าตัวเลข เช่น กระเพรา = 0, โหระพา = 1, แมงลัก = 2 นอกจากนั้นยังจะต้องแปลงข้อมูลให้อยู่ในรูปของ One-Hot Encoding (เวกเตอร์ที่มี 1 เพียงที่เดียว) โดย แปลงคลาสต่างๆ ให้เป็นเวกเตอร์ เช่น [1, 0, 0] สำหรับ กระเพรา, [0, 1, 0] สำหรับ โหระพา, [0, 0, 1] สำหรับ แมงลัก
#
# ซึ่งในตอนที่ยกตัวอย่างการทำงาน ก็จะเห็นวิธีการได้ชัดเจน
#
# 2. ส่วนของ Output Layer จะต้องเปลี่ยนการคำนวณ Logistic Regression แบบหลายคลาส (Multinomial Logistic Regression) จากเดิมที่ใช้ Sigmoid ไปใช้ฟังก์ชันแบบใหม่ที่เรียกว่า Softmax

# %% [markdown]
# ### Softmax
#
# Softmax อาจถือได้ว่าเป็น Actication Function ตัวหนึ่ง โดยมีบทบาทคล้ายกับ Sigmoid แต่ในขณะที่ Sigmoid (ที่ผ่าน round อีกรอบ) มีผลทำให้เกิดตัวเลขเพียง 0 และ 1 เพื่อใช้ในการทำนาย Binary Classification แต่ Softmax จะให้ผลลัพธ์เป็นตัวเลขความน่าจะเป็นที่จะตรงกับข้อมูลแต่ละกลุ่ม การทำงานของ Softmax แสดงดังรูป
#
# <div>
#
# <img src="https://images.contentstack.io/v3/assets/bltac01ee6daa3a1e14/blte5e1674e3883fab3/65ef8ba4039fdd4df8335b7c/img_blog_image1_inline_(2).png?width=2240&disable=upscale&auto=webp" width="400"/><div>
# <br>
#
# จะเห็นว่าหลักของการทำงาน คือ ต้องแปลงค่าใน Output Layer ซึ่งออกมาเป็นตัวเลขให้เป็นความน่าจะเป็นที่ Input จะอยู่ในกลุ่มต่างๆ
# - อาจจะใช้วิธีนำตัวเลขของแต่ละตัวมาบวกกัน แล้วใช้เป็นตัวหารของตัวเลขแต่ละตัวก็ได้ แต่จะมีปัญหาข้อมูลบวกลบที่อาจจะหักล้างกันเอง
# - จึงใช้ยกกำลังเพื่อป้องกันค่าติดลบ คราวนี้พอพิจารณาเรื่องยกกำลัง เขาก็เลือก $e^x$ โดยมีเหตุผล คือ ยกกำลังเพราะหาอนุพันธ์ง่ายและค่าไม่ติดลบ
# - ดังนั้นก็เริ่มจากนำทุกค่ามาทำ $e^x$ เช่น $e^{z1}+e^{z2}+e^{z3}+e^{z4}+e^{z5}$
# - จากนั้นนำมารวมกัน (Sum) และ นำมาเป็นตัวหาร
# - ตย. $e^{1.3} / (e^{1.3}+e^{5.1}+e^{2.2}+e^{0.7}+e^{1.1})$ จะได้เป็น 0.02
#
# วิธีการแบบนี้เรียกว่า Softmax ซึ่งสังเกตุว่า ผลลัพธ์ของทุกตัวรวมกันจะเท่ากับ 1.0

# %% [markdown]
# ### Cross Entropy Loss
#
# สรุปว่า Activation Function ของ Output Layer กำหนดให้เป็น Softmax เพื่อแสดงความน่าจะเป็นที่ Input นั้นจะเป็น output ตัวไหนมากที่สุด
#
# คราวนี้จะพิจารณาหาค่า Loss จาก Softmax ซึ่งจะใช้หลักการที่เรียกว่า Cross Entropy Loss
#
# - Entropy เป็นการวัดความไม่แน่นอน (uncertainty) หรือความสุ่ม (randomness) ของการแจกแจงความน่าจะเป็น ดังนั้น Cross Entropy Loss จึงแปลว่าการวัดค่า Loss ของความน่าจะเป็นเมื่อเทียบกับความน่าจะเป็นทั้งหมด
#
# >$ \text{Cross Entropy Loss} = - \sum_{i} y_i \log(p_i) $
#
# โดยที่:
# - $ y_i $ คือค่าจริงของตัวอย่างที่ $i$ (one-hot encoded)
# - $ p_i $ คือค่าความน่าจะเป็นที่โมเดลคาดการณ์สำหรับคลาสที่ $i$
#
# ลองมาดูการใช้งานสมมติว่า
# - ข้อมูล $y_i$ คือ $[0,1,0,0,0]$ (one-hot encoded)
# - ความน่าจะเป็น $p_i$ คือ $[0.02, 0.90, 0.05, 0.01, 0.02]$
#
# >$Cross Entropy Loss = $
# $−[0⋅log(0.02)+1⋅log(0.90)+0⋅log(0.05)+0⋅log(0.01)+0⋅log(0.02)] $
#
# >$= −log(0.90) $
#
# >$= 0.105360516 $
#
# นี่เป็นกรณีที่ผลลัพธ์กับเป้าหมายตรงกัน
#
# แต่หากเป็นกรณีที่ผลลัพธ์กับเป้าหมายไม่ตรงกัน เช่น สมมติว่า $y_i$ คือ $[1,0,0,0,0]$
#
# >$Cross Entropy Loss= $
#
# >$−[1⋅log(0.02)+0⋅log(0.90)+0⋅log(0.05)+0⋅log(0.01)+0⋅log(0.02)] $
#
# >$=−log(0.02) $
#
# >$= 3.912023005428146$
#
# ซึ่งจะเห็นได้ชัดเจนว่ากรณีผลลัพธ์ตรงกับเป้าหมายจะให้ค่า Loss ที่ต่ำ และหากผลลัพธ์ไม่ตรงกับเป้าหมาย จะให้ค่า Loss ที่สูง

# %% [markdown]
# # การ Classification ข้อมูลตัวเลขไทย
#
# หลังจากที่ได้อธิบาย Loss Function ที่ใช้กับ Multiple Classification กันไปแล้ว ต่อไปเราจะมาทำงานกับข้อมูลจริง โดยข้อมูลนี้เป็นข้อมูลจาก [https://github.com/kittinan/thai-handwriting-number](https://github.com/kittinan/thai-handwriting-number) แต่นำมา clean ข้อมูลบางส่วนอีกที โดยมีตัวอย่างข้อมูลดังนี้
#
# <div>
#
# <img src="https://raw.githubusercontent.com/kittinan/thai-handwriting-number/master/docs/img/thai-handwriting-number.png" width="800"/><div>
# <br>
#
# เราจะนำข้อมูลมาทำการ Classification ว่าเป็นเลขใดใน 0-9 ดังนั้นโจทย์นี้จะมี คลาสคำตอบอยู่ทั้งหมด 10 คลาส
#
# ในการนำข้อมูลเข้ามา เราจะใช้คำสั่ง git clone ตามโปรแกรมด้านล่าง เพื่อ copy ข้อมูลจาก repository มายัง google colab ของเรา
#
# **ข้อควรระวัง**
# ข้อมูลใน google colab จะอยู่เฉพาะตอนที่รัน เมื่อออกจากการทำงานข้อมูลจะถูกลบทัังหมด ดังนั้นต้องทำใหม่ทุกครั้ง

# %%
# !git clone https://github.com/NextGen-AI-Camp/curriculum/
# Out:
# Cloning into 'curriculum'...
# remote: Enumerating objects: 108, done.
# remote: Counting objects: 100% (108/108), done.
# remote: Compressing objects: 100% (92/92), done.
# remote: Total 108 (delta 30), reused 62 (delta 13), pack-reused 0
# Receiving objects: 100% (108/108), 12.60 MiB | 31.70 MiB/s, done.
# Resolving deltas: 100% (30/30), done.

# %% [markdown]
# เนื่องจากข้อมูลจะเป็นแบบ compress ดังนั้นจะต้องแตกไฟล์โดยใช้คำสั่งข้างล่างนี้

# %%
# !unzip /content/curriculum/Dataset/thai-handwritten-dataset.zip -d /content/curriculum/Dataset/
# Out:
# Archive:  /content/curriculum/Dataset/thai-handwritten-dataset.zip
#    creating: /content/curriculum/Dataset/thai-handwritten-dataset/
#    creating: /content/curriculum/Dataset/thai-handwritten-dataset/0/
#   inflating: /content/curriculum/Dataset/thai-handwritten-dataset/0/0098326c-aa9e-410d-b949-e13d3cd74cfd.png
#   inflating: /content/curriculum/Dataset/thai-handwritten-dataset/0/02415aec-d4a3-4762-a1e5-bf4fe584aa66.png
#   inflating: /content/curriculum/Dataset/thai-handwritten-dataset/0/051d7c9a-2b54-4e73-9d0b-3fa75dcf1539.png
#   inflating: /content/curriculum/Dataset/thai-handwritten-dataset/0/05587e2a-e6f1-4191-8246-61e3f1cf59e9.png
#   inflating: /content/curriculum/Dataset/thai-handwritten-dataset/0/09165777-8ac1-4638-bf06-741896c7e1b9.png
#   inflating: /content/curriculum/Dataset/thai-handwritten-dataset/0/0a51150d-0afd-455e-9782-9141b68475ed.png
#   inflating: /content/curriculum/Dataset/thai-handwritten-dataset/0/0a8e39b3-4d7c-4050-a25d-746a6b8de686.png
#   inflating: /content/curriculum/Dataset/thai-handwritten-dataset/0/0b48e328-0e73-4946-8fe5-c2324cf55c88.png
#   inflating: /content/curriculum/Dataset/thai-handwritten-dataset/0/0b7155a7-4e52-4485-a675-d53397049917.png
#   inflating: /content/curriculum/Dataset/thai-handwritten-dataset/0/0f14b574-daf6-4a22-ae06-86eaeee72efa.png
#   inflating: /content/curriculum/Dataset/thai-handwritten-dataset/0/12a710d6-8774-4468-93c8-5edc8f7b8ad8.png
#   inflating: /content/curriculum/Dataset/thai-handwritten-dataset/0/136d09a5-05af-47d6-b9ca-be4c3d6b24ea.png
#   inflating: /content/curriculum/Dataset/thai-handwritten-dataset/0/14113d5b-146d-487e-a4ff-bcff10cd25d6.png
#   inflating: /content/curriculum/Dataset/thai-handwritten-dataset/0/18332707-69ff-47ca-89ea-ce468a473cb8.png
#   inflating: /content/curriculum/Dataset/thai-handwritten-dataset/0/19867988-3ae7-478f-b934-3f6c51b47fed.png
#   inflating: /content/curriculum/Dataset/thai-handwritten-dataset/0/1c09699b-4b5f-4a13-8193-a154e569abed.png
#   inflating: /content/curriculum/Dataset/thai-handwritten-dataset/0/1cb62f0c-7ba6-492e-9a67-a3a4d8af7cf8.png
#   inflating: /content/curriculum/Dataset/thai-handwritten-dataset/0/1e7a0e6c-9b02-434c-bf88-6d60958adab7.png
#   inflating: /content/curriculum/Dataset/thai-handwritten-dataset/0/1fd3d350-d79b-420e-8052-b2a04f7de87d.png
#   inflating: /content/curriculum/Dataset/thai-handwritten-dataset/0/206aed63-05a8-4105-b9b1-7cbf70557783.png
#   inflating: /content/curriculum/Dataset/thai-handwritten-dataset/0/20_2864961c-7481-43f8-b6bc-dacaec8913d3.png
#   inflating: /content/curriculum/Dataset/thai-handwritten-dataset/0/21fc8e57-6097-497e-aa62-50d16abc6321.png
#   inflating: /content/curriculum/Dataset/thai-handwritten-dataset/0/21_0b978eb2-bfd6-4587-a095-bcf1408ea829.png
#   inflating: /content/curriculum/Dataset/thai-handwritten-dataset/0/21_0cce64ca-f6e6-4b77-99ec-f06922163ab7.png
#   inflating: /content/curriculum/Dataset/thai-handwritten-dataset/0/21_333cdee9-234a-46da-83d9-8cbb12965a2d.png
#   inflating: /content/curriculum/Dataset/thai-handwritten-dataset/0/2271c5c4-4099-4f21-9bac-a8cc0af2b181.png
#   inflating: /content/curriculum/Dataset/thai-handwritten-dataset/0/22af2c46-9229-4e4a-b7c9-590c310273af.png
#   inflating: /content/curriculum/Dataset/thai-handwritten-dataset/0/22_50e3df51-981a-413a-951e-cb074d9fa3ff.png
#   inflating: /content/curriculum/Dataset/thai-handwritten-dataset/0/22_e9db2799-214e-463e-8890-2c1900ef5d9d.png
#   inflating: /content/curriculum/Dataset/thai-handwritten-dataset/0/23_6db9fc09-96ed-44a9-8052-cfad0e2e34c1.png
#   inflating: /content/curriculum/Dataset/thai-handwritten-dataset/0/24_69799b34-de22-4866-b1cd-dd76fcd8566c.png
#   inflating: /content/curriculum/Dataset/thai-handwritten-dataset/0/24_c51fbd41-94f8-42c6-8eee-52fa4c0c574b.png
#   inflating: /content/curriculum/Dataset/thai-handwritten-dataset/0/25_68b67e04-51ee-4db5-8b11-fc70965e5ed2.png
#   inflating: /content/curriculum/Dataset/thai-handwritten-dataset/0/25_88a89388-02dd-4244-9580-4e9e98eb12b4.png
#   inflating: /content/curriculum/Dataset/thai-handwritten-dataset/0/26a9523d-b782-47c0-a678-3b04aea2867e.png
#   inflating: /content/curriculum/Dataset/thai-handwritten-dataset/0/26_3ee523f0-f687-4b31-84d4-d499c8241f83.png
#   inflating: /content/curriculum/Dataset/thai-handwritten-dataset/0/26_fda94ed8-bb0a-4b87-b327-926ca1649371.png
#   inflating: /content/curriculum/Dataset/thai-handwritten-dataset/0/2703d9f2-d0d6-4547-a087-e5b97654c95e.png
#   inflating: /content/curriculum/Dataset/thai-handwritten-dataset/0/27_446dc181-636f-457b-b124-1660f26b12c4.png
#   inflating: /content/curriculum/Dataset/thai-handwritten-dataset/0/27_a2906e61-1956-469c-b882-35b6b1514871.png
#   inflating: /content/curriculum/Dataset/thai-handwritten-dataset/0/27_a4d5211f-a587-4d3d-8060-5fc86ff984bb.png
#   inflating: /content/curriculum/Dataset/thai-handwritten-dataset/0/27_f99428f4-21d4-4e7c-97c5-8d6b69b2451a.png
#   inflating: /content/curriculum/Dataset/thai-handwritten-dataset/0/288c27d7-7287-477a-91d5-580c48b24564.png
#   inflating: /content/curriculum/Dataset/thai-handwritten-dataset/0/296cc7f7-1c8f-4b34-b2df-7673eecd80ac.png
#   inflating: /content/curriculum/Dataset/thai-handwritten-dataset/0/297b1457-bf0c-4d92-847d-69e151e38f03.png
#   inflating: /content/curriculum/Dataset/thai-handwritten-dataset/0/29_056a10b8-1fff-49cd-a0ca-afcd0130825a.png
#   inflating: /content/curriculum/Dataset/thai-handwritten-dataset/0/29_32d908eb-d9a4-4c22-80f2-3b0ddd486bd8.png
#   inflating: /content/curriculum/Dataset/thai-handwritten-dataset/0/29_5a1c9814-68a2-418c-b73d-a717d58cd066.png
#   inflating: /content/curriculum/Dataset/thai-handwritten-dataset/0/29_5b3dbb03-bd57-4e38-8695-dc42d519a066.png
#   inflating: /content/curriculum/Dataset/thai-handwritten-dataset/0/29_e82b5700-f60a-4ace-b9ad-bad9b8ac6de1.png
#   inflating: /content/curriculum/Dataset/thai-handwritten-dataset/0/29_ff2c097b-8bd3-4cf1-91be-d49196f4f5b1.png
#   inflating: /content/curriculum/Dataset/thai-handwritten-dataset/0/2c35dfca-6982-4b27-8328-09f7fff2827a.png
#   inflating: /content/curriculum/Dataset/thai-handwritten-dataset/0/2e64c13a-c763-4f08-96b8-652909cb2032.png
#   inflating: /content/curriculum/Dataset/thai-handwritten-dataset/0/30_19d391bc-519e-4c2d-9389-1a3e2cc3f1ad.png
#   inflating: /content/curriculum/Dataset/thai-handwritten-dataset/0/30_5b05c5f8-c5d1-41d9-afe0-fb7205471e4a.png
#   inflating: /content/curriculum/Dataset/thai-handwritten-dataset/0/31_0a29845c-aad3-4f48-8bed-7a87b86e861d.png
#   inflating: /content/curriculum/Dataset/thai-handwritten-dataset/0/31_c052c230-4af1-45b6-9177-d7758fb2ff6b.png
#   inflating: /content/curriculum/Dataset/thai-handwritten-dataset/0/3207615b-b1f3-40eb-8777-7fce669fa242.png
#   inflating: /content/curriculum/Dataset/thai-handwritten-dataset/0/32585979-33a9-44a7-aeab-b90e8b17025c.png
#   inflating: /content/curriculum/Dataset/thai-handwritten-dataset/0/33_c8de7a32-dbbc-45d0-bfae-b43afa40074f.png
#   inflating: /content/curriculum/Dataset/thai-handwritten-dataset/0/34_5eb5bc4c-64ba-4d53-bc21-c5c8228fe580.png
#   inflating: /content/curriculum/Dataset/thai-handwritten-dataset/0/35_12be8d35-b827-4514-8b54-eeea9c48b491.png
#   inflating: /content/curriculum/Dataset/thai-handwritten-dataset/0/35_ba261ff8-1eb7-452e-944b-30c473b3a76a.png
#   inflating: /content/curriculum/Dataset/thai-handwritten-dataset/0/364b41b9-43b7-45ee-a7be-956c33f0cf7b.png
#   inflating: /content/curriculum/Dataset/thai-handwritten-dataset/0/37488f3e-6944-4a2a-99dd-43c790183c80.png
#   inflating: /content/curriculum/Dataset/thai-handwritten-dataset/0/376b5857-d33b-4eab-9491-1c346741717b.png
#   inflating: /content/curriculum/Dataset/thai-handwritten-dataset/0/37_8e0e0499-7e9c-42cc-8b1c-8d54398367fa.png
#   inflating: /content/curriculum/Dataset/thai-handwritten-dataset/0/37_a78b761e-2039-4755-b5ec-8747240f0cd4.png
#   inflating: /content/curriculum/Dataset/thai-handwritten-dataset/0/37_d6e7ce89-dc1a-47f7-96bc-45e78ca57c73.png
#   inflating: /content/curriculum/Dataset/thai-handwritten-dataset/0/37_e88da3e6-11d9-44bc-9021-3393d43b4756.png
#   inflating: /content/curriculum/Dataset/thai-handwritten-dataset/0/37_f65be60c-cf0a-4c44-b5b6-29bf9298b1fc.png
#   inflating: /content/curriculum/Dataset/thai-handwritten-dataset/0/38_647c93ed-330c-4525-bafb-d1e29b7df65f.png
#   inflating: /content/curriculum/Dataset/thai-handwritten-dataset/0/38_b453540e-12c1-423e-93e4-a1605a3181f3.png
#   inflating: /content/curriculum/Dataset/thai-handwritten-dataset/0/3d0e872f-4def-4d84-823f-9c5606f7f672.png
#   inflating: /content/curriculum/Dataset/thai-handwritten-dataset/0/40_1f250dec-c0ae-442f-90ef-f41c30dff87a.png
#   inflating: /content/curriculum/Dataset/thai-handwritten-dataset/0/40_a69be344-cfe6-4b09-af57-0b563115e212.png
#   inflating: /content/curriculum/Dataset/thai-handwritten-dataset/0/41639886-eef5-4de0-91e1-5c01a653dc05.png
#   inflating: /content/curriculum/Dataset/thai-handwritten-dataset/0/41dc9580-4104-4505-acc7-b99ad6aa4fee.png
#   inflating: /content/curriculum/Dataset/thai-handwritten-dataset/0/445a454e-435a-4e7a-bf57-63ef3917f1d8.png
#   inflating: /content/curriculum/Dataset/thai-handwritten-dataset/0/44_9f2d7454-dd40-4c4a-916e-5d310196c854.png
#   inflating: /content/curriculum/Dataset/thai-handwritten-dataset/0/44_de8f50ce-68ee-4867-9c65-8ac7e977179d.png
#   inflating: /content/curriculum/Dataset/thai-handwritten-dataset/0/4889b382-fddb-4f02-bc81-eb8d16aca1b7.png
#   inflating: /content/curriculum/Dataset/thai-handwritten-dataset/0/49a4314b-68e4-443a-85cb-6f8c30f5143a.png
#   inflating: /content/curriculum/Dataset/thai-handwritten-dataset/0/4a90e3ed-1019-4595-b525-e0b4fa702b81.png
#   inflating: /content/curriculum/Dataset/thai-handwritten-dataset/0/4c0da7b7-6dc1-412d-96b3-944f7c2b53cc.png
#   inflating: /content/curriculum/Dataset/thai-handwritten-dataset/0/4cb18a6d-d793-4d82-b03f-bfeeb760cb02.png
#   inflating: /content/curriculum/Dataset/thai-handwritten-dataset/0/4e8c9277-a1f5-47a6-87ad-2a058405f996.png
#   inflating: /content/curriculum/Dataset/thai-handwritten-dataset/0/4fb09988-bc3b-48cc-b0cf-cf74b70ef712.png
#   inflating: /content/curriculum/Dataset/thai-handwritten-dataset/0/504cd1fd-14d3-442a-b694-8da967748ba5.png
#   inflating: /content/curriculum/Dataset/thai-handwritten-dataset/0/527f32ba-3c4a-4e47-be39-056d4989b061.png
#   inflating: /content/curriculum/Dataset/thai-handwritten-dataset/0/53c9ac1f-6e18-46e8-97b2-ea5dd3b135f1.png
#   inflating: /content/curriculum/Dataset/thai-handwritten-dataset/0/5437cad2-2cc1-4a07-aa20-f019c3d6845d.png
#   inflating: /content/curriculum/Dataset/thai-handwritten-dataset/0/5489a3f6-6434-4e4c-8060-b277c202a3fd.png
#   inflating: /content/curriculum/Dataset/thai-handwritten-dataset/0/59427957-9fa6-4b28-b73a-e8b4a03455a6.png
#   inflating: /content/curriculum/Dataset/thai-handwritten-dataset/0/5bf28b06-c6e2-4243-a859-794e5e1d6849.png
#   inflating: /content/curriculum/Dataset/thai-handwritten-dataset/0/5df9143e-69fe-4f99-91de-cbec97f15039.png
#   inflating: /content/curriculum/Dataset/thai-handwritten-dataset/0/5f700dba-fecf-4a3f-b49a-2fadd8866d18.png
#   inflating: /content/curriculum/Dataset/thai-handwritten-dataset/0/6538b23f-fa6c-42d5-8f38-12c70ac2586e.png
#   inflating: /content/curriculum/Dataset/thai-handwritten-dataset/0/665f0c7b-33e4-49c5-9f88-3bf28ddee0d1.png
#   inflating: /content/curriculum/Dataset/thai-handwritten-dataset/0/6758a5f0-f4f9-4fa1-9653-3e772737294f.png
#   inflating: /content/curriculum/Dataset/thai-handwritten-dataset/0/6a008b6f-5f5e-479d-83e4-21ba2fac8ef9.png
#   inflating: /content/curriculum/Dataset/thai-handwritten-dataset/0/6afb4ca1-11e4-4b5b-8679-b600b545f211.png
#   inflating: /content/curriculum/Dataset/thai-handwritten-dataset/0/6bb3907a-19b2-49da-8438-bfd05df4f7ba.png
#   inflating: /content/curriculum/Dataset/thai-handwritten-dataset/0/6c3c2054-9114-424f-b928-39aa8619a835.png
#   inflating: /content/curriculum/Dataset/thai-handwritten-dataset/0/6ce28806-35e0-486c-b235-65bf1d5cca08.png
#   inflating: /content/curriculum/Dataset/thai-handwritten-dataset/0/6db9fc09-96ed-44a9-8052-cfad0e2e34c1.png
#   inflating: /content/curriculum/Dataset/thai-handwritten-dataset/0/6ef7bb23-bbec-40fe-8f97-4bc20284afc6.png
#   inflating: /content/curriculum/Dataset/thai-handwritten-dataset/0/71490747-c9e9-4635-965c-404735ecd783.png
#   inflating: /content/curriculum/Dataset/thai-handwritten-dataset/0/72ab9f80-3341-44b0-bf64-8dac1ba4b011.png
#   inflating: /content/curriculum/Dataset/thai-handwritten-dataset/0/736ab16a-1d9c-4dcb-bba8-16a4f7879559.png
#   inflating: /content/curriculum/Dataset/thai-handwritten-dataset/0/7405ec15-df29-4056-bcf2-056c54b908bd.png
#   inflating: /content/curriculum/Dataset/thai-handwritten-dataset/0/75c725fd-211b-450b-a386-ad72f990cbd2.png
#   inflating: /content/curriculum/Dataset/thai-handwritten-dataset/0/7873a30b-e9bc-4e2a-9c80-62ebf2a852ae.png
#   inflating: /content/curriculum/Dataset/thai-handwritten-dataset/0/7c6937a4-b351-4b43-9f6b-0eca4b1ea0b6.png
#   inflating: /content/curriculum/Dataset/thai-handwritten-dataset/0/7df9d218-313d-4ba5-91f3-81e6089e2e87.png
#   inflating: /content/curriculum/Dataset/thai-handwritten-dataset/0/7f2d7dde-86ce-442c-8c93-e477528fd9e0.png
#   inflating: /content/curriculum/Dataset/thai-handwritten-dataset/0/805cddfe-0603-4c78-b224-ce4d33d6c0b2.png
#   inflating: /content/curriculum/Dataset/thai-handwritten-dataset/0/81d3f7b2-4644-4c83-b01e-237d9563f318.png
#   inflating: /content/curriculum/Dataset/thai-handwritten-dataset/0/82065dab-4172-4369-80e3-101ea533be8f.png
#   inflating: /content/curriculum/Dataset/thai-handwritten-dataset/0/825a4276-7839-4bdd-81ae-253b978c7e4d.png
#   inflating: /content/curriculum/Dataset/thai-handwritten-dataset/0/839dcddb-e9fb-4b7a-9c68-969eee92f2a5.png
#   inflating: /content/curriculum/Dataset/thai-handwritten-dataset/0/84a8ff60-7740-41f3-a594-f4d0d4a75018.png
#   inflating: /content/curriculum/Dataset/thai-handwritten-dataset/0/85eaa4dc-3aff-4840-a2d4-179a2c047651.png
#   inflating: /content/curriculum/Dataset/thai-handwritten-dataset/0/8d79ae43-34ca-4f49-8d38-98384d57566a.png
#   inflating: /content/curriculum/Dataset/thai-handwritten-dataset/0/8e0e0499-7e9c-42cc-8b1c-8d54398367fa.png
#   inflating: /content/curriculum/Dataset/thai-handwritten-dataset/0/8e117d81-c6d6-4f34-a11a-43d3b6cd2d3d.png
#   inflating: /content/curriculum/Dataset/thai-handwritten-dataset/0/9584c39b-82ce-4834-a171-f16ae6be98e9.png
#   inflating: /content/curriculum/Dataset/thai-handwritten-dataset/0/96140adf-5a81-4d06-841d-d6db23f89ca7.png
#   inflating: /content/curriculum/Dataset/thai-handwritten-dataset/0/98f01bd2-e214-433f-a848-ecf4fc100e6d.png
#   inflating: /content/curriculum/Dataset/thai-handwritten-dataset/0/9b72c4c7-d4e6-4e28-b263-6bc305ddd003.png
#   inflating: /content/curriculum/Dataset/thai-handwritten-dataset/0/a03cc6e2-326d-4b7c-96dc-bc8eccca909a.png
#   inflating: /content/curriculum/Dataset/thai-handwritten-dataset/0/a2b6edc8-2373-4854-a66c-da5928171610.png
#   inflating: /content/curriculum/Dataset/thai-handwritten-dataset/0/a427e80c-a6a5-4c77-a064-2eba49ea0d2b.png
#   inflating: /content/curriculum/Dataset/thai-handwritten-dataset/0/a58fffa3-e1a7-4c6f-b29e-a5bd2d2f6c3d.png
#   inflating: /content/curriculum/Dataset/thai-handwritten-dataset/0/a639354a-9be9-45dd-8be2-10264f75bd4f.png
#   inflating: /content/curriculum/Dataset/thai-handwritten-dataset/0/a78b761e-2039-4755-b5ec-8747240f0cd4.png
#   inflating: /content/curriculum/Dataset/thai-handwritten-dataset/0/ae00abb4-8864-4d9f-99af-ebf9e0ef8f52.png
#   inflating: /content/curriculum/Dataset/thai-handwritten-dataset/0/ae9006e5-764b-495c-ad9b-aea5df546eb9.png
#   inflating: /content/curriculum/Dataset/thai-handwritten-dataset/0/af0d395e-f6b3-40a6-81f3-a3a77ec7996c.png
#   inflating: /content/curriculum/Dataset/thai-handwritten-dataset/0/b01291b5-f7a2-4a1e-9f75-83d5754d24c3.png
#   inflating: /content/curriculum/Dataset/thai-handwritten-dataset/0/b06349cd-3c32-45c3-896a-36ae8f58cd44.png
#   inflating: /content/curriculum/Dataset/thai-handwritten-dataset/0/b2a55151-fcac-483a-80cb-37ea0131828d.png
#   inflating: /content/curriculum/Dataset/thai-handwritten-dataset/0/b6b40844-50cc-4847-8b83-9961b3bf7b2a.png
#   inflating: /content/curriculum/Dataset/thai-handwritten-dataset/0/b870715e-8162-403f-a061-240e7f445d6d.png
#   inflating: /content/curriculum/Dataset/thai-handwritten-dataset/0/bb22aa67-b9d5-466a-9334-718ca6391b4c.png
#   inflating: /content/curriculum/Dataset/thai-handwritten-dataset/0/bb49430e-72a1-47f0-8965-667a1aaa938f.png
#   inflating: /content/curriculum/Dataset/thai-handwritten-dataset/0/bd733e16-0cd6-4746-a5da-8a459032b6af.png
#   inflating: /content/curriculum/Dataset/thai-handwritten-dataset/0/c04b59ea-0a6c-4dee-8e7c-45e3ca970c1e.png
#   inflating: /content/curriculum/Dataset/thai-handwritten-dataset/0/c17a09d4-a8b0-40be-bcd1-4666b8a00d61.png
#   inflating: /content/curriculum/Dataset/thai-handwritten-dataset/0/c2361c50-30ed-4420-b7b4-db0b4f021005.png
#   inflating: /content/curriculum/Dataset/thai-handwritten-dataset/0/c7d9e3cd-ff4f-4fe8-9525-351a3ffd6b8e.png
#   inflating: /content/curriculum/Dataset/thai-handwritten-dataset/0/ca6f8a66-1c4d-4d4d-bf3e-c03d9e5da610.png
#   inflating: /content/curriculum/Dataset/thai-handwritten-dataset/0/cccff6b3-8d74-4718-ab8e-38cbfa845ff9.png
#   inflating: /content/curriculum/Dataset/thai-handwritten-dataset/0/cdd62ceb-15e0-4c75-bbc2-83852a658959.png
#   inflating: /content/curriculum/Dataset/thai-handwritten-dataset/0/ce169337-9ad4-423b-b185-eaf502169cc1.png
#   inflating: /content/curriculum/Dataset/thai-handwritten-dataset/0/cf5ffe38-3822-44d1-8c11-e04c66fd706f.png
#   inflating: /content/curriculum/Dataset/thai-handwritten-dataset/0/d43229b0-faa7-498e-987f-02136edff8bd.png
#   inflating: /content/curriculum/Dataset/thai-handwritten-dataset/0/d86d0ca1-d4cb-48e9-aa8a-6c0ffe80f93e.png
#   inflating: /content/curriculum/Dataset/thai-handwritten-dataset/0/db5328a6-6d83-4be7-bcbb-12d9bed2c9db.png
#   inflating: /content/curriculum/Dataset/thai-handwritten-dataset/0/dc8fe6a8-d899-47b4-bdd1-11277bd39510.png
#   inflating: /content/curriculum/Dataset/thai-handwritten-dataset/0/ddfe8d4f-f032-4d2f-9248-96385754c6e6.png
#   inflating: /content/curriculum/Dataset/thai-handwritten-dataset/0/df2e311c-b1c9-4b32-b80b-50296ccd6640.png
#   inflating: /content/curriculum/Dataset/thai-handwritten-dataset/0/e0efffa2-fb77-4750-9053-404ceacd1cf1.png
#   inflating: /content/curriculum/Dataset/thai-handwritten-dataset/0/e230c18a-eb9c-4027-afbd-e51c1b3a9cbb.png
#   inflating: /content/curriculum/Dataset/thai-handwritten-dataset/0/e24b88b2-99d6-4175-9db6-8be9c41c7d7a.png
#   inflating: /content/curriculum/Dataset/thai-handwritten-dataset/0/e5d2950c-be8a-4132-9911-e15fd84ea685.png
#   inflating: /content/curriculum/Dataset/thai-handwritten-dataset/0/e88da3e6-11d9-44bc-9021-3393d43b4756.png
#   inflating: /content/curriculum/Dataset/thai-handwritten-dataset/0/f667e55e-cc49-4514-a507-2d18f662db78.png
#   inflating: /content/curriculum/Dataset/thai-handwritten-dataset/0/f893756e-ed08-47e0-8ed0-4145a4fe929f.png
#   inflating: /content/curriculum/Dataset/thai-handwritten-dataset/0/f99428f4-21d4-4e7c-97c5-8d6b69b2451a.png
#   inflating: /content/curriculum/Dataset/thai-handwritten-dataset/0/fa382ab8-209c-46dd-881c-d46c605cf905.png
#   inflating: /content/curriculum/Dataset/thai-handwritten-dataset/0/fab2e093-9f46-42c5-ba21-3b01d672cbd6.png
#   inflating: /content/curriculum/Dataset/thai-handwritten-dataset/0/fb7a1f69-8fee-46dc-a14c-91eef1f46129.png
#   inflating: /content/curriculum/Dataset/thai-handwritten-dataset/0/fc1e5637-baea-4d76-b9f2-4ae801d7aad3.png
#   inflating: /content/curriculum/Dataset/thai-handwritten-dataset/0/ff2c097b-8bd3-4cf1-91be-d49196f4f5b1.png
#    creating: /content/curriculum/Dataset/thai-handwritten-dataset/1/
#   inflating: /content/curriculum/Dataset/thai-handwritten-dataset/1/0098326c-aa9e-410d-b949-e13d3cd74cfd.png
#   inflating: /content/curriculum/Dataset/thai-handwritten-dataset/1/02415aec-d4a3-4762-a1e5-bf4fe584aa66.png
#   inflating: /content/curriculum/Dataset/thai-handwritten-dataset/1/051d7c9a-2b54-4e73-9d0b-3fa75dcf1539.png
#   inflating: /content/curriculum/Dataset/thai-handwritten-dataset/1/05587e2a-e6f1-4191-8246-61e3f1cf59e9.png
#   inflating: /content/curriculum/Dataset/thai-handwritten-dataset/1/09165777-8ac1-4638-bf06-741896c7e1b9.png
#   inflating: /content/curriculum/Dataset/thai-handwritten-dataset/1/0a51150d-0afd-455e-9782-9141b68475ed.png
#   inflating: /content/curriculum/Dataset/thai-handwritten-dataset/1/0a8e39b3-4d7c-4050-a25d-746a6b8de686.png
#   inflating: /content/curriculum/Dataset/thai-handwritten-dataset/1/0b48e328-0e73-4946-8fe5-c2324cf55c88.png
#   inflating: /content/curriculum/Dataset/thai-handwritten-dataset/1/0b7155a7-4e52-4485-a675-d53397049917.png
#   inflating: /content/curriculum/Dataset/thai-handwritten-dataset/1/0f14b574-daf6-4a22-ae06-86eaeee72efa.png
#   inflating: /content/curriculum/Dataset/thai-handwritten-dataset/1/12a710d6-8774-4468-93c8-5edc8f7b8ad8.png
#   inflating: /content/curriculum/Dataset/thai-handwritten-dataset/1/136d09a5-05af-47d6-b9ca-be4c3d6b24ea.png
#   inflating: /content/curriculum/Dataset/thai-handwritten-dataset/1/14113d5b-146d-487e-a4ff-bcff10cd25d6.png
#   inflating: /content/curriculum/Dataset/thai-handwritten-dataset/1/18332707-69ff-47ca-89ea-ce468a473cb8.png
#   inflating: /content/curriculum/Dataset/thai-handwritten-dataset/1/19867988-3ae7-478f-b934-3f6c51b47fed.png
#   inflating: /content/curriculum/Dataset/thai-handwritten-dataset/1/1c09699b-4b5f-4a13-8193-a154e569abed.png
#   inflating: /content/curriculum/Dataset/thai-handwritten-dataset/1/1cb62f0c-7ba6-492e-9a67-a3a4d8af7cf8.png
#   inflating: /content/curriculum/Dataset/thai-handwritten-dataset/1/1e7a0e6c-9b02-434c-bf88-6d60958adab7.png
#   inflating: /content/curriculum/Dataset/thai-handwritten-dataset/1/1fd3d350-d79b-420e-8052-b2a04f7de87d.png
#   inflating: /content/curriculum/Dataset/thai-handwritten-dataset/1/206aed63-05a8-4105-b9b1-7cbf70557783.png
#   inflating: /content/curriculum/Dataset/thai-handwritten-dataset/1/20_2864961c-7481-43f8-b6bc-dacaec8913d3.png
#   inflating: /content/curriculum/Dataset/thai-handwritten-dataset/1/21fc8e57-6097-497e-aa62-50d16abc6321.png
#   inflating: /content/curriculum/Dataset/thai-handwritten-dataset/1/21_0b978eb2-bfd6-4587-a095-bcf1408ea829.png
#   inflating: /content/curriculum/Dataset/thai-handwritten-dataset/1/21_0cce64ca-f6e6-4b77-99ec-f06922163ab7.png
#   inflating: /content/curriculum/Dataset/thai-handwritten-dataset/1/21_333cdee9-234a-46da-83d9-8cbb12965a2d.png
#   inflating: /content/curriculum/Dataset/thai-handwritten-dataset/1/2271c5c4-4099-4f21-9bac-a8cc0af2b181.png
#   inflating: /content/curriculum/Dataset/thai-handwritten-dataset/1/22af2c46-9229-4e4a-b7c9-590c310273af.png
#   inflating: /content/curriculum/Dataset/thai-handwritten-dataset/1/22_50e3df51-981a-413a-951e-cb074d9fa3ff.png
#   inflating: /content/curriculum/Dataset/thai-handwritten-dataset/1/22_e9db2799-214e-463e-8890-2c1900ef5d9d.png
#   inflating: /content/curriculum/Dataset/thai-handwritten-dataset/1/23_6db9fc09-96ed-44a9-8052-cfad0e2e34c1.png
#   inflating: /content/curriculum/Dataset/thai-handwritten-dataset/1/24_69799b34-de22-4866-b1cd-dd76fcd8566c.png
#   inflating: /content/curriculum/Dataset/thai-handwritten-dataset/1/24_c51fbd41-94f8-42c6-8eee-52fa4c0c574b.png
#   inflating: /content/curriculum/Dataset/thai-handwritten-dataset/1/25_68b67e04-51ee-4db5-8b11-fc70965e5ed2.png
#   inflating: /content/curriculum/Dataset/thai-handwritten-dataset/1/25_88a89388-02dd-4244-9580-4e9e98eb12b4.png
#   inflating: /content/curriculum/Dataset/thai-handwritten-dataset/1/26a9523d-b782-47c0-a678-3b04aea2867e.png
#   inflating: /content/curriculum/Dataset/thai-handwritten-dataset/1/26_3ee523f0-f687-4b31-84d4-d499c8241f83.png
#   inflating: /content/curriculum/Dataset/thai-handwritten-dataset/1/26_fda94ed8-bb0a-4b87-b327-926ca1649371.png
#   inflating: /content/curriculum/Dataset/thai-handwritten-dataset/1/2703d9f2-d0d6-4547-a087-e5b97654c95e.png
#   inflating: /content/curriculum/Dataset/thai-handwritten-dataset/1/27_446dc181-636f-457b-b124-1660f26b12c4.png
#   inflating: /content/curriculum/Dataset/thai-handwritten-dataset/1/27_a2906e61-1956-469c-b882-35b6b1514871.png
#   inflating: /content/curriculum/Dataset/thai-handwritten-dataset/1/27_a4d5211f-a587-4d3d-8060-5fc86ff984bb.png
#   inflating: /content/curriculum/Dataset/thai-handwritten-dataset/1/27_f99428f4-21d4-4e7c-97c5-8d6b69b2451a.png
#   inflating: /content/curriculum/Dataset/thai-handwritten-dataset/1/288c27d7-7287-477a-91d5-580c48b24564.png
#   inflating: /content/curriculum/Dataset/thai-handwritten-dataset/1/296cc7f7-1c8f-4b34-b2df-7673eecd80ac.png
#   inflating: /content/curriculum/Dataset/thai-handwritten-dataset/1/297b1457-bf0c-4d92-847d-69e151e38f03.png
#   inflating: /content/curriculum/Dataset/thai-handwritten-dataset/1/29_056a10b8-1fff-49cd-a0ca-afcd0130825a.png
#   inflating: /content/curriculum/Dataset/thai-handwritten-dataset/1/29_32d908eb-d9a4-4c22-80f2-3b0ddd486bd8.png
#   inflating: /content/curriculum/Dataset/thai-handwritten-dataset/1/29_5a1c9814-68a2-418c-b73d-a717d58cd066.png
#   inflating: /content/curriculum/Dataset/thai-handwritten-dataset/1/29_5b3dbb03-bd57-4e38-8695-dc42d519a066.png
#   inflating: /content/curriculum/Dataset/thai-handwritten-dataset/1/29_e82b5700-f60a-4ace-b9ad-bad9b8ac6de1.png
#   inflating: /content/curriculum/Dataset/thai-handwritten-dataset/1/29_ff2c097b-8bd3-4cf1-91be-d49196f4f5b1.png
#   inflating: /content/curriculum/Dataset/thai-handwritten-dataset/1/2c35dfca-6982-4b27-8328-09f7fff2827a.png
#   inflating: /content/curriculum/Dataset/thai-handwritten-dataset/1/2e64c13a-c763-4f08-96b8-652909cb2032.png
#   inflating: /content/curriculum/Dataset/thai-handwritten-dataset/1/30_19d391bc-519e-4c2d-9389-1a3e2cc3f1ad.png
#   inflating: /content/curriculum/Dataset/thai-handwritten-dataset/1/30_5b05c5f8-c5d1-41d9-afe0-fb7205471e4a.png
#   inflating: /content/curriculum/Dataset/thai-handwritten-dataset/1/31_0a29845c-aad3-4f48-8bed-7a87b86e861d.png
#   inflating: /content/curriculum/Dataset/thai-handwritten-dataset/1/31_c052c230-4af1-45b6-9177-d7758fb2ff6b.png
#   inflating: /content/curriculum/Dataset/thai-handwritten-dataset/1/3207615b-b1f3-40eb-8777-7fce669fa242.png
#   inflating: /content/curriculum/Dataset/thai-handwritten-dataset/1/32585979-33a9-44a7-aeab-b90e8b17025c.png
#   inflating: /content/curriculum/Dataset/thai-handwritten-dataset/1/33_c8de7a32-dbbc-45d0-bfae-b43afa40074f.png
#   inflating: /content/curriculum/Dataset/thai-handwritten-dataset/1/34_5eb5bc4c-64ba-4d53-bc21-c5c8228fe580.png
#   inflating: /content/curriculum/Dataset/thai-handwritten-dataset/1/35_12be8d35-b827-4514-8b54-eeea9c48b491.png
#   inflating: /content/curriculum/Dataset/thai-handwritten-dataset/1/35_ba261ff8-1eb7-452e-944b-30c473b3a76a.png
#   inflating: /content/curriculum/Dataset/thai-handwritten-dataset/1/364b41b9-43b7-45ee-a7be-956c33f0cf7b.png
#   inflating: /content/curriculum/Dataset/thai-handwritten-dataset/1/37488f3e-6944-4a2a-99dd-43c790183c80.png
#   inflating: /content/curriculum/Dataset/thai-handwritten-dataset/1/376b5857-d33b-4eab-9491-1c346741717b.png
#   inflating: /content/curriculum/Dataset/thai-handwritten-dataset/1/37_8e0e0499-7e9c-42cc-8b1c-8d54398367fa.png
#   inflating: /content/curriculum/Dataset/thai-handwritten-dataset/1/37_a78b761e-2039-4755-b5ec-8747240f0cd4.png
#   inflating: /content/curriculum/Dataset/thai-handwritten-dataset/1/37_d6e7ce89-dc1a-47f7-96bc-45e78ca57c73.png
#   inflating: /content/curriculum/Dataset/thai-handwritten-dataset/1/37_e88da3e6-11d9-44bc-9021-3393d43b4756.png
#   inflating: /content/curriculum/Dataset/thai-handwritten-dataset/1/37_f65be60c-cf0a-4c44-b5b6-29bf9298b1fc.png
#   inflating: /content/curriculum/Dataset/thai-handwritten-dataset/1/38_647c93ed-330c-4525-bafb-d1e29b7df65f.png
#   inflating: /content/curriculum/Dataset/thai-handwritten-dataset/1/38_b453540e-12c1-423e-93e4-a1605a3181f3.png
#   inflating: /content/curriculum/Dataset/thai-handwritten-dataset/1/3d0e872f-4def-4d84-823f-9c5606f7f672.png
#   inflating: /content/curriculum/Dataset/thai-handwritten-dataset/1/40_1f250dec-c0ae-442f-90ef-f41c30dff87a.png
#   inflating: /content/curriculum/Dataset/thai-handwritten-dataset/1/40_a69be344-cfe6-4b09-af57-0b563115e212.png
#   inflating: /content/curriculum/Dataset/thai-handwritten-dataset/1/41639886-eef5-4de0-91e1-5c01a653dc05.png
#   inflating: /content/curriculum/Dataset/thai-handwritten-dataset/1/41dc9580-4104-4505-acc7-b99ad6aa4fee.png
#   inflating: /content/curriculum/Dataset/thai-handwritten-dataset/1/445a454e-435a-4e7a-bf57-63ef3917f1d8.png
#   inflating: /content/curriculum/Dataset/thai-handwritten-dataset/1/44_9f2d7454-dd40-4c4a-916e-5d310196c854.png
#   inflating: /content/curriculum/Dataset/thai-handwritten-dataset/1/44_de8f50ce-68ee-4867-9c65-8ac7e977179d.png
#   inflating: /content/curriculum/Dataset/thai-handwritten-dataset/1/4889b382-fddb-4f02-bc81-eb8d16aca1b7.png
#   inflating: /content/curriculum/Dataset/thai-handwritten-dataset/1/49a4314b-68e4-443a-85cb-6f8c30f5143a.png
#   inflating: /content/curriculum/Dataset/thai-handwritten-dataset/1/4a90e3ed-1019-4595-b525-e0b4fa702b81.png
#   inflating: /content/curriculum/Dataset/thai-handwritten-dataset/1/4c0da7b7-6dc1-412d-96b3-944f7c2b53cc.png
#   inflating: /content/curriculum/Dataset/thai-handwritten-dataset/1/4cb18a6d-d793-4d82-b03f-bfeeb760cb02.png
#   inflating: /content/curriculum/Dataset/thai-handwritten-dataset/1/4e8c9277-a1f5-47a6-87ad-2a058405f996.png
#   inflating: /content/curriculum/Dataset/thai-handwritten-dataset/1/4fb09988-bc3b-48cc-b0cf-cf74b70ef712.png
#   inflating: /content/curriculum/Dataset/thai-handwritten-dataset/1/504cd1fd-14d3-442a-b694-8da967748ba5.png
#   inflating: /content/curriculum/Dataset/thai-handwritten-dataset/1/527f32ba-3c4a-4e47-be39-056d4989b061.png
#   inflating: /content/curriculum/Dataset/thai-handwritten-dataset/1/53c9ac1f-6e18-46e8-97b2-ea5dd3b135f1.png
#   inflating: /content/curriculum/Dataset/thai-handwritten-dataset/1/5437cad2-2cc1-4a07-aa20-f019c3d6845d.png
#   inflating: /content/curriculum/Dataset/thai-handwritten-dataset/1/5489a3f6-6434-4e4c-8060-b277c202a3fd.png
#   inflating: /content/curriculum/Dataset/thai-handwritten-dataset/1/59427957-9fa6-4b28-b73a-e8b4a03455a6.png
#   inflating: /content/curriculum/Dataset/thai-handwritten-dataset/1/5bf28b06-c6e2-4243-a859-794e5e1d6849.png
#   inflating: /content/curriculum/Dataset/thai-handwritten-dataset/1/5df9143e-69fe-4f99-91de-cbec97f15039.png
#   inflating: /content/curriculum/Dataset/thai-handwritten-dataset/1/5f700dba-fecf-4a3f-b49a-2fadd8866d18.png
#   inflating: /content/curriculum/Dataset/thai-handwritten-dataset/1/6538b23f-fa6c-42d5-8f38-12c70ac2586e.png
#   inflating: /content/curriculum/Dataset/thai-handwritten-dataset/1/665f0c7b-33e4-49c5-9f88-3bf28ddee0d1.png
#   inflating: /content/curriculum/Dataset/thai-handwritten-dataset/1/6758a5f0-f4f9-4fa1-9653-3e772737294f.png
#   inflating: /content/curriculum/Dataset/thai-handwritten-dataset/1/6a008b6f-5f5e-479d-83e4-21ba2fac8ef9.png
#   inflating: /content/curriculum/Dataset/thai-handwritten-dataset/1/6afb4ca1-11e4-4b5b-8679-b600b545f211.png
#   inflating: /content/curriculum/Dataset/thai-handwritten-dataset/1/6bb3907a-19b2-49da-8438-bfd05df4f7ba.png
#   inflating: /content/curriculum/Dataset/thai-handwritten-dataset/1/6c3c2054-9114-424f-b928-39aa8619a835.png
#   inflating: /content/curriculum/Dataset/thai-handwritten-dataset/1/6ce28806-35e0-486c-b235-65bf1d5cca08.png
#   inflating: /content/curriculum/Dataset/thai-handwritten-dataset/1/6db9fc09-96ed-44a9-8052-cfad0e2e34c1.png
#   inflating: /content/curriculum/Dataset/thai-handwritten-dataset/1/6ef7bb23-bbec-40fe-8f97-4bc20284afc6.png
#   inflating: /content/curriculum/Dataset/thai-handwritten-dataset/1/71490747-c9e9-4635-965c-404735ecd783.png
#   inflating: /content/curriculum/Dataset/thai-handwritten-dataset/1/72ab9f80-3341-44b0-bf64-8dac1ba4b011.png
#   inflating: /content/curriculum/Dataset/thai-handwritten-dataset/1/736ab16a-1d9c-4dcb-bba8-16a4f7879559.png
#   inflating: /content/curriculum/Dataset/thai-handwritten-dataset/1/7405ec15-df29-4056-bcf2-056c54b908bd.png
#   inflating: /content/curriculum/Dataset/thai-handwritten-dataset/1/75c725fd-211b-450b-a386-ad72f990cbd2.png
#   inflating: /content/curriculum/Dataset/thai-handwritten-dataset/1/7873a30b-e9bc-4e2a-9c80-62ebf2a852ae.png
#   inflating: /content/curriculum/Dataset/thai-handwritten-dataset/1/7c6937a4-b351-4b43-9f6b-0eca4b1ea0b6.png
#   inflating: /content/curriculum/Dataset/thai-handwritten-dataset/1/7df9d218-313d-4ba5-91f3-81e6089e2e87.png
#   inflating: /content/curriculum/Dataset/thai-handwritten-dataset/1/7f2d7dde-86ce-442c-8c93-e477528fd9e0.png
#   inflating: /content/curriculum/Dataset/thai-handwritten-dataset/1/805cddfe-0603-4c78-b224-ce4d33d6c0b2.png
#   inflating: /content/curriculum/Dataset/thai-handwritten-dataset/1/81d3f7b2-4644-4c83-b01e-237d9563f318.png
#   inflating: /content/curriculum/Dataset/thai-handwritten-dataset/1/82065dab-4172-4369-80e3-101ea533be8f.png
#   inflating: /content/curriculum/Dataset/thai-handwritten-dataset/1/825a4276-7839-4bdd-81ae-253b978c7e4d.png
#   inflating: /content/curriculum/Dataset/thai-handwritten-dataset/1/839dcddb-e9fb-4b7a-9c68-969eee92f2a5.png
#   inflating: /content/curriculum/Dataset/thai-handwritten-dataset/1/84a8ff60-7740-41f3-a594-f4d0d4a75018.png
#   inflating: /content/curriculum/Dataset/thai-handwritten-dataset/1/85eaa4dc-3aff-4840-a2d4-179a2c047651.png
#   inflating: /content/curriculum/Dataset/thai-handwritten-dataset/1/8d79ae43-34ca-4f49-8d38-98384d57566a.png
#   inflating: /content/curriculum/Dataset/thai-handwritten-dataset/1/8e0e0499-7e9c-42cc-8b1c-8d54398367fa.png
#   inflating: /content/curriculum/Dataset/thai-handwritten-dataset/1/8e117d81-c6d6-4f34-a11a-43d3b6cd2d3d.png
#   inflating: /content/curriculum/Dataset/thai-handwritten-dataset/1/9584c39b-82ce-4834-a171-f16ae6be98e9.png
#   inflating: /content/curriculum/Dataset/thai-handwritten-dataset/1/96140adf-5a81-4d06-841d-d6db23f89ca7.png
#   inflating: /content/curriculum/Dataset/thai-handwritten-dataset/1/98f01bd2-e214-433f-a848-ecf4fc100e6d.png
#   inflating: /content/curriculum/Dataset/thai-handwritten-dataset/1/9b72c4c7-d4e6-4e28-b263-6bc305ddd003.png
#   inflating: /content/curriculum/Dataset/thai-handwritten-dataset/1/a03cc6e2-326d-4b7c-96dc-bc8eccca909a.png
#   inflating: /content/curriculum/Dataset/thai-handwritten-dataset/1/a2b6edc8-2373-4854-a66c-da5928171610.png
#   inflating: /content/curriculum/Dataset/thai-handwritten-dataset/1/a427e80c-a6a5-4c77-a064-2eba49ea0d2b.png
#   inflating: /content/curriculum/Dataset/thai-handwritten-dataset/1/a58fffa3-e1a7-4c6f-b29e-a5bd2d2f6c3d.png
#   inflating: /content/curriculum/Dataset/thai-handwritten-dataset/1/a639354a-9be9-45dd-8be2-10264f75bd4f.png
#   inflating: /content/curriculum/Dataset/thai-handwritten-dataset/1/a78b761e-2039-4755-b5ec-8747240f0cd4.png
#   inflating: /content/curriculum/Dataset/thai-handwritten-dataset/1/ae00abb4-8864-4d9f-99af-ebf9e0ef8f52.png
#   inflating: /content/curriculum/Dataset/thai-handwritten-dataset/1/ae9006e5-764b-495c-ad9b-aea5df546eb9.png
#   inflating: /content/curriculum/Dataset/thai-handwritten-dataset/1/af0d395e-f6b3-40a6-81f3-a3a77ec7996c.png
#   inflating: /content/curriculum/Dataset/thai-handwritten-dataset/1/b01291b5-f7a2-4a1e-9f75-83d5754d24c3.png
#   inflating: /content/curriculum/Dataset/thai-handwritten-dataset/1/b06349cd-3c32-45c3-896a-36ae8f58cd44.png
#   inflating: /content/curriculum/Dataset/thai-handwritten-dataset/1/b2a55151-fcac-483a-80cb-37ea0131828d.png
#   inflating: /content/curriculum/Dataset/thai-handwritten-dataset/1/b6b40844-50cc-4847-8b83-9961b3bf7b2a.png
#   inflating: /content/curriculum/Dataset/thai-handwritten-dataset/1/b870715e-8162-403f-a061-240e7f445d6d.png
#   inflating: /content/curriculum/Dataset/thai-handwritten-dataset/1/bb22aa67-b9d5-466a-9334-718ca6391b4c.png
#   inflating: /content/curriculum/Dataset/thai-handwritten-dataset/1/bb49430e-72a1-47f0-8965-667a1aaa938f.png
#   inflating: /content/curriculum/Dataset/thai-handwritten-dataset/1/bd733e16-0cd6-4746-a5da-8a459032b6af.png
#   inflating: /content/curriculum/Dataset/thai-handwritten-dataset/1/c04b59ea-0a6c-4dee-8e7c-45e3ca970c1e.png
#   inflating: /content/curriculum/Dataset/thai-handwritten-dataset/1/c17a09d4-a8b0-40be-bcd1-4666b8a00d61.png
#   inflating: /content/curriculum/Dataset/thai-handwritten-dataset/1/c2361c50-30ed-4420-b7b4-db0b4f021005.png
#   inflating: /content/curriculum/Dataset/thai-handwritten-dataset/1/c7d9e3cd-ff4f-4fe8-9525-351a3ffd6b8e.png
#   inflating: /content/curriculum/Dataset/thai-handwritten-dataset/1/ca6f8a66-1c4d-4d4d-bf3e-c03d9e5da610.png
#   inflating: /content/curriculum/Dataset/thai-handwritten-dataset/1/cccff6b3-8d74-4718-ab8e-38cbfa845ff9.png
#   inflating: /content/curriculum/Dataset/thai-handwritten-dataset/1/cdd62ceb-15e0-4c75-bbc2-83852a658959.png
#   inflating: /content/curriculum/Dataset/thai-handwritten-dataset/1/ce169337-9ad4-423b-b185-eaf502169cc1.png
#   inflating: /content/curriculum/Dataset/thai-handwritten-dataset/1/cf5ffe38-3822-44d1-8c11-e04c66fd706f.png
#   inflating: /content/curriculum/Dataset/thai-handwritten-dataset/1/d43229b0-faa7-498e-987f-02136edff8bd.png
#   inflating: /content/curriculum/Dataset/thai-handwritten-dataset/1/d86d0ca1-d4cb-48e9-aa8a-6c0ffe80f93e.png
#   inflating: /content/curriculum/Dataset/thai-handwritten-dataset/1/db5328a6-6d83-4be7-bcbb-12d9bed2c9db.png
#   inflating: /content/curriculum/Dataset/thai-handwritten-dataset/1/dc8fe6a8-d899-47b4-bdd1-11277bd39510.png
#   inflating: /content/curriculum/Dataset/thai-handwritten-dataset/1/ddfe8d4f-f032-4d2f-9248-96385754c6e6.png
#   inflating: /content/curriculum/Dataset/thai-handwritten-dataset/1/df2e311c-b1c9-4b32-b80b-50296ccd6640.png
#   inflating: /content/curriculum/Dataset/thai-handwritten-dataset/1/e0efffa2-fb77-4750-9053-404ceacd1cf1.png
#   inflating: /content/curriculum/Dataset/thai-handwritten-dataset/1/e230c18a-eb9c-4027-afbd-e51c1b3a9cbb.png
#   inflating: /content/curriculum/Dataset/thai-handwritten-dataset/1/e24b88b2-99d6-4175-9db6-8be9c41c7d7a.png
#   inflating: /content/curriculum/Dataset/thai-handwritten-dataset/1/e5d2950c-be8a-4132-9911-e15fd84ea685.png
#   inflating: /content/curriculum/Dataset/thai-handwritten-dataset/1/e88da3e6-11d9-44bc-9021-3393d43b4756.png
#   inflating: /content/curriculum/Dataset/thai-handwritten-dataset/1/f667e55e-cc49-4514-a507-2d18f662db78.png
#   inflating: /content/curriculum/Dataset/thai-handwritten-dataset/1/f893756e-ed08-47e0-8ed0-4145a4fe929f.png
#   inflating: /content/curriculum/Dataset/thai-handwritten-dataset/1/f99428f4-21d4-4e7c-97c5-8d6b69b2451a.png
#   inflating: /content/curriculum/Dataset/thai-handwritten-dataset/1/fa382ab8-209c-46dd-881c-d46c605cf905.png
#   inflating: /content/curriculum/Dataset/thai-handwritten-dataset/1/fab2e093-9f46-42c5-ba21-3b01d672cbd6.png
#   inflating: /content/curriculum/Dataset/thai-handwritten-dataset/1/fb7a1f69-8fee-46dc-a14c-91eef1f46129.png
#   inflating: /content/curriculum/Dataset/thai-handwritten-dataset/1/fc1e5637-baea-4d76-b9f2-4ae801d7aad3.png
#   inflating: /content/curriculum/Dataset/thai-handwritten-dataset/1/ff2c097b-8bd3-4cf1-91be-d49196f4f5b1.png
#    creating: /content/curriculum/Dataset/thai-handwritten-dataset/2/
#   inflating: /content/curriculum/Dataset/thai-handwritten-dataset/2/0098326c-aa9e-410d-b949-e13d3cd74cfd.png
#   inflating: /content/curriculum/Dataset/thai-handwritten-dataset/2/02415aec-d4a3-4762-a1e5-bf4fe584aa66.png
#   inflating: /content/curriculum/Dataset/thai-handwritten-dataset/2/051d7c9a-2b54-4e73-9d0b-3fa75dcf1539.png
#   inflating: /content/curriculum/Dataset/thai-handwritten-dataset/2/05587e2a-e6f1-4191-8246-61e3f1cf59e9.png
#   inflating: /content/curriculum/Dataset/thai-handwritten-dataset/2/09165777-8ac1-4638-bf06-741896c7e1b9.png
#   inflating: /content/curriculum/Dataset/thai-handwritten-dataset/2/0a51150d-0afd-455e-9782-9141b68475ed.png
#   inflating: /content/curriculum/Dataset/thai-handwritten-dataset/2/0a8e39b3-4d7c-4050-a25d-746a6b8de686.png
#   inflating: /content/curriculum/Dataset/thai-handwritten-dataset/2/0b48e328-0e73-4946-8fe5-c2324cf55c88.png
#   inflating: /content/curriculum/Dataset/thai-handwritten-dataset/2/0b7155a7-4e52-4485-a675-d53397049917.png
#   inflating: /content/curriculum/Dataset/thai-handwritten-dataset/2/0f14b574-daf6-4a22-ae06-86eaeee72efa.png
#   inflating: /content/curriculum/Dataset/thai-handwritten-dataset/2/12a710d6-8774-4468-93c8-5edc8f7b8ad8.png
#   inflating: /content/curriculum/Dataset/thai-handwritten-dataset/2/136d09a5-05af-47d6-b9ca-be4c3d6b24ea.png
#   inflating: /content/curriculum/Dataset/thai-handwritten-dataset/2/14113d5b-146d-487e-a4ff-bcff10cd25d6.png
#   inflating: /content/curriculum/Dataset/thai-handwritten-dataset/2/18332707-69ff-47ca-89ea-ce468a473cb8.png
#   inflating: /content/curriculum/Dataset/thai-handwritten-dataset/2/19867988-3ae7-478f-b934-3f6c51b47fed.png
#   inflating: /content/curriculum/Dataset/thai-handwritten-dataset/2/1c09699b-4b5f-4a13-8193-a154e569abed.png
#   inflating: /content/curriculum/Dataset/thai-handwritten-dataset/2/1cb62f0c-7ba6-492e-9a67-a3a4d8af7cf8.png
#   inflating: /content/curriculum/Dataset/thai-handwritten-dataset/2/1e7a0e6c-9b02-434c-bf88-6d60958adab7.png
#   inflating: /content/curriculum/Dataset/thai-handwritten-dataset/2/1fd3d350-d79b-420e-8052-b2a04f7de87d.png
#   inflating: /content/curriculum/Dataset/thai-handwritten-dataset/2/206aed63-05a8-4105-b9b1-7cbf70557783.png
#   inflating: /content/curriculum/Dataset/thai-handwritten-dataset/2/20_2864961c-7481-43f8-b6bc-dacaec8913d3.png
#   inflating: /content/curriculum/Dataset/thai-handwritten-dataset/2/21fc8e57-6097-497e-aa62-50d16abc6321.png
#   inflating: /content/curriculum/Dataset/thai-handwritten-dataset/2/21_0b978eb2-bfd6-4587-a095-bcf1408ea829.png
#   inflating: /content/curriculum/Dataset/thai-handwritten-dataset/2/21_0cce64ca-f6e6-4b77-99ec-f06922163ab7.png
#   inflating: /content/curriculum/Dataset/thai-handwritten-dataset/2/21_333cdee9-234a-46da-83d9-8cbb12965a2d.png
#   inflating: /content/curriculum/Dataset/thai-handwritten-dataset/2/2271c5c4-4099-4f21-9bac-a8cc0af2b181.png
#   inflating: /content/curriculum/Dataset/thai-handwritten-dataset/2/22af2c46-9229-4e4a-b7c9-590c310273af.png
#   inflating: /content/curriculum/Dataset/thai-handwritten-dataset/2/22_50e3df51-981a-413a-951e-cb074d9fa3ff.png
#   inflating: /content/curriculum/Dataset/thai-handwritten-dataset/2/22_e9db2799-214e-463e-8890-2c1900ef5d9d.png
#   inflating: /content/curriculum/Dataset/thai-handwritten-dataset/2/23_6db9fc09-96ed-44a9-8052-cfad0e2e34c1.png
#   inflating: /content/curriculum/Dataset/thai-handwritten-dataset/2/24_69799b34-de22-4866-b1cd-dd76fcd8566c.png
#   inflating: /content/curriculum/Dataset/thai-handwritten-dataset/2/24_c51fbd41-94f8-42c6-8eee-52fa4c0c574b.png
#   inflating: /content/curriculum/Dataset/thai-handwritten-dataset/2/25_68b67e04-51ee-4db5-8b11-fc70965e5ed2.png
#   inflating: /content/curriculum/Dataset/thai-handwritten-dataset/2/25_88a89388-02dd-4244-9580-4e9e98eb12b4.png
#   inflating: /content/curriculum/Dataset/thai-handwritten-dataset/2/26a9523d-b782-47c0-a678-3b04aea2867e.png
#   inflating: /content/curriculum/Dataset/thai-handwritten-dataset/2/26_3ee523f0-f687-4b31-84d4-d499c8241f83.png
#   inflating: /content/curriculum/Dataset/thai-handwritten-dataset/2/26_fda94ed8-bb0a-4b87-b327-926ca1649371.png
#   inflating: /content/curriculum/Dataset/thai-handwritten-dataset/2/2703d9f2-d0d6-4547-a087-e5b97654c95e.png
#   inflating: /content/curriculum/Dataset/thai-handwritten-dataset/2/27_446dc181-636f-457b-b124-1660f26b12c4.png
#   inflating: /content/curriculum/Dataset/thai-handwritten-dataset/2/27_a2906e61-1956-469c-b882-35b6b1514871.png
#   inflating: /content/curriculum/Dataset/thai-handwritten-dataset/2/27_a4d5211f-a587-4d3d-8060-5fc86ff984bb.png
#   inflating: /content/curriculum/Dataset/thai-handwritten-dataset/2/27_f99428f4-21d4-4e7c-97c5-8d6b69b2451a.png
#   inflating: /content/curriculum/Dataset/thai-handwritten-dataset/2/288c27d7-7287-477a-91d5-580c48b24564.png
#   inflating: /content/curriculum/Dataset/thai-handwritten-dataset/2/296cc7f7-1c8f-4b34-b2df-7673eecd80ac.png
#   inflating: /content/curriculum/Dataset/thai-handwritten-dataset/2/297b1457-bf0c-4d92-847d-69e151e38f03.png
#   inflating: /content/curriculum/Dataset/thai-handwritten-dataset/2/29_056a10b8-1fff-49cd-a0ca-afcd0130825a.png
#   inflating: /content/curriculum/Dataset/thai-handwritten-dataset/2/29_32d908eb-d9a4-4c22-80f2-3b0ddd486bd8.png
#   inflating: /content/curriculum/Dataset/thai-handwritten-dataset/2/29_5a1c9814-68a2-418c-b73d-a717d58cd066.png
#   inflating: /content/curriculum/Dataset/thai-handwritten-dataset/2/29_5b3dbb03-bd57-4e38-8695-dc42d519a066.png
#   inflating: /content/curriculum/Dataset/thai-handwritten-dataset/2/29_e82b5700-f60a-4ace-b9ad-bad9b8ac6de1.png
#   inflating: /content/curriculum/Dataset/thai-handwritten-dataset/2/29_ff2c097b-8bd3-4cf1-91be-d49196f4f5b1.png
#   inflating: /content/curriculum/Dataset/thai-handwritten-dataset/2/2c35dfca-6982-4b27-8328-09f7fff2827a.png
#   inflating: /content/curriculum/Dataset/thai-handwritten-dataset/2/2e64c13a-c763-4f08-96b8-652909cb2032.png
#   inflating: /content/curriculum/Dataset/thai-handwritten-dataset/2/30_19d391bc-519e-4c2d-9389-1a3e2cc3f1ad.png
#   inflating: /content/curriculum/Dataset/thai-handwritten-dataset/2/30_5b05c5f8-c5d1-41d9-afe0-fb7205471e4a.png
#   inflating: /content/curriculum/Dataset/thai-handwritten-dataset/2/31_0a29845c-aad3-4f48-8bed-7a87b86e861d.png
#   inflating: /content/curriculum/Dataset/thai-handwritten-dataset/2/31_c052c230-4af1-45b6-9177-d7758fb2ff6b.png
#   inflating: /content/curriculum/Dataset/thai-handwritten-dataset/2/3207615b-b1f3-40eb-8777-7fce669fa242.png
#   inflating: /content/curriculum/Dataset/thai-handwritten-dataset/2/32585979-33a9-44a7-aeab-b90e8b17025c.png
#   inflating: /content/curriculum/Dataset/thai-handwritten-dataset/2/33_c8de7a32-dbbc-45d0-bfae-b43afa40074f.png
#   inflating: /content/curriculum/Dataset/thai-handwritten-dataset/2/34_5eb5bc4c-64ba-4d53-bc21-c5c8228fe580.png
#   inflating: /content/curriculum/Dataset/thai-handwritten-dataset/2/35_12be8d35-b827-4514-8b54-eeea9c48b491.png
#   inflating: /content/curriculum/Dataset/thai-handwritten-dataset/2/35_ba261ff8-1eb7-452e-944b-30c473b3a76a.png
#   inflating: /content/curriculum/Dataset/thai-handwritten-dataset/2/364b41b9-43b7-45ee-a7be-956c33f0cf7b.png
#   inflating: /content/curriculum/Dataset/thai-handwritten-dataset/2/37488f3e-6944-4a2a-99dd-43c790183c80.png
#   inflating: /content/curriculum/Dataset/thai-handwritten-dataset/2/376b5857-d33b-4eab-9491-1c346741717b.png
#   inflating: /content/curriculum/Dataset/thai-handwritten-dataset/2/37_8e0e0499-7e9c-42cc-8b1c-8d54398367fa.png
#   inflating: /content/curriculum/Dataset/thai-handwritten-dataset/2/37_a78b761e-2039-4755-b5ec-8747240f0cd4.png
#   inflating: /content/curriculum/Dataset/thai-handwritten-dataset/2/37_d6e7ce89-dc1a-47f7-96bc-45e78ca57c73.png
#   inflating: /content/curriculum/Dataset/thai-handwritten-dataset/2/37_e88da3e6-11d9-44bc-9021-3393d43b4756.png
#   inflating: /content/curriculum/Dataset/thai-handwritten-dataset/2/37_f65be60c-cf0a-4c44-b5b6-29bf9298b1fc.png
#   inflating: /content/curriculum/Dataset/thai-handwritten-dataset/2/38_647c93ed-330c-4525-bafb-d1e29b7df65f.png
#   inflating: /content/curriculum/Dataset/thai-handwritten-dataset/2/38_b453540e-12c1-423e-93e4-a1605a3181f3.png
#   inflating: /content/curriculum/Dataset/thai-handwritten-dataset/2/3d0e872f-4def-4d84-823f-9c5606f7f672.png
#   inflating: /content/curriculum/Dataset/thai-handwritten-dataset/2/40_1f250dec-c0ae-442f-90ef-f41c30dff87a.png
#   inflating: /content/curriculum/Dataset/thai-handwritten-dataset/2/40_a69be344-cfe6-4b09-af57-0b563115e212.png
# ...
#   inflating: /content/curriculum/Dataset/thai-handwritten-dataset/9/25_88a89388-02dd-4244-9580-4e9e98eb12b4.png
#   inflating: /content/curriculum/Dataset/thai-handwritten-dataset/9/26a9523d-b782-47c0-a678-3b04aea2867e.png
#   inflating: /content/curriculum/Dataset/thai-handwritten-dataset/9/26_3ee523f0-f687-4b31-84d4-d499c8241f83.png
#   inflating: /content/curriculum/Dataset/thai-handwritten-dataset/9/26_fda94ed8-bb0a-4b87-b327-926ca1649371.png
#   inflating: /content/curriculum/Dataset/thai-handwritten-dataset/9/2703d9f2-d0d6-4547-a087-e5b97654c95e.png
#   inflating: /content/curriculum/Dataset/thai-handwritten-dataset/9/27_446dc181-636f-457b-b124-1660f26b12c4.png
#   inflating: /content/curriculum/Dataset/thai-handwritten-dataset/9/27_a2906e61-1956-469c-b882-35b6b1514871.png
#   inflating: /content/curriculum/Dataset/thai-handwritten-dataset/9/27_a4d5211f-a587-4d3d-8060-5fc86ff984bb.png
#   inflating: /content/curriculum/Dataset/thai-handwritten-dataset/9/27_f99428f4-21d4-4e7c-97c5-8d6b69b2451a.png
#   inflating: /content/curriculum/Dataset/thai-handwritten-dataset/9/288c27d7-7287-477a-91d5-580c48b24564.png
#   inflating: /content/curriculum/Dataset/thai-handwritten-dataset/9/296cc7f7-1c8f-4b34-b2df-7673eecd80ac.png
#   inflating: /content/curriculum/Dataset/thai-handwritten-dataset/9/297b1457-bf0c-4d92-847d-69e151e38f03.png
#   inflating: /content/curriculum/Dataset/thai-handwritten-dataset/9/29_056a10b8-1fff-49cd-a0ca-afcd0130825a.png
#   inflating: /content/curriculum/Dataset/thai-handwritten-dataset/9/29_32d908eb-d9a4-4c22-80f2-3b0ddd486bd8.png
#   inflating: /content/curriculum/Dataset/thai-handwritten-dataset/9/29_5a1c9814-68a2-418c-b73d-a717d58cd066.png
#   inflating: /content/curriculum/Dataset/thai-handwritten-dataset/9/29_5b3dbb03-bd57-4e38-8695-dc42d519a066.png
#   inflating: /content/curriculum/Dataset/thai-handwritten-dataset/9/29_e82b5700-f60a-4ace-b9ad-bad9b8ac6de1.png
#   inflating: /content/curriculum/Dataset/thai-handwritten-dataset/9/29_ff2c097b-8bd3-4cf1-91be-d49196f4f5b1.png
#   inflating: /content/curriculum/Dataset/thai-handwritten-dataset/9/2c35dfca-6982-4b27-8328-09f7fff2827a.png
#   inflating: /content/curriculum/Dataset/thai-handwritten-dataset/9/2e64c13a-c763-4f08-96b8-652909cb2032.png
#   inflating: /content/curriculum/Dataset/thai-handwritten-dataset/9/30_19d391bc-519e-4c2d-9389-1a3e2cc3f1ad.png
#   inflating: /content/curriculum/Dataset/thai-handwritten-dataset/9/30_5b05c5f8-c5d1-41d9-afe0-fb7205471e4a.png
#   inflating: /content/curriculum/Dataset/thai-handwritten-dataset/9/31_0a29845c-aad3-4f48-8bed-7a87b86e861d.png
#   inflating: /content/curriculum/Dataset/thai-handwritten-dataset/9/31_c052c230-4af1-45b6-9177-d7758fb2ff6b.png
#   inflating: /content/curriculum/Dataset/thai-handwritten-dataset/9/3207615b-b1f3-40eb-8777-7fce669fa242.png
#   inflating: /content/curriculum/Dataset/thai-handwritten-dataset/9/32585979-33a9-44a7-aeab-b90e8b17025c.png
#   inflating: /content/curriculum/Dataset/thai-handwritten-dataset/9/33_c8de7a32-dbbc-45d0-bfae-b43afa40074f.png
#   inflating: /content/curriculum/Dataset/thai-handwritten-dataset/9/34_5eb5bc4c-64ba-4d53-bc21-c5c8228fe580.png
#   inflating: /content/curriculum/Dataset/thai-handwritten-dataset/9/35_12be8d35-b827-4514-8b54-eeea9c48b491.png
#   inflating: /content/curriculum/Dataset/thai-handwritten-dataset/9/35_ba261ff8-1eb7-452e-944b-30c473b3a76a.png
#   inflating: /content/curriculum/Dataset/thai-handwritten-dataset/9/364b41b9-43b7-45ee-a7be-956c33f0cf7b.png
#   inflating: /content/curriculum/Dataset/thai-handwritten-dataset/9/37488f3e-6944-4a2a-99dd-43c790183c80.png
#   inflating: /content/curriculum/Dataset/thai-handwritten-dataset/9/376b5857-d33b-4eab-9491-1c346741717b.png
#   inflating: /content/curriculum/Dataset/thai-handwritten-dataset/9/37_8e0e0499-7e9c-42cc-8b1c-8d54398367fa.png
#   inflating: /content/curriculum/Dataset/thai-handwritten-dataset/9/37_a78b761e-2039-4755-b5ec-8747240f0cd4.png
#   inflating: /content/curriculum/Dataset/thai-handwritten-dataset/9/37_d6e7ce89-dc1a-47f7-96bc-45e78ca57c73.png
#   inflating: /content/curriculum/Dataset/thai-handwritten-dataset/9/37_e88da3e6-11d9-44bc-9021-3393d43b4756.png
#   inflating: /content/curriculum/Dataset/thai-handwritten-dataset/9/37_f65be60c-cf0a-4c44-b5b6-29bf9298b1fc.png
#   inflating: /content/curriculum/Dataset/thai-handwritten-dataset/9/38_647c93ed-330c-4525-bafb-d1e29b7df65f.png
#   inflating: /content/curriculum/Dataset/thai-handwritten-dataset/9/38_b453540e-12c1-423e-93e4-a1605a3181f3.png
#   inflating: /content/curriculum/Dataset/thai-handwritten-dataset/9/3d0e872f-4def-4d84-823f-9c5606f7f672.png
#   inflating: /content/curriculum/Dataset/thai-handwritten-dataset/9/40_1f250dec-c0ae-442f-90ef-f41c30dff87a.png
#   inflating: /content/curriculum/Dataset/thai-handwritten-dataset/9/40_a69be344-cfe6-4b09-af57-0b563115e212.png
#   inflating: /content/curriculum/Dataset/thai-handwritten-dataset/9/41639886-eef5-4de0-91e1-5c01a653dc05.png
#   inflating: /content/curriculum/Dataset/thai-handwritten-dataset/9/41dc9580-4104-4505-acc7-b99ad6aa4fee.png
#   inflating: /content/curriculum/Dataset/thai-handwritten-dataset/9/445a454e-435a-4e7a-bf57-63ef3917f1d8.png
#   inflating: /content/curriculum/Dataset/thai-handwritten-dataset/9/44_9f2d7454-dd40-4c4a-916e-5d310196c854.png
#   inflating: /content/curriculum/Dataset/thai-handwritten-dataset/9/44_de8f50ce-68ee-4867-9c65-8ac7e977179d.png
#   inflating: /content/curriculum/Dataset/thai-handwritten-dataset/9/4889b382-fddb-4f02-bc81-eb8d16aca1b7.png
#   inflating: /content/curriculum/Dataset/thai-handwritten-dataset/9/49a4314b-68e4-443a-85cb-6f8c30f5143a.png
#   inflating: /content/curriculum/Dataset/thai-handwritten-dataset/9/4a90e3ed-1019-4595-b525-e0b4fa702b81.png
#   inflating: /content/curriculum/Dataset/thai-handwritten-dataset/9/4c0da7b7-6dc1-412d-96b3-944f7c2b53cc.png
#   inflating: /content/curriculum/Dataset/thai-handwritten-dataset/9/4cb18a6d-d793-4d82-b03f-bfeeb760cb02.png
#   inflating: /content/curriculum/Dataset/thai-handwritten-dataset/9/4e8c9277-a1f5-47a6-87ad-2a058405f996.png
#   inflating: /content/curriculum/Dataset/thai-handwritten-dataset/9/4fb09988-bc3b-48cc-b0cf-cf74b70ef712.png
#   inflating: /content/curriculum/Dataset/thai-handwritten-dataset/9/504cd1fd-14d3-442a-b694-8da967748ba5.png
#   inflating: /content/curriculum/Dataset/thai-handwritten-dataset/9/527f32ba-3c4a-4e47-be39-056d4989b061.png
#   inflating: /content/curriculum/Dataset/thai-handwritten-dataset/9/53c9ac1f-6e18-46e8-97b2-ea5dd3b135f1.png
#   inflating: /content/curriculum/Dataset/thai-handwritten-dataset/9/5437cad2-2cc1-4a07-aa20-f019c3d6845d.png
#   inflating: /content/curriculum/Dataset/thai-handwritten-dataset/9/5489a3f6-6434-4e4c-8060-b277c202a3fd.png
#   inflating: /content/curriculum/Dataset/thai-handwritten-dataset/9/59427957-9fa6-4b28-b73a-e8b4a03455a6.png
#   inflating: /content/curriculum/Dataset/thai-handwritten-dataset/9/5bf28b06-c6e2-4243-a859-794e5e1d6849.png
#   inflating: /content/curriculum/Dataset/thai-handwritten-dataset/9/5df9143e-69fe-4f99-91de-cbec97f15039.png
#   inflating: /content/curriculum/Dataset/thai-handwritten-dataset/9/5f700dba-fecf-4a3f-b49a-2fadd8866d18.png
#   inflating: /content/curriculum/Dataset/thai-handwritten-dataset/9/6538b23f-fa6c-42d5-8f38-12c70ac2586e.png
#   inflating: /content/curriculum/Dataset/thai-handwritten-dataset/9/665f0c7b-33e4-49c5-9f88-3bf28ddee0d1.png
#   inflating: /content/curriculum/Dataset/thai-handwritten-dataset/9/6758a5f0-f4f9-4fa1-9653-3e772737294f.png
#   inflating: /content/curriculum/Dataset/thai-handwritten-dataset/9/6a008b6f-5f5e-479d-83e4-21ba2fac8ef9.png
#   inflating: /content/curriculum/Dataset/thai-handwritten-dataset/9/6afb4ca1-11e4-4b5b-8679-b600b545f211.png
#   inflating: /content/curriculum/Dataset/thai-handwritten-dataset/9/6bb3907a-19b2-49da-8438-bfd05df4f7ba.png
#   inflating: /content/curriculum/Dataset/thai-handwritten-dataset/9/6c3c2054-9114-424f-b928-39aa8619a835.png
#   inflating: /content/curriculum/Dataset/thai-handwritten-dataset/9/6ce28806-35e0-486c-b235-65bf1d5cca08.png
#   inflating: /content/curriculum/Dataset/thai-handwritten-dataset/9/6db9fc09-96ed-44a9-8052-cfad0e2e34c1.png
#   inflating: /content/curriculum/Dataset/thai-handwritten-dataset/9/6ef7bb23-bbec-40fe-8f97-4bc20284afc6.png
#   inflating: /content/curriculum/Dataset/thai-handwritten-dataset/9/71490747-c9e9-4635-965c-404735ecd783.png
#   inflating: /content/curriculum/Dataset/thai-handwritten-dataset/9/72ab9f80-3341-44b0-bf64-8dac1ba4b011.png
#   inflating: /content/curriculum/Dataset/thai-handwritten-dataset/9/736ab16a-1d9c-4dcb-bba8-16a4f7879559.png
#   inflating: /content/curriculum/Dataset/thai-handwritten-dataset/9/7405ec15-df29-4056-bcf2-056c54b908bd.png
#   inflating: /content/curriculum/Dataset/thai-handwritten-dataset/9/75c725fd-211b-450b-a386-ad72f990cbd2.png
#   inflating: /content/curriculum/Dataset/thai-handwritten-dataset/9/7873a30b-e9bc-4e2a-9c80-62ebf2a852ae.png
#   inflating: /content/curriculum/Dataset/thai-handwritten-dataset/9/7c6937a4-b351-4b43-9f6b-0eca4b1ea0b6.png
#   inflating: /content/curriculum/Dataset/thai-handwritten-dataset/9/7df9d218-313d-4ba5-91f3-81e6089e2e87.png
#   inflating: /content/curriculum/Dataset/thai-handwritten-dataset/9/7f2d7dde-86ce-442c-8c93-e477528fd9e0.png
#   inflating: /content/curriculum/Dataset/thai-handwritten-dataset/9/805cddfe-0603-4c78-b224-ce4d33d6c0b2.png
#   inflating: /content/curriculum/Dataset/thai-handwritten-dataset/9/81d3f7b2-4644-4c83-b01e-237d9563f318.png
#   inflating: /content/curriculum/Dataset/thai-handwritten-dataset/9/82065dab-4172-4369-80e3-101ea533be8f.png
#   inflating: /content/curriculum/Dataset/thai-handwritten-dataset/9/825a4276-7839-4bdd-81ae-253b978c7e4d.png
#   inflating: /content/curriculum/Dataset/thai-handwritten-dataset/9/839dcddb-e9fb-4b7a-9c68-969eee92f2a5.png
#   inflating: /content/curriculum/Dataset/thai-handwritten-dataset/9/84a8ff60-7740-41f3-a594-f4d0d4a75018.png
#   inflating: /content/curriculum/Dataset/thai-handwritten-dataset/9/85eaa4dc-3aff-4840-a2d4-179a2c047651.png
#   inflating: /content/curriculum/Dataset/thai-handwritten-dataset/9/8d79ae43-34ca-4f49-8d38-98384d57566a.png
#   inflating: /content/curriculum/Dataset/thai-handwritten-dataset/9/8e0e0499-7e9c-42cc-8b1c-8d54398367fa.png
#   inflating: /content/curriculum/Dataset/thai-handwritten-dataset/9/8e117d81-c6d6-4f34-a11a-43d3b6cd2d3d.png
#   inflating: /content/curriculum/Dataset/thai-handwritten-dataset/9/9584c39b-82ce-4834-a171-f16ae6be98e9.png
#   inflating: /content/curriculum/Dataset/thai-handwritten-dataset/9/96140adf-5a81-4d06-841d-d6db23f89ca7.png
#   inflating: /content/curriculum/Dataset/thai-handwritten-dataset/9/98f01bd2-e214-433f-a848-ecf4fc100e6d.png
#   inflating: /content/curriculum/Dataset/thai-handwritten-dataset/9/9b72c4c7-d4e6-4e28-b263-6bc305ddd003.png
#   inflating: /content/curriculum/Dataset/thai-handwritten-dataset/9/a03cc6e2-326d-4b7c-96dc-bc8eccca909a.png
#   inflating: /content/curriculum/Dataset/thai-handwritten-dataset/9/a2b6edc8-2373-4854-a66c-da5928171610.png
#   inflating: /content/curriculum/Dataset/thai-handwritten-dataset/9/a427e80c-a6a5-4c77-a064-2eba49ea0d2b.png
#   inflating: /content/curriculum/Dataset/thai-handwritten-dataset/9/a58fffa3-e1a7-4c6f-b29e-a5bd2d2f6c3d.png
#   inflating: /content/curriculum/Dataset/thai-handwritten-dataset/9/a639354a-9be9-45dd-8be2-10264f75bd4f.png
#   inflating: /content/curriculum/Dataset/thai-handwritten-dataset/9/a78b761e-2039-4755-b5ec-8747240f0cd4.png
#   inflating: /content/curriculum/Dataset/thai-handwritten-dataset/9/ae00abb4-8864-4d9f-99af-ebf9e0ef8f52.png
#   inflating: /content/curriculum/Dataset/thai-handwritten-dataset/9/ae9006e5-764b-495c-ad9b-aea5df546eb9.png
#   inflating: /content/curriculum/Dataset/thai-handwritten-dataset/9/af0d395e-f6b3-40a6-81f3-a3a77ec7996c.png
#   inflating: /content/curriculum/Dataset/thai-handwritten-dataset/9/b01291b5-f7a2-4a1e-9f75-83d5754d24c3.png
#   inflating: /content/curriculum/Dataset/thai-handwritten-dataset/9/b06349cd-3c32-45c3-896a-36ae8f58cd44.png
#   inflating: /content/curriculum/Dataset/thai-handwritten-dataset/9/b2a55151-fcac-483a-80cb-37ea0131828d.png
#   inflating: /content/curriculum/Dataset/thai-handwritten-dataset/9/b6b40844-50cc-4847-8b83-9961b3bf7b2a.png
#   inflating: /content/curriculum/Dataset/thai-handwritten-dataset/9/b870715e-8162-403f-a061-240e7f445d6d.png
#   inflating: /content/curriculum/Dataset/thai-handwritten-dataset/9/bb22aa67-b9d5-466a-9334-718ca6391b4c.png
#   inflating: /content/curriculum/Dataset/thai-handwritten-dataset/9/bb49430e-72a1-47f0-8965-667a1aaa938f.png
#   inflating: /content/curriculum/Dataset/thai-handwritten-dataset/9/bd733e16-0cd6-4746-a5da-8a459032b6af.png
#   inflating: /content/curriculum/Dataset/thai-handwritten-dataset/9/c04b59ea-0a6c-4dee-8e7c-45e3ca970c1e.png
#   inflating: /content/curriculum/Dataset/thai-handwritten-dataset/9/c17a09d4-a8b0-40be-bcd1-4666b8a00d61.png
#   inflating: /content/curriculum/Dataset/thai-handwritten-dataset/9/c2361c50-30ed-4420-b7b4-db0b4f021005.png
#   inflating: /content/curriculum/Dataset/thai-handwritten-dataset/9/c7d9e3cd-ff4f-4fe8-9525-351a3ffd6b8e.png
#   inflating: /content/curriculum/Dataset/thai-handwritten-dataset/9/ca6f8a66-1c4d-4d4d-bf3e-c03d9e5da610.png
#   inflating: /content/curriculum/Dataset/thai-handwritten-dataset/9/cccff6b3-8d74-4718-ab8e-38cbfa845ff9.png
#   inflating: /content/curriculum/Dataset/thai-handwritten-dataset/9/cdd62ceb-15e0-4c75-bbc2-83852a658959.png
#   inflating: /content/curriculum/Dataset/thai-handwritten-dataset/9/ce169337-9ad4-423b-b185-eaf502169cc1.png
#   inflating: /content/curriculum/Dataset/thai-handwritten-dataset/9/cf5ffe38-3822-44d1-8c11-e04c66fd706f.png
#   inflating: /content/curriculum/Dataset/thai-handwritten-dataset/9/d43229b0-faa7-498e-987f-02136edff8bd.png
#   inflating: /content/curriculum/Dataset/thai-handwritten-dataset/9/d86d0ca1-d4cb-48e9-aa8a-6c0ffe80f93e.png
#   inflating: /content/curriculum/Dataset/thai-handwritten-dataset/9/db5328a6-6d83-4be7-bcbb-12d9bed2c9db.png
#   inflating: /content/curriculum/Dataset/thai-handwritten-dataset/9/dc8fe6a8-d899-47b4-bdd1-11277bd39510.png
#   inflating: /content/curriculum/Dataset/thai-handwritten-dataset/9/ddfe8d4f-f032-4d2f-9248-96385754c6e6.png
#   inflating: /content/curriculum/Dataset/thai-handwritten-dataset/9/df2e311c-b1c9-4b32-b80b-50296ccd6640.png
#   inflating: /content/curriculum/Dataset/thai-handwritten-dataset/9/e0efffa2-fb77-4750-9053-404ceacd1cf1.png
#   inflating: /content/curriculum/Dataset/thai-handwritten-dataset/9/e230c18a-eb9c-4027-afbd-e51c1b3a9cbb.png
#   inflating: /content/curriculum/Dataset/thai-handwritten-dataset/9/e24b88b2-99d6-4175-9db6-8be9c41c7d7a.png
#   inflating: /content/curriculum/Dataset/thai-handwritten-dataset/9/e5d2950c-be8a-4132-9911-e15fd84ea685.png
#   inflating: /content/curriculum/Dataset/thai-handwritten-dataset/9/e88da3e6-11d9-44bc-9021-3393d43b4756.png
#   inflating: /content/curriculum/Dataset/thai-handwritten-dataset/9/f667e55e-cc49-4514-a507-2d18f662db78.png
#   inflating: /content/curriculum/Dataset/thai-handwritten-dataset/9/f893756e-ed08-47e0-8ed0-4145a4fe929f.png
#   inflating: /content/curriculum/Dataset/thai-handwritten-dataset/9/f99428f4-21d4-4e7c-97c5-8d6b69b2451a.png
#   inflating: /content/curriculum/Dataset/thai-handwritten-dataset/9/fa382ab8-209c-46dd-881c-d46c605cf905.png
#   inflating: /content/curriculum/Dataset/thai-handwritten-dataset/9/fab2e093-9f46-42c5-ba21-3b01d672cbd6.png
#   inflating: /content/curriculum/Dataset/thai-handwritten-dataset/9/fb7a1f69-8fee-46dc-a14c-91eef1f46129.png
#   inflating: /content/curriculum/Dataset/thai-handwritten-dataset/9/fc1e5637-baea-4d76-b9f2-4ae801d7aad3.png
#   inflating: /content/curriculum/Dataset/thai-handwritten-dataset/9/ff2c097b-8bd3-4cf1-91be-d49196f4f5b1.png
#   inflating: /content/curriculum/Dataset/thai-handwritten-dataset/README.md

# %% [markdown]
# หลังจากที่นำไฟล์เข้ามาแล้ว เมื่อคลิกที่เครื่องหมาย Files ที่ด้านซ้ายของ google colab จะพบว่ามีไฟล์ปรากฏขึ้นมา และ หากคลิกเข้าไปในกล่องเลข 1 จะพบว่ามีไฟล์จำนวนมาก
#
# <div>
# <br>
# <img src="https://github.com/khthana/AI_resource/blob/main/number_folder.JPG?raw=true" width="300"/><div>
# <br>

# %% [markdown]
# ## การโหลดข้อมูล
#
# ### Library สำหรับจัดการไฟล์
#
# ก่อนอื่นต้องขออธิบายการใช้งาน Library สำหรับจัดการไฟล์ก่อน เพราะใช้อยู่หลายตัวเหมือนกัน

# %% [markdown]
# #### Library os
#
# os เป็น Library ครอบจักรวาล คือ ใช้สำหรับให้ python สามารถใช้บริการของระบบปฏิบัติการได้ สำหรับโปรแกรมของเราจะใช้เฉพาะ Module ย่อยของ os คือใช้เฉพาะที่เกี่ยวกับ path จะใช้ในการสร้าง path ก็คือเอา string ที่เป็นลำดับของ folder มาต่อกันแล้วใส่เครื่องหมาย "/" คั่น

# %%
import os

directory = "curriculum/Dataset"
path = os.path.join(directory, "thai-handwritten-dataset", "*", "*")
print(path)
# Out:
# curriculum/Dataset/thai-handwritten-dataset/*/*

# %% [markdown]
# #### Library "glob"
#
# glob เป็น library สำหรับค้นหาชื่อไฟล์ โดยมีความสามารถในการค้นหาชื่อไฟล์ที่เก่งมาก เนื่องจากสามารถใช้ เครื่องหมาย * (หมายถึงทุกตัวอักษรทุกความยาว) และ ? หมายถึง ทุกตัวอักษรยาว 1 ตัว ในการค้นหาชื่อไฟล์ได้
#
# จากโปรแกรมข้างล่างนี้จะเห็นว่า glob จะทำหน้าที่ค้นหาไฟล์ที่อยู่ใน folder thai-handwritten-dataset ในทุกไฟล์หรือโฟลเดอร์ และค้นหาไฟล์หรือโฟลเดอร์ในชั้นย่อยลงไปอีกชั้น โดยข้อมูลที่ค้นหาได้จะเก็บใน List ซึ่งจะเห็นว่ามีไฟล์ทั้งหมด 1750 ไฟล์
#
# ```
# การทำงานเทียบเท่า dir thai-handwritten-dataset\*\* /s
# ```

# %%
import os
from glob import glob

directory = "curriculum/Dataset/"
path = os.path.join(directory, "thai-handwritten-dataset", "*", "*")
all_file = glob(path)
print(len(all_file))
all_file[:3]
# Out:
# 1750
# ['curriculum/Dataset/thai-handwritten-dataset/2/25_68b67e04-51ee-4db5-8b11-fc70965e5ed2.png',
#  'curriculum/Dataset/thai-handwritten-dataset/2/364b41b9-43b7-45ee-a7be-956c33f0cf7b.png',
#  'curriculum/Dataset/thai-handwritten-dataset/2/4889b382-fddb-4f02-bc81-eb8d16aca1b7.png']

# %% [markdown]
# #### Library PIL
#
# PIL ย่อมาจาก Python Imaging Library ทำหน้าที่ในการจัดการกับข้อมูลประเภท Image บางทีก็เรียกว่า PILLOW สามารถการปรับแต่งพิกเซล, การกรองภาพ, การปรับปรุงภาพ, เพิ่มข้อความในรูปภาพ, ฟังก์ชันการประมวลผลภาพพื้นฐาน
#
# ดังนั้นจึงสามารถนำภาพที่อยู่ในไฟล์มาแสดงได้

# %%
import os
from glob import glob
from PIL import Image

directory = "curriculum/Dataset/"
path = os.path.join(directory, "thai-handwritten-dataset", "*", "*")
all_file = glob(path)

idx = 100
image = Image.open(all_file[idx])
print(image.size)
image
# Out:
# (300, 300)
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=300x300>

# %% [markdown]
# ## การแบ่งข้อมูลใน Dataset เป็น Training Set และ Test Set
#
# เมื่อเรามีข้อมูลเรียบร้อยแล้ว ก่อนที่เราจะนำข้อมูลเข้าสู่ Model เราจะต้องแบ่งข้อมูลออกเป็น 2 หรือ 3 ส่วนเสียก่อน ให้ลองนึกภาพว่าคุณเป็นนักแข่งจักรยานผาดโผน และคุณมีสนามสำหรับฝึกซ้อมอยู่ 1 สนาม คุณก็ฝึกหัดกับสนามของคุณจนคล่องแคล่ว คำถามมีอยู่ว่า คุณจะพร้อมสำหรับการแข่งขันหรือไม่ คำตอบที่ควรจะเป็น คือ ยังไม่พร้อม เพราะมีประสบการณ์กับสนามของตัวเองเท่านั้น ยังไม่เคยไปขี่ในสนามอื่นเลย เราเก่งในสนามของตัวเอง ส่วนหนึ่งอาจเป็นเพราะทักษะการขี่ แต่ส่วนหนึ่งเป็นเพราะเราจำได้ว่าสนามเป็นแบบไหน พอถึงจุดไหนต้องทำอย่างไร แต่เมื่อไปเจอสนามที่ไม่เคยขี่มาก่อน เราจะเหลือแค่ทักษะการขี่เท่านั้น พูดง่ายๆ คือ ขาดความหลากหลายของประสบการณ์
# <br>
#
# การฝึกสอน Model ก็เช่นเดียวกัน ถ้าเราเอาข้อมูลไปสอนก่อน จากนั้นเอาข้อมูลชุดเดิมไปทดสอบ Model ก็จะเก่งตามข้อมูลที่สอนและจำข้อมูลที่สอนได้ ในที่สุดก็อาจจะทำได้ดีมาก ถ้าเป็นข้อสอบก็อาจจะบอกว่าตอบถูกหมด แต่เมื่อไปเจอข้อมูลที่ไม่คุ้นเคย คราวนี้ก็จะทำได้ไม่ดี เราคงไม่ต้องการ Model ที่เป็นประเภท สิงห์สนามซ้อม แต่อ่อนสนามจริง ใช่มั้ย
# <br>
#
# ดังนั้นเมื่อจะ Train หรือฝึกสอน Model ก็จะมีการแบ่งข้อมูลออกเป็น 2 หรือ 3 ส่วน ประกอบด้วย
# - ข้อมูลสำหรับฝึกสอน (Training Set) ถ้าเปรียบเทียบกับการเรียนก็คือ งานที่ให้ในห้องเรียนหรือการบ้าน ข้อมูลส่วนนี้จะมีจำนวนมากที่สุด เพื่อฝึกให้มีความชำนาญหรือเก่ง โดยทั่วไปจะประมาณ 60-80% ของข้อมูล dataset ทั้งหมด
# - ข้อมูลสำหรับตรวจสอบความถูกต้อง (Validation Set) ถ้าเปรียบเทียบกับการเรียนก็คือ การ Quiz คือการทดสอบว่า Model เก่งแค่ไหนในขณะที่ทำการฝึกสอน ควรจะหยุดการฝึกสอนหรือยัง หรือ เปลี่ยนแปลงค่าการฝึกสอน โดยทั่วไปจะแบ่งข้อมูลประเภทนี้ไว้ระหว่าง 10-20% โดยข้อมูลนี้จะถูกนำมาทดสอบหลังจากการฝึกสอนในแต่ละ epoch
# - ข้อมูลสำหรับทดสอบจริง (Testing Set) ถ้าเปรียบเทียบกับการเรียน ก็คือ การสอบ Midterm หรือ Final Exam โดยการสอบนี้จะเป็นการทดสอบจริงว่าเมื่อนำ Model ไปใช้กับข้อมูลที่มันไม่เคยเห็นมาก่อน จะทำงานได้ดีหรือไม่ โดยทั่วไปจะแบ่งข้อมูลประเภทนี้ไว้ระหว่าง 10-20%
#
# ในการทำงาน อย่างน้อยจะต้องมี Training Set และ Testing Set เสมอจะขาดไม่ได้เลย แต่สำหรับ Validation Set ก็ขึ้นกับผู้พัฒนา Model ว่าจะใช้หรือไม่
#
# อาจมีข้อสงสัยว่า Validation Set กับ Testing Set ต่างกันอย่างไร ก็ขอตอบว่าทั้ง 2 ข้อมูลใช้ในการทดสอบเหมือนกัน แต่ Testing Set จะไม่นำข้อมูลไปใช้ในระหว่างขั้นตอนการ Train เลย พูดง่ายๆ คือ ต้องเป็นข้อมูลที่ไม่เคยเห็นมาก่อน (เหมือนสอบ Final) และจะทดสอบเพียงครั้งเดียว แต่ Validation Set จะนำมาทดสอบในทุกครั้งของรอบการฝึกสอน (Epoch) โดยไม่นำข้อมูลใน Validation Set ไปฝึกสอนด้วย แต่จะใช้ทดสอบว่าเรียนรู้ได้ดีหรือยัง ถ้าเรียนรู้ได้ดีผลงานใน Validation Set ก็จะดีไปด้วย
#
# เรื่องของข้อมูลทั้ง 3 ประเภทนี้ จะเห็นภาพชัดเจนขึ้นเมื่อเราเห็นภาพของการฝึกสอน
#
#
#
# | Split | Purpose | Amount of total data | How often is it used? |
# | ----- | ----- | ----- | ----- |
# | **Training set** | The model learns from this data (like the course materials you study during the semester). | ~60-80% | Always |
# | **Validation set** | The model gets tuned on this data (like the practice exam you take before the final exam). | ~10-20% | Often but not always |
# | **Testing set** | The model gets evaluated on this data to test what it has learned (like the final exam you take at the end of the semester). | ~10-20% | Always |

# %% [markdown]
# ### ขั้นตอนการแบ่งข้อมูล
#
# ในส่วนนี้จะมี Library ที่เรียกใช้เพิ่มอีกหลายตัว
# - Pathlib จะมาช่วยในการจัดการไฟล์
# - tqdm ใช้ในการแสดงความก้าวหน้าในการ copy ไฟล์ เพื่อไม่ให้ดูเงียบๆ
# - shutil ใช้ในการ copy ไฟล์
#
# การแบ่งข้อมูลสำหรับโปรแกรมนี้ จะแบ่งออกเป็น 2 ส่วน คือ traning data กับ test data เท่านั้น

# %%
from pathlib import Path
from tqdm.auto import tqdm
from sklearn.model_selection import train_test_split
import shutil

train_paths, test_paths = train_test_split(all_file, test_size=0.1, random_state=42)

for i in range(10):
    os.makedirs(f"data/train/{i}", exist_ok=True)
    os.makedirs(f"data/test/{i}", exist_ok=True)

def copy_to_destination(src_paths, dst_path: str = "data/train/"):
    for path in tqdm(src_paths):
        path = Path(path)
        if path.parent.name == "10":
            parent_dir = "0"
        else:
            parent_dir = path.parent.name
        shutil.copy(path, os.path.join(dst_path, parent_dir, path.name))

copy_to_destination(train_paths, "data/train/")
copy_to_destination(test_paths, "data/test/")
# Out:
#   0%|          | 0/1575 [00:00<?, ?it/s]
#   0%|          | 0/175 [00:00<?, ?it/s]

# %% [markdown]
# ### ลดขนาดข้อมูล
#
# เอาละ! มาถึงตรงนี้ เราก็มีข้อมูลพร้อมแล้ว โดยแบ่งเป็น training data จำนวน 1575 ข้อมูล และ test data จำนวน 175 ข้อมูล
#
# แต่ถ้ายังจำได้จะเห็นว่ารูปต้นฉบับมีขนาด 300x300 ซึ่งรูปที่มีขนาดใหญ่ จะทำให้การประมวลผลข้อมูลนาน ดังนั้นในกรณีนี้ เราควรจะลดขนาดภาพลง เพื่อให้การประมวลผลเร็วขึ้น แต่การลดขนาดภาพก็มีความเสี่ยงอยู่บ้างที่จะทำให้ผลลัพธ์แย่ลง
#
# ในการทำงานของ Nueral Network ให้เทียบกับการเรียนรู้ของมนุษย์ หากภาพมีข้อมูลมาก การมีภาพที่มีรายละเอียด (ขนาดใหญ่) ก็ทำให้มนุษย์ทำงานได้ดีขึ้น แต่ในบางกรณี เช่น กรณีนี้เราต้องการบอกว่าภาพเป็นภาพของเลขอะไรเท่านั้น ดังนั้นแม้จะลดความละเอียดลงไปบ้าง เราก็อาจจะแยกแยะได้อยู่ดี
#
# ดังนั้นในกรณีนี้ ถือว่ามีความคุ้มค่าในการลดขนาดภาพ เพราะประสิทธิภาพการทำงานไม่ลดลงมากนัก แต่ความเร็วลดลงได้มาก
#
# ในการลดขนาดข้อมูลกรณีนี้จะลดเหลือแค่ 28x28 เท่านั้น โดยค่า 28x28 เป็นค่าที่ได้จากการทดลองในอดีตที่พบว่ารูปขนาดเล็กที่ 28x28 ให้ผลดีมากกว่า 24x24 หรือ 30x30
#
# ในการลดขนาดข้อมูล เราจะใช้ library อีกตัวหนึ่งซึ่งผู้พัฒนา PyTorch ได้พัฒนาไว้ โดยมีชื่อว่า TorchVision ซึ่งทำหน้าที่เกี่ยวกับการประมวลผลภาพ โดยใน TorchVision จะมี Module หนึ่งชื่อว่า transform ซึ่งทำหน้าที่แปลงภาพ โดยการแปลงนี้จะมี 3 ขั้นตอน คือ
# - แปลงจาก 300x300 เป็น 28x28
# - เปลี่ยนเป็นภาพ Grayscale
# - เปลี่ยนเป็น Tensors ของ Torch และเปลี่ยนจาก 0-255 เป็น 0-1
#
# จากภาพที่แสดง จะเห็นได้ชัดเจนว่าภาพมีรายละเอียดลดลงอย่างชัดเจน แต่ก็ยังเห็นว่าเป็นเลข 1

# %%
import torch
from torchvision import transforms
import matplotlib.pyplot as plt

transform = transforms.Compose([
    transforms.Resize((28, 28)),
    transforms.Grayscale(),
    transforms.ToTensor()
])

# %%
im = Image.open(all_file[100])
im = (1 - transform(im)).squeeze(0)
print(im[10])
plt.title("Number: {}".format(Path(all_file[100]).parent.name))
plt.imshow(im, cmap="gray")
plt.show()
# Out:
# tensor([0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.5333, 0.8588,
#         0.1216, 0.4039, 0.8588, 0.9333, 0.9333, 0.6471, 0.2196, 0.6863, 0.8784,
#         0.8353, 0.4275, 0.0157, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#         0.0000])

# %% [markdown]
# ในบรรทัด im = (1 - transform(im)).squeeze(0) มีการทำงาน 2 อย่าง คือ
# - squeeze ซึ่งทำหน้าที่ลดมิติของ im ให้เหลือเพียงมิติเดียว
# - 1 - transform(im) ทำหน้าที่กลับสีระหว่างดำกับขาว เพื่อให้ประมวลผลได้ง่ายขึ้น

# %% [markdown]
# ### สร้าง class ของข้อมูล
#
# เวลานี้เรามีข้อมูลที่แบ่งออกเป็น Training Data และ Test Data แล้วแต่ข้อมูลที่เป็นไฟล์จะยุ่งยากต่อการจัดการ ดังนั้นหลักนิยมเขามักจะสร้าง "ตัวครอบ" ขึ้นมาอีกชั้น โดยมอง ตัวครอบ ที่ว่าเป็นแหล่งข้อมูล Data Source โดยไม่สนใจว่าข้อมูลนั้นจะเก็บไว้ที่ใด ซึ่ง PyTorch ก็ได้เตรียม Library เอาไว้ สำหรับใช้ในงานนี้ โดยอยู่ในโมดูล Dataset
# - ใน `__init__` จะเป็นการกำหนดข้อมูลเบื้องต้นของคลาส ได้แก่ directory หรือ folder ของไฟล์รูปภาพ และ การ transform (ถ้ามี) และสร้าง image label จากข้อมูลไฟล์
# - ใน `__len__` จะทำให้สามารถใช้คำสั่ง len กับข้อมูลได้
# - ใน `__getitem__` จะทำให้สามารถอ้างถึงข้อมูลในรูปแบบคล้าย List ได้ดังตัวอย่าง

# %%
from torch.utils.data import Dataset, DataLoader

class ThaiHandNumData(Dataset):
    def __init__(self, image_dir: str, transform=None):
        self.image_dir = image_dir
        self.transform = transform
        self.image_labels = [(image_dir, Path(image_dir).parent.name) for image_dir in glob(os.path.join(image_dir, "*", "*"))]

    def __len__(self):
        return len(self.image_labels)

    def __getitem__(self, idx):
        image, label = self.image_labels[idx]
        label = int(label)
        image = Image.open(image)
        if self.transform:
            image = 1 - self.transform(image)
        return image, label

# %% [markdown]
# จากนั้นทำการสร้าง object ข้อมูล ขึ้นมา 2 object ชื่อว่า training_data และ validation_data

# %%
training_data = ThaiHandNumData("data/train/", transform=transform)
validation_data = ThaiHandNumData("data/test/", transform=transform)

image, label = training_data[100]
plt.imshow(image.permute(1, 2, 0), cmap='gray')
plt.title(f'Label: {label}')
plt.show()

# %% [markdown]
# ต่อไปจะเป็นการสร้างสิ่งที่เรียกว่า batch of data เนื่องจากในการทำงานนี้เราจะใช้วิธีการที่เรียกว่า mini batch ในการปรับ weight กล่าวคือ
# - จะไม่ปรับ weight กับทุกข้อมูลเนื่องจากจะทำให้ช้า
# - จะไม่ปรับ weight ครั้งเดียวตอนครบทุกข้อมูลเพราะประสิทธิภาพจะไม่ดี
#
# ดังนั้นเราจะใช้วิธีการแบ่งข้อมูลออกเป็นส่วนๆ แล้วป้อนเข้าไปใน Model เช่น ส่งไปครั้งละ 16 ข้อมูล หรือ 32 ข้อมูล จากนั้นเมื่อหาค่า Loss แล้ว จึงนำมาปรับ weight เป็นครั้งๆ ไป ซึ่งจากการทดลองพบว่า จะให้ผลดีกว่าการปรับ weight กับทุกข้อมูล หรือ ปรับ weight ครั้งเดียวตอนครบทุกข้อมูล นอกจากนั้นการส่งข้อมูลเข้าไปเป็น batch ยังทำให้ลดการใช้หน่วยความจำใน GPU อีกด้วย
#
# <img src="https://static.javatpoint.com/tutorial/machine-learning/images/epoch-in-machine-learning2.png" width="400"/><div>
#
#
# link ด้านล่างนี้เป็น link Twitter(X) ของ Yann LeCun ปรมาจารย์คนหนึ่งในวงการ AI ซึ่งเป็นหัวหน้านักวิทยาศาสตร์เอไอที่บริษัท Meta เขาบอกว่าไม่ควรจะให้ Batch Size มากกว่า 32
#
# [Yann LeCun : say about batch  size](https://x.com/ylecun/status/989610208497360896)
#
# รูปด้านล่างแสดงผลของการปรับ weight ในแต่ละแบบ
# - แบบ Batch Gradient Descent  การปรับค่าพารามิเตอร์จะเกิดขึ้นโดยใช้ข้อมูลทั้งหมดในหนึ่งชุดข้อมูล (batch) ต่อการอัปเดตหนึ่งครั้ง วิธีการนี้ทำให้เกิดการอัปเดตที่มีเสถียรภาพ เนื่องจากการคำนวณ gradient จะทำจากข้อมูลทั้งหมด ทำให้ค่า gradient มีค่าที่แน่นอนและไม่เปลี่ยนแปลงบ่อยครั้ง ข้อเสีย คือ เสียเวลาและทรัพยากรมาก  จึงเหมาะสำหรับปัญหาที่มีชุดข้อมูลขนาดเล็กถึงขนาดกลาง
#
# - แบบ Stochastic Gradient Descent การปรับค่าพารามิเตอร์จะเกิดขึ้นโดยใช้ข้อมูลเพียงหนึ่งตัวอย่าง (instance) ต่อการอัปเดตหนึ่งครั้ง แทนที่จะใช้ข้อมูลทั้งหมดในชุดข้อมูล (batch) เหมือนใน Batch Gradient Descent (เลือกข้อมูลโดยการสุ่ม) ทำให้การอัปเดตพารามิเตอร์เกิดขึ้นบ่อยครั้งและมีการเปลี่ยนแปลงที่หลากหลายมากขึ้น ซึ่งสามารถช่วยหลีกเลี่ยง local minima ได้ดีขึ้นในบางกรณี
#
# - แบบ Mini-Batch Gradient Descent คือวิธีการปรับค่าพารามิเตอร์ของโมเดลในการเรียนรู้เชิงลึกหรือการเรียนรู้ของเครื่องที่ผสมผสานข้อดีของ Batch Gradient Descent และ Stochastic Gradient Descent โดยแบ่งชุดข้อมูลทั้งหมดออกเป็นกลุ่มย่อยๆ (mini-batches) แล้วใช้แต่ละกลุ่มย่อยในการคำนวณ gradient และอัปเดตพารามิเตอร์ของโมเดล
#
# <img src="https://statusneo.com/wp-content/uploads/2023/09/Credit-Analytics-Vidya.jpg" width="600"/><div>
# <br>
#
# ในโปรแกรมของเราจะใช้แบบ mini-batch และใช้ batch size เป็น 16

# %%
torch.manual_seed(42)
train_loader = DataLoader(training_data, batch_size=16, shuffle=True)
validation_loader = DataLoader(validation_data, batch_size=16, shuffle=False)

# %%
# load example batch
images, labels = next(iter(train_loader))
print(images.shape, labels.shape)
plt.imshow(image.permute(1, 2, 0), cmap='gray')
plt.title(f'Label: {label}')
plt.show()
# Out:
# torch.Size([16, 1, 28, 28]) torch.Size([16])

# %%
# print(image[0])
images.shape, labels
# Out:
# (torch.Size([16, 1, 28, 28]),
#  tensor([0, 9, 8, 3, 3, 2, 2, 8, 4, 7, 5, 9, 4, 0, 0, 5]))

# %% [markdown]
# ## การสร้าง Model
#
# ก่อนจะสร้างข้อมูลขอทบทวนขั้นตอนการ Train อีกครั้งโดยมีขั้นตอนตามตารางนี้ ดังนั้นในการ Train ให้ตรวจสอบว่าทำครบในทุกขั้นตอน
#
# | Number | Step name | What does it do? | Code example |
# | ----- | ----- | ----- | ----- |
# | 1 | Forward pass | The model goes through all of the training data once, performing its `forward()` function calculations. | `model(x_train)` |
# | 2 | Calculate the loss | The model's outputs (predictions) are compared to the ground truth and evaluated to see how wrong they are. | `loss = loss_fn(y_pred, y_train)` |
# | 3 | Zero gradients | The optimizers gradients are set to zero (they are accumulated by default) so they can be recalculated for the specific training step. | `optimizer.zero_grad()` |
# | 4 | Perform backpropagation on the loss | Computes the gradient of the loss with respect for every model parameter to be updated  (each parameter with `requires_grad=True`). This is known as **backpropagation**, hence "backwards".  | `loss.backward()` |
# | 5 | Update the optimizer (**gradient descent**) | Update the parameters with `requires_grad=True` with respect to the loss gradients in order to improve them. | `optimizer.step()` |
# <br>
#
# ขั้นตอนแรก คือ forward pass ซึ่ง forward pass จะสร้างใน Class ของ Model Neural Network โดยในที่นี้ตั้งชื่อว่า ThaiNumberNN ซึ่งแสดงตามโปรแกรมด้านล่าง

# %%
import torch.nn as nn
import torch.nn.functional as F

class ThaiNumberNN(nn.Module):
    def __init__(self):
        super().__init__()
        self.fc1 = nn.Linear(28 * 28, 80)
        self.fc2 = nn.Linear(80, 10)

    def forward(self, x):
        x = x.view(-1, 28 * 28)
        x = self.fc1(x)
        x = F.relu(x)
        x = self.fc2(x)
        return x

# %% [markdown]
# จะเห็นว่าใน Model จะประกอบด้วย Hidden Layer จำนวน 1 Layer โดย Input มีขนาดเป็นเป็น 28x28 เนื่องจากในแต่ละรูปมีจุดภาพ 28x28 จุด โดยแต่ละจุดภาพมีขนาด 1 ไบต์ (เนื่องจากเก็บแบบ Grayscale) ดังนั้นเราจะนำข้อมูลแต่ละจุดมาเรียงกันเป็น Array 1 มิติ (ขนาด 784 ไบต์) โดยผ่านคำสั่ง view
#
# แล้วส่งเข้าในแต่ละ Neuron ของ Hidden Layer ชั้นที่ 1 ซึ่งมีจำนวน 80 Neuron และนำมาผ่านฟังก์ชัน ReLU แล้วจึงนำเข้ามาที่ output layer ซึ่งจะมี 10 neuron ซึ่งเท่ากับจำนวน Input

# %%
my_NN = ThaiNumberNN()
images, labels = next(iter(train_loader))
pred = my_NN(images)
print(images.shape, pred.shape)
print(pred[:5])
print(pred.argmax(1))
labels
# Out:
# torch.Size([16, 1, 28, 28]) torch.Size([16, 10])
# tensor([[ 0.0463,  0.1628, -0.0030, -0.0869, -0.0337,  0.0391,  0.1665, -0.0014,
#           0.0143,  0.1464],
#         [ 0.0046,  0.0322, -0.0200,  0.0488,  0.0876,  0.0650,  0.0868,  0.0159,
#          -0.0267,  0.1207],
#         [ 0.0743,  0.0313,  0.1117,  0.0214,  0.1003,  0.0606, -0.0373, -0.0039,
#          -0.0020,  0.1972],
#         [ 0.0595,  0.1081, -0.0324,  0.0424, -0.0339,  0.0671,  0.1055, -0.0362,
#          -0.0713,  0.1621],
#         [ 0.1203,  0.0802,  0.1149,  0.0219, -0.0087,  0.0907,  0.0741, -0.0163,
#           0.0211,  0.2544]], grad_fn=<SliceBackward0>)
# tensor([6, 9, 9, 9, 9, 9, 9, 1, 9, 5, 1, 9, 9, 6, 9, 9])
# tensor([7, 6, 5, 9, 5, 5, 6, 6, 9, 7, 7, 2, 0, 8, 7, 6])

# %% [markdown]
# ### ส่วน Train ข้อมูล และหาค่า Validation
#
# คราวนี้ก็มาถึงการ train ข้อมูล ซึ่งหากดูจากตาราง จะพบว่าประกอบด้วยขั้นตอน 1) calculate loss 2) zero gradient 3) backpropagation และ 4) update parameter ผ่าน optimizer function
#
# ในฟังก์ชัน train จะมีส่วนประกอบดังนี้
# - training_logs ทำหน้าที่เก็บข้อมูลจำนวน 4 ข้อมูล คือ training loss ของแต่ละรอบ, training accuracy ของแต่ละรอบ, validation loss และ validation accuracy โดย loss จะเป็นผลรวมค่า loss ของทุกข้อมูล (training loss คือ ผลรวมของ training data, validation loss ผลรวมของ validation data) สำหรับ accuracy คือ ร้อยละที่ทำนายได้ถูกของแต่ละข้อมูล
# - ใน Loop นอกจะทำหน้าที่รัน epoch คือ ส่งข้อมูลเข้าไป train จนครบทุกข้อมูล
# - เริ่มต้นจะกำหนดให้เป็น training mode โดยใช้คำสั่ง `model.train()`
# - ส่วน loop ด้านใน loop แรก `for images, labels in train_loader`  จะทำหน้าที่ค่อยๆ นำข้อมูลของ image และ label ของรูป ออกมาทีละรูป
# - `pred = model(images)` นำรูปนั้นไปผ่าน forward pass ของ model
# - `loss = loss_function(pred, labels)` คำนวณค่า loss เทียบกับ label โดยใช้ loss_function
# - `optimizer.zero_grad()` clear ค่า gradient ที่คำนวณได้ออก เพื่อเตรียมสำหรับรันใน loop ถัดไป
# - `loss.backward()` ทำ Backpropagation เพื่อคำนวณค่าที่ต้องใช้ในการปรับพารามิเตอร์
# - `optimizer.step()` ทำการปรับพารามิเตอร์
# - บันทึกค่า loss และ ค่าความถูกต้อง valid
#
# จากนั้นก็เก็บค่า Loss และ Validation ของ training รอบนั้น คราวนี้ต่อไปก็จะมาทำส่วนของ Validation Test ซึ่งขั้นตอนก็จะคล้ายกับ Training เพียงแต่จะไม่มีการปรับพารามิเตอร์ จะเห็นว่าคำสั่ง `optimizer.zero_grad()`, `loss.backward()` และ `optimizer.step()` ไม่มีใน loop นี้ ซึ่งก็คือ การนำข้อมูลอีกชุดมาตรวจสอบผลการทำงานนั่นเอง
#
# จากนั้นในทุกๆ 5 รอบก็จะพิมพ์ผลมาดูครั้งหนึ่ง (ปรับเป็นค่าอื่นก็ได้)

# %%
torch.manual_seed(42)
# Check if CUDA is available
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# Create training loop function
def train(model, n_epochs, loss_function, optimizer, train_loader, test_loader):
    training_logs = {"train_loss": [],  "train_acc": [], "validate_loss": [], "validate_acc": []}
    print("-"*80)
    for epoch in range(1, n_epochs+1):
        # training
        model.train()
        train_loss, correct = 0, 0
        for images, labels in train_loader:
            images, labels = images.to(device), labels.to(device)  # Move data to GPU
            pred = model(images)
            loss = loss_function(pred, labels)

            optimizer.zero_grad()
            loss.backward()
            optimizer.step()

            train_loss += loss.item()
            correct += (pred.argmax(1) == labels).float().sum().item()
        # save training logs
        training_logs["train_loss"].append(train_loss/ len(train_loader))
        training_logs["train_acc"].append(correct / len(train_loader.dataset))

        # validation
        model.eval()
        test_loss, correct = 0, 0
        for images, labels in validation_loader:
            images, labels = images.to(device), labels.to(device)  # Move data to GPU
            pred = model(images)
            test_loss += loss_function(pred, labels).item()
            correct += (pred.argmax(1) == labels).float().sum().item()
        # save validation logs
        training_logs["validate_loss"].append(test_loss/ len(validation_loader))
        training_logs["validate_acc"].append(correct / len(validation_loader.dataset))

        if epoch % 5 == 0:
          print(f"Epochs {epoch}".ljust(10),
                f"train loss {training_logs['train_loss'][-1]:.5f}",
                f"train acc {training_logs['train_acc'][-1]:.5f}",

                f"validate loss {training_logs['validate_loss'][-1]:.5f}",
                f"validate acc {training_logs['validate_acc'][-1]:.5f}",
                )
          print("-"*80)
    return model, training_logs
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-bda730830063> in <cell line: 1>()
# ----> 1 torch.manual_seed(42)
#       2 # Check if CUDA is available
#       3 device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
#       4
#       5 # Create training loop function
#
# NameError: name 'torch' is not defined

# %% [markdown]
# ### ส่วน run model
#
# คราวนี้ก็มาถึงส่วนที่ทำหน้าที่ run model โดยกำหนด
# - ค่า epoch ไว้ที่ 100 รอบ
# - ใช้ loss function เป็น `nn.CrossEntropyLoss()` เพราะใช้กับการทำงานแบบ Classification
# - ใช้ gradient descent หรือการปรับพารามิเตอร์แบบไล่ตามความชันในแบบ SDG หรือ Stocastic Gradient Descent
# - กำหนด learning rate เป็น 0.01

# %%
n_epoch = 100

TN_model = ThaiNumberNN().to(device) # Initialize the model

loss_fn = nn.CrossEntropyLoss()
optimizer = torch.optim.SGD(TN_model.parameters(), lr=0.01)

TN_model, TN_model_history = train(TN_model, n_epoch, loss_fn, optimizer, train_loader, validation_loader)
# Out:
# --------------------------------------------------------------------------------
# Epochs 5   train loss 2.04517 train acc 0.44952 validate loss 2.06125 validate acc 0.37143
# --------------------------------------------------------------------------------
# Epochs 10  train loss 1.56964 train acc 0.56063 validate loss 1.69361 validate acc 0.46857
# --------------------------------------------------------------------------------
# Epochs 15  train loss 1.26545 train acc 0.63810 validate loss 1.49176 validate acc 0.52571
# --------------------------------------------------------------------------------
# Epochs 20  train loss 1.10877 train acc 0.69206 validate loss 1.40499 validate acc 0.56000
# --------------------------------------------------------------------------------
# Epochs 25  train loss 1.01149 train acc 0.71302 validate loss 1.35315 validate acc 0.58857
# --------------------------------------------------------------------------------
# Epochs 30  train loss 0.93955 train acc 0.72952 validate loss 1.31749 validate acc 0.60571
# --------------------------------------------------------------------------------
# Epochs 35  train loss 0.87500 train acc 0.74921 validate loss 1.29215 validate acc 0.58857
# --------------------------------------------------------------------------------
# Epochs 40  train loss 0.82002 train acc 0.76952 validate loss 1.27329 validate acc 0.59429
# --------------------------------------------------------------------------------
# Epochs 45  train loss 0.76811 train acc 0.78540 validate loss 1.25328 validate acc 0.59429
# --------------------------------------------------------------------------------
# Epochs 50  train loss 0.72352 train acc 0.80127 validate loss 1.24776 validate acc 0.61143
# --------------------------------------------------------------------------------
# Epochs 55  train loss 0.67858 train acc 0.81079 validate loss 1.23068 validate acc 0.61143
# --------------------------------------------------------------------------------
# Epochs 60  train loss 0.63860 train acc 0.82730 validate loss 1.22943 validate acc 0.61143
# --------------------------------------------------------------------------------
# Epochs 65  train loss 0.59961 train acc 0.84190 validate loss 1.22748 validate acc 0.60571
# --------------------------------------------------------------------------------
# Epochs 70  train loss 0.56157 train acc 0.85905 validate loss 1.22450 validate acc 0.61143
# --------------------------------------------------------------------------------
# Epochs 75  train loss 0.52838 train acc 0.87048 validate loss 1.23327 validate acc 0.61714
# --------------------------------------------------------------------------------
# Epochs 80  train loss 0.49440 train acc 0.88127 validate loss 1.23257 validate acc 0.61714
# --------------------------------------------------------------------------------
# Epochs 85  train loss 0.46457 train acc 0.88889 validate loss 1.23265 validate acc 0.61143
# --------------------------------------------------------------------------------
# Epochs 90  train loss 0.43392 train acc 0.89651 validate loss 1.23556 validate acc 0.60571
# --------------------------------------------------------------------------------
# Epochs 95  train loss 0.40566 train acc 0.91048 validate loss 1.23290 validate acc 0.61714
# --------------------------------------------------------------------------------
# Epochs 100 train loss 0.38022 train acc 0.91810 validate loss 1.24426 validate acc 0.61714
# --------------------------------------------------------------------------------

# %% [markdown]
# ### ผลการทำงาน
#
# - จะเห็นได้ว่าเมื่อทำงานไปเรื่อยๆ จะพบว่าค่าความถูกต้องของ training accuracy จะเพิ่มขึ้นเรื่อย จนค่าสุดท้ายคือ 91 % ซึ่งถือว่าดีมากทีเดียว
# - แต่เมื่อนำข้อมูลที่กันเอาไว้สำหรับตรวจสอบความถูกต้อง มาทดสอบก็พบว่าความถูกต้องจะอยู่ที่ประมาณ 60% กว่ามาตั้งแต่รอบที่ 25 และไม่ดีขึ้นเลย

# %%
def plot_graph(history):
    fig, (ax1, ax2) = plt.subplots(1, 2)
    fig.set_figwidth(10)
    fig.suptitle("Train vs Validation")
    ax1.plot(history["train_acc"], label="Train")
    ax1.plot(history["validate_acc"], label="Validation")
    ax1.legend()
    ax1.set_title("Accuracy")

    ax2.plot(history["train_loss"], label="Train")
    ax2.plot(history["validate_loss"], label="Validation")
    ax2.legend()
    ax2.set_title("Loss")
    fig.show()

# %%
plot_graph(TN_model_history)

# %% [markdown]
# ### วิเคราะห์กราฟ
#
# เมื่อนำข้อมูลของ Accuracy มา plot เป็นกราฟก็จะเห็นได้ชัดเจนว่าหลังจากรอบที่ 20 ความถูกต้องเมื่อเทียบกับ validation data ไม่ได้เพิ่มขึ้นเท่าไร แต่ความถูกต้องของ traning data กลับเพิ่มขึ้นเรื่อยๆ
#
# การฉีกออกจากกันระหว่าง กราฟ traing accuracy และ validation accuracy แบบนี้แสดงให้เห็นว่าการ train ยังไม่ได้ผลที่ดีมากนัก โดยการ train ที่ได้ผลดี กราฟ trainng accuracy และ validation accuracy ควรจะอยู่ใกล้ๆ กัน ไม่แยกออกจากกันมาก
# <br>
#
# #### Overfitting
# การแยกออกจากกันของ validation accuracy กับ trainng accuracy เป็นปัญหาที่เรียกว่า **overfitting** ซึ่งเป็นสถานการณ์ที่เกิดขึ้นเมื่อโมเดล machine learning ทำงานได้ดีมากกับข้อมูลการฝึก (training data) แต่ทำงานได้ไม่ดีหรือแย่มากกับข้อมูลทดสอบ (testing data) หรือข้อมูลที่ไม่เคยเห็นมาก่อน โดยลักษณะคือ Training Accuracy สูง แต่ Testing Accuracy หรือ validation Accuracy ต่ำ
#
# > <img src="https://miro.medium.com/v2/resize:fit:1100/format:webp/1*lARssDbZVTvk4S-Dk1g-eA.png" width="500">
#
# <br>
#
# #### เปรียบเทียบกับการทำงานของสมอง
#
# การ overfit หากเปรียบเทียบกับการทำงานของสมอง ก็ต้องบอกว่าเป็นการใช้ความจำมากเกินไป เช่น สมมติว่าเราซ้อมจักรยานวิบาก ในสนามที่ซ้อมเป็นประจำ จนรู้ว่าตรงไหนเป็นหลุม หรือเป็นเนิน ทำให้เราสามารถหลบเนินหรือหลุมได้ ทำให้เราขับได้คล่องในสนามที่ซ้อมเป็นประจำ แต่ทำให้เราขาดทักษะในการปรับตัวกับสนามแบบทั่วไป ดังนั้นแทนที่จะพัฒนาทักษะหลบหลุม หรือ เนิน กลับไปใช้ความจำแทน
#
# ในทาง Machine Larning อาจจะบอกว่าการเรียนรู้ไปจดจำ Noise มากเกินไป ทำให้พลาดการมองแนวโน้ม

# %% [markdown]
# ### การนำไปใช้งาน
#
# ทีนี้สมมติว่าเราต้องการเอาข้อมูลมาทดสอบสักหน่อย จะทำอย่างไร เราก็ต้องเขียนโปรแกรมอ่านภาพ และนำมา transform จากนั้นนำไป predict และเทียบผลกับคำตอบจริง

# %%
# Show some random images with their predicted number
sample_path = glob("data/test/*/*.png")[99]
img = Image.open(sample_path)
img = (1 - transform(img)).squeeze(0).to(device)
TN_model.to(device)
pred = TN_model(img)
pred = int(pred.argmax(dim=1).item())
true_class = Path(sample_path).parent.name

plt.title("Predicted class = {}, True class = {}".format(pred, true_class))
plt.imshow(img.cpu(), cmap="gray")
plt.show()

# %% [markdown]
# ## Optimization Algorithm
#
# ใน Machine Learning มี Optimization Algorithm อยู่มากมาย เช่น หากอยากจะทราบว่าใน PyTorch มี optimization มีอะไรบ้างให้คลิก [ที่นี่](https://pytorch.org/docs/stable/optim.html#algorithms)
#
# ต่อไปจะอธิบาย Optimization Algorithm อย่างย่อๆ จำนวน 3 ตัวได้แก่
# - Stochastic Gradient Descent (SGD) optimizer
# - Adam Optimizer
# - SDG with Momentum

# %% [markdown]
# ### Stochastic Gradient Descent (SGD)
#
# - Gradient Descent (GD): เป็นวิธีการหาค่าต่ำสุดของ loss function  โดยการอัพเดตพารามิเตอร์ในทิศทางที่ทำให้ Loss มีค่าลดลงไปเรื่อยๆ ซึ่งสามารถทำได้โดยการคำนวณ gradient  ของ loss function ตามพารามิเตอร์แล้วอัพเดตพารามิเตอร์ไปในทิศทางที่ตรงข้ามกับ gradient นั้น วิธีการนี้ให้ที่ถูกต้องสูง แต่จะเสียเวลาในการทำงาน เนื่องจากจะต้องอัพเดตพารามิเตอร์จากทุกข้อมูล
#
# - Stochastic Gradient Descent (SGD): แตกต่างจาก GD ตรงที่การคำนวณ gradient ในแต่ละครั้งจะไม่ใช้ข้อมูลทั้งหมด แต่จะใช้ข้อมูลตัวอย่างเดียวหรือชุดย่อย (mini-batch) ของข้อมูลเท่านั้น ซึ่งทำให้การคำนวณ gradient ในแต่ละครั้งเร็วขึ้น ซึ่งจะเกิดผลทำให้การปรับพารามิเตอร์มีการ swing ตามรูปที่แสดงอยู่ด้านบน
#
# *** SDG กับ local minima ***
#
# - เนื่องจาก gradient ของทุกพารามิเตอร์ อาจมีจุดต่ำสุดหลายที่ตามรูป โดยจุดต่ำสุดเฉพาะถิ่น จะเรียกว่า local minima และจุดต่ำสุดของทั้งหมดจะเรียกว่า global minima
# - โดยในการทำงานแบบ gradient descent นั้น การสุ่มตำแหน่งแรกของการทำงานเพื่อนำมาคำนวณค่า gradient นั้นมีความสำคัญมาก เพราะหากเริ่มต้นจากจุดที่ไม่ดีแล้ว อาจทำให้ได้จุดต่ำสุดที่ไม่ใช่จุดต่ำสุดรวม
# - เนื่องจาก SDG ใช้การสุ่มข้อมูลมาคำนวณค่า gradient เป็นผลทำให้เกิดการกระโดดของจุดทำงาน ซึ่งอาจบังเอิญเป็นการกระโดดข้าม local minima ก็ได้ ดังนั้น SDG จึงได้รับความนิยมมากกว่า และ ยังมีการทำงานที่เร็วกว่าอีกด้วย
#
# > <img src="https://www.researchgate.net/publication/338621083/figure/fig4/AS:847811214069760@1579145353037/Gradient-Descent-Stuck-at-Local-Minima-18.ppm" width="300"/><div>
# <br>
#
# > <img src="https://miro.medium.com/v2/resize:fit:1400/0*HwFeAB4nHLpqgw-7.png" width="400"/><div>
# <br>
#
# *Ref : Loss landscape of a convolutional neural network with 56 layers (VGG-56) [source](https://arxiv.org/abs/1712.09913)*

# %% [markdown]
# ### SDG with Momentum
#
# - SGD with Momentum เป็นเทคนิคที่ปรับปรุงจาก Stochastic Gradient Descent (SGD) โดยการเพิ่ม "momentum" เพื่อเร่งการลู่เข้า (convergence) และลดการสั่น (oscillations) ของการปรับพารามิเตอร์
# - โดยการปรับพารามิเตอร์ไม่เพียงแต่พิจารณาจาก gradient ของ loss function ในปัจจุบันเท่านั้น แต่ยังพิจารณาจากทิศทางของการอัพเดตก่อนหน้านี้ด้วย ซึ่งเป็นที่มีของคำว่า momentum
# - ขอยกตัวอย่างเช่น สมมติว่าการปรับพารามิเตอร์ เป็นไปในทิศทางหนึ่งมาตลอด แต่อยู่ๆ ก็มีการฉีกออกจากเส้นทางเดิม เนื่องจากการสุ่มข้อมูลที่นำมาคำนวณ gredient อาจเป็นข้อมูลที่มีความต่างไปจากข้อมูลอื่นๆ มาก ก็จะนำค่า momentum มาลบออกจากค่าของการปรับ ทำให้การฉีกจากเส้นทางเดิมมีค่าลดลง
#
# ใน PyTorch ใช้ SDG with Momentum ดังนี้
# ```
# # optimizer SGD with Momentum
# optimizer = optim.SGD(model.parameters(), lr=0.01, momentum=0.9)
# ```

# %% [markdown]
# ### Adam (Adaptive Moment Estimation)
#
# ก่อนจะทำความเข้าใจกับ Adam ต้องรู้จักกับ Adagrad และ RMSProp ก่อน
# - Adagrad (Adaptive Gradient Algorithm) Adagrad เป็นอัลกอริธึมการปรับค่าเรียนรู้ (learning rate) แบบปรับตัวเองได้ ที่พัฒนาขึ้นมาเพื่อจัดการกับปัญหาการลดค่าเรียนรู้ในระหว่างการฝึกโมเดล machine learning อัลกอริธึมนี้ได้รับความนิยมเพราะสามารถปรับค่าเรียนรู้ของพารามิเตอร์แต่ละตัวได้อย่างอัตโนมัติ ทำให้เหมาะสมกับข้อมูลและการอัพเดตที่แตกต่างกันในแต่ละพารามิเตอร์ Adagrad ปรับค่าเรียนรู้ของพารามิเตอร์แต่ละตัวโดยพิจารณาจากประวัติของ gradient ก่อนหน้า แนวคิดหลักคือการใช้ gradient ที่เคยคำนวณในอดีตเพื่อปรับค่าเรียนรู้ในปัจจุบัน โดยการปรับค่านี้จะทำให้พารามิเตอร์ที่มีการอัพเดตมากมีค่าเรียนรู้ที่ลดลง และพารามิเตอร์ที่มีการอัพเดตน้อยจะมีค่าเรียนรู้ที่สูงขึ้น สำหรับการทำงานโดยละเอียด จะไม่อธิบาย ผู้สนใจให้ศึกษาเพิ่มเติม
# - RMSprop (Root Mean Square Propagation) RMSprop เป็นอัลกอริธึมการปรับค่าพารามิเตอร์ที่ใช้ในการฝึกโมเดล machine learning ซึ่งเป็นการพัฒนาต่อจาก Adagrad โดยปรับปรุงปัญหาที่ค่า learning rate ลดลงเร็วเกินไป RMSprop มีแนวคิดหลักคือการรักษาค่า learning rate ให้เหมาะสมตลอดการฝึกโดยใช้ค่าเฉลี่ยเคลื่อนที่ (moving average) ของกำลังสองของ gradient ซึ่งช่วยลดปัญหาที่ค่า learning rate ลดลงเร็วเกินไปใน Adagrad
#
# รูปด้านล่างแสดงการเปรียบเทียบการทำงานระหว่าง SDG, Momentum, Adagrad, RMSprop และอื่นๆ ซึ่งจะเห็นได้ว่าในขณะที่ SDG ติดอยู่ที่ local minima แต่ตัวอื่นสามารถออกจาก local minima ได้
#
# <img src="https://editor.analyticsvidhya.com/uploads/121381obtV.gif" width="400"/><div>
# <br>
#
# สำหรับ ADAM เป็นการนำเอาอัลกอริทึม Adagrad และ RMSprop มารวมคุณสมบัติที่ดีไว้ด้วยกัน ซึ่งไม่อธิบายการทำงานโดยละเอียดเช่นกัน
#
# ในเรื่องของ Optimization ไม่มีอัลกอริทึมใดที่ดีที่สุด เช่น ในการประมาณค่าสมการเส้นตรงแบบที่เราทำในตอนแรก หากนำ Adam ไปใช้กลับให้ผลการทำงานที่ไม่ดี ดังนั้นต้องเลือกใช้ อัลกอริทึม  Optimization ให้เหมาะสม ซึ่งจะทดลองเองก็ได้ หรือศึกษางานของผู้อื่น

# %% [markdown]
# ## การปรับปรุง Model (Optimization)
#
# มาถึงจุดนี้ คงจะเห็นภาพรวมของการทำงานของ Machine Learning แล้ว ซึ่งคงยังจำกันได้ว่า Model ที่เราสร้างยังทำงานได้ไม่ดี เนื่องจากเกิด Overfitting ขึ้น

# %% [markdown]
# ### Overfitting คืออะไร
#
# เนื่องจาก Overfitting คือ สิ่งหนึ่งที่แสดงว่า Model ยังไม่ดี ดังนั้นเราจะมากทำความเข้าใจกันว่า Overfitting คืออะไร ก่อนหน้านี้ได้กล่าวว่า Overfitting คือ "การเรียนรู้ไปจดจำ Noise มากเกินไป ทำให้พลาดการมองแนวโน้ม"
#
# ลองมาดูรูปนี้
#
# <img src="https://miro.medium.com/v2/format:webp/1*SJENTprShSaT9eB-4CUyAw.gif" width="300"/><div>
#
#
# จากรูปจะเห็นการเปลี่ยนไปของ weight ในระหว่างการ train จะเห็นว่าบางเส้นทางค่า weight มีค่าเพิ่มขึ้น แปลว่า model ให้ค่ากับพารามิเตอร์ หรือ ข้อมูลของเส้นทางนั้นมาก คราวนี้ลองตอบคำถาม 2 ข้อ
#
# **คำถามข้อที่ 1 **
# - ค่า Loss ต่ำสุดของ Model มีได้กี่แบบ
# - คำตอบ คือ มีได้มากมาย เนื่องจากค่าพารามิเตอร์เริ่มต้นจะเป็นค่าสุ่ม และการเลือกตัวอย่างสำหรับการปรับพารามิเตอร์ก็เป็นการสุ่ม ดังนั้นเมื่อ run model ไปเรื่อยๆ ในที่สุดก็จะได้ชุดพารามิเตอร์ชุดหนึ่งที่ทำให้ค่า loss ต่ำ และ หากรันอีกครั้งก็จะได้ค่าพารามิเตอร์ที่ทำให้ค่า loss ต่ำใกล้เคียงกับกับครั้งแรก ดังนั้นสรุปได้ว่าผลจากการ run model จะมีคำตอบมากมาย แต่ได้ผลสิ่งเดียวกัน คือ ทำให้ค่า loss ต่ำ ทำให้สามารถทำนาย หรือ ประมาณค่าได้ถูกต้อง
#
# **คำถามข้อที่ 2 **
# - ระหว่าง model ที่มีผลเดียวกัน แต่มีค่าพารามิเตอร์แตกต่างกันมาก คือ ค่ามากก็มาก ค่าน้อยก็น้อย กับอีก model ที่มีพารามิเตอร์แตกต่างกันน้อยกว่า ควรเลือก model ไหนมาใช้
# - คำตอบ ควรเลือกโมเดลที่ 2 หากถามว่าทำไม ก็ต้องย้อนความทรงจำกลับไปที่เรื่องการประมาณค่า sine ซึ่งจะเห็นว่าแต่ละ neuron จะ active กับแต่ละข้อมูลไม่เท่ากัน และ มีความจริงอีกประการ คือ ข้อมูลที่นำมาให้ model เรียนรู้ บางข้อมูลจะใกล้เคียงกัน แต่บางข้อมูลจะต่างไปจากข้อมูลอื่นๆ มาก (ซึ่งอาจจะเรียกว่า Noise เพราะข้อมูลโดดไปจากเพื่อน) ทีนี้หากบังเอิญว่า ในข้อมูลที่เป็น Noise มาเจอกับ Neuron ที่มีค่าพารามิเตอร์สูงๆ จะเกิดอะไรขึ้น ผลที่เกิดขึ้นก็คือจะทำให้การคำนวณค่า loss เกิดเพี้ยนได้มาก ซึ่งเป็นสิ่งที่เราไม่ต้องการ
#
# จึงได้กล่าวว่า Overfitting คือ "การเรียนรู้ไปจดจำ Noise มากเกินไป ทำให้พลาดการมองแนวโน้ม"
#
# เมื่อเราทราบถึงสาเหตุ ดังนั้นการแก้ไขก็คือ พยายามทำให้ model มีพารามิเตอร์ที่ "ไม่มีเส้นใหญ่" มากนัก

# %% [markdown]
# ### วิธีในการแก้ไข Overfitting
#
# เมื่อเราทราบสาเหตุแล้ว เราก็มาดูว่าจะมีวิธีแก้อย่างไรบ้าง
#
# 1. เพิ่มข้อมูลการฝึกให้มากขึ้น เมื่อมีข้อมูลที่หลากหลายขึ้น ข้อมูลที่เป็น Noise ก็จะมีผลกับ model ลดลง การจำรูปแบบก็จะลดลง
#
# 2. ทำ Cross validation เป็นการปรับปรุงการแบ่งข้อมูลใหม่ โดยแทนที่จะแบ่งข้อมูลเป็นชุดสอน (Training set) และ ชุดทดสอบ (Test set) ก็จะทำอีกแบบ คือชุดข้อมูลจะถูกแบ่งออกเป็นชุดย่อยๆ จำนวน k ชุด และ ในการทำงานจะทำงานทั้งหมด k รอบ โดยในแต่ละรอบ ชุดข้อมูล Test จะมีการสับเปลี่ยนกัน ทำให้เมื่อ train ครบทั้ง k รอบ ชุดข้อมูลทุกส่วนจะมีโอกาสเป็นทั้งชุดข้อมูลสอน และทดสอบ โดยอาจมองว่าเป็นการเพิ่มความหลากหลายของข้อมูลเพิ่มขึ้นวิธีหนึ่งนั่นเอง
#
# <img src="https://user-images.githubusercontent.com/26833433/258589390-8d815058-ece8-48b9-a94e-0e1ab53ea0f6.png" width="500"/><div>
#
# 3. Data Augmentation เป็นวิธีในการเพิ่มจำนวนของชุดข้อมูลสอน (Train set) โดยการนำข้อมูลเดิมมาดัดแปลงเพื่อเพิ่มความหลากหลายของข้อมูล กรณีที่เราไม่สามารถหาข้อมูลที่มีความหลากหลายได้มากพอ วิธีการทำ Data Augmentation จะนิยมใช้กับข้อมูลที่เป็นภาพมาก เพราะสามารถเพิ่มความหลากหลายได้ง่าย เช่น เอารูปมาขยาย หรือ หมุน หรืออื่นๆ ก็จะได้ข้อมูลที่แตกต่างจากข้อมูลเดิม จากนั้นก็นำเข้าไปเป็นข้อมูลสำหรับฝึกสอน
#
# <img src="https://ubiai.tools/wp-content/uploads/2023/11/UKwFg.jpg" width="500"/><div>
#
# 4. Early stopping เป็นวิธีการในการหยุดการ overfit โดยการหยุดการทำงานของ model เสียก่อน เช่น จากรูป เมื่อเราเห็นว่าการ overfit เริ่มเกิดขึ้น เราก็หยุดการทำงานของ model เสียก่อน
#
# <img src="https://miro.medium.com/v2/resize:fit:567/0*z19dbRlkgocQYn6t.png" width="350"/><div>
#
#
# ใน 3 วิธีแรกจะเน้นไปที่การเพิ่มข้อมูลการฝึกโดยวิธีการต่างๆ ส่วนวิธีที่ 4 คือ หยุดการฝึก แต่สำหรับวิธีที่จะกล่าวถึงต่อไป เป็นวิธีที่ใช้กระบวนการทางคณิตศาสตร์เข้ามาช่วย โดยมีเป้าหมายเพื่อที่จะ "แกล้ง" หรือ "ลดความสำคัญ" หรือ "ลงโทษ" (Penalty) กับพารามิเตอร์ที่มีค่ามากๆ
#
# 4. L1 Regularization คำว่า Regularization แปลว่า การทำให้เป็นทั่วไป หรือ การทำให้เป็นมาตรฐาน โดยนัยคือ ต้องการให้พารามิเตอร์อยู่ในกรอบที่ต้องการ หลักการของ L1 regularization คือการเพิ่มเทอมลงโทษเข้าไปใน loss function ของโมเดล โดยเทอมลงโทษนี้เป็นค่าสัมบูรณ์ของค่าสัมประสิทธิ์ ดังนี้:
#
#
# >  $  \text{Loss} = \frac{1}{2m} \sum_{i=1}^{m} (y_i - \hat{y}_i)^2 + \lambda \sum_{j=1}^{n} |w_j| $
# <br>
#
# จะเห็นว่าสมการแบ่งออกเป็น 2 เทอม โดยเทอมแรก ก็คือ Loss Function นั่นเอง ดังนั้น L1 regularization ก็คือการเพิ่มเทอมที่ 2 เข้าไป โดยเอาค่า w ทั้งหมดมาทำ absolute แล้วบวกกัน จากนั้นคูณด้วย $\lambda$ ซึ่งเป็น coefficient ซึ่งใช้ในการควบคุมความแรงของการลงโทษ (penalty) หาก $\lambda$ มีค่าสูง การลงโทษจะมีความแรงมาก ทำให้ค่าสัมประสิทธิ์ $w_j$ ถูกปรับให้มีค่าน้อยลงมากและบางตัวอาจเป็น 0 ได้
#
# 5. L2 Regularization จะคล้ายกับ L1 แต่เปลี่ยนเป็นยกกำลังสอง ตามสมการ ความแตกต่างจาก L1 คือ L2 จะไม่ทำให้พารามิเตอร์เป็น 0 แต่จะเป็นการเกลี่ยพารามิเตอร์ให้ใกล้กันมากขึ้น
#
# > $ \text{Loss} = \frac{1}{2m} \sum_{i=1}^{m} (y_i - \hat{y}_i)^2 + \lambda \sum_{j=1}^{n} w_j^2 $
#
# ุ6. Dropout Regularization วิธีการนี้จะเป็นการเกลี่ยพารามิเตอร์อีกรูปแบบหนึ่ง โดยจะเป็นการสุ่มตัด Neuron บางตัวออกไปในระหว่างการเรียนรู้ของโมเดล อาจมองได้ว่าเป็นการแกล้ง model ก็ได้ โดยในแต่ละรอบการทำงาน Neuron บางตัวจะถูกกำหนดให้มีน้ำหนักเป็น 0 โดยการสุ่ม ซึ่งนิวรอลที่มีน้ำหนักเป็น 0 จะไม่ส่งผลต่อการทำงาน การทำซ้ำเช่นนี้ไปเรื่อยๆ ในกระบวนการสอน จะทำให้นิวรอลเน็ตเวิร์กพยายามไม่ขึ้นอยู่กับ (Dependent) Neuron ใด Neuron หนึ่งมากเกินไป ทำให้ส่งผลต่อการลดโอกาสการเกิด Overfitting ได้นั่นเอง วิธีการนี้เราอาจมองว่าคล้ายกับการเรียนรู้ของมนุษย์ เพราะมนุษย์จะมีการลืมบางข้อมูล ดังนั้นในรอบการเรียนรู้ก็จะทำให้โมเดลลืมบางพารามิเตอร์ไปบ้าง จะทำให้ model เรียนรู้แนวโน้ม (trend) มากขึ้น
#
#
# <img src="https://www.researchgate.net/publication/309206911/figure/fig3/AS:418379505651712@1476760855735/Dropout-neural-network-model-a-is-a-standard-neural-network-b-is-the-same-network.png" width="600"/><div>

# %% [markdown]
# ### ปรับปรุง model โดยการเพิ่ม node และ Layer
#
# เอาละ! คราวนี้เราจะกลับมาปรับปรุง Model โดยเพิ่มจำนวน Node และ Layer เข้าไป โดยหวังว่าจะเรียนรู้ได้มากขึ้น โดยได้เพิ่มเป็น 2 Layer โดยกำหนดให้ Layer แรกมี 160 node และ Layer ที่ 2 จำนวน 80 node
#
# โดยเขียนเป็น คลาสชื่อ ThaiNumberNN2

# %%
class ThaiNumberNN2(nn.Module):
    def __init__(self):
        super().__init__()
        self.fc1 = nn.Linear(28 * 28, 160)
        self.fc2 = nn.Linear(160, 80)
        self.fc3 = nn.Linear(80, 10)

    def forward(self, x):
        x = x.view(-1, 28 * 28)
        x = self.fc1(x)
        x = F.relu(x)
        x = self.fc2(x)
        x = F.relu(x)
        x = self.fc3(x)
        return x

# %% [markdown]
# ### ทดสอบการทำงาน
#
# เมื่อปรับโมเดลเรียบร้อย ก็ทดลอง train 100 epoch เหมือนเดิม แล้วดูว่าจะได้ผลดีขึ้นไหม

# %%
n_epochs = 100

TN_model2 = ThaiNumberNN2().to(device)
loss_fn = nn.CrossEntropyLoss()
optimizer = torch.optim.SGD(TN_model2.parameters(), lr=0.01)

TN_model2, TN_model2_history = train(
    TN_model2, n_epochs, loss_fn, optimizer, train_loader, validation_loader)
# Out:
# --------------------------------------------------------------------------------
# Epochs 5   train loss 2.27430 train acc 0.20127 validate loss 2.27089 validate acc 0.19429
# --------------------------------------------------------------------------------
# Epochs 10  train loss 2.15867 train acc 0.41397 validate loss 2.12922 validate acc 0.37143
# --------------------------------------------------------------------------------
# Epochs 15  train loss 1.73625 train acc 0.50476 validate loss 1.67280 validate acc 0.49143
# --------------------------------------------------------------------------------
# Epochs 20  train loss 1.31519 train acc 0.58476 validate loss 1.29977 validate acc 0.58286
# --------------------------------------------------------------------------------
# Epochs 25  train loss 1.13191 train acc 0.67365 validate loss 1.17427 validate acc 0.61143
# --------------------------------------------------------------------------------
# Epochs 30  train loss 1.00076 train acc 0.70794 validate loss 1.08687 validate acc 0.64000
# --------------------------------------------------------------------------------
# Epochs 35  train loss 0.90045 train acc 0.73460 validate loss 1.05226 validate acc 0.64000
# --------------------------------------------------------------------------------
# Epochs 40  train loss 0.80995 train acc 0.77016 validate loss 1.00956 validate acc 0.66857
# --------------------------------------------------------------------------------
# Epochs 45  train loss 0.72142 train acc 0.78921 validate loss 1.00298 validate acc 0.68000
# --------------------------------------------------------------------------------
# Epochs 50  train loss 0.64862 train acc 0.81460 validate loss 0.98859 validate acc 0.69714
# --------------------------------------------------------------------------------
# Epochs 55  train loss 0.57383 train acc 0.84254 validate loss 0.96897 validate acc 0.69143
# --------------------------------------------------------------------------------
# Epochs 60  train loss 0.50030 train acc 0.86921 validate loss 0.97399 validate acc 0.70286
# --------------------------------------------------------------------------------
# Epochs 65  train loss 0.43933 train acc 0.89079 validate loss 0.98809 validate acc 0.70286
# --------------------------------------------------------------------------------
# Epochs 70  train loss 0.38414 train acc 0.90603 validate loss 0.96445 validate acc 0.71429
# --------------------------------------------------------------------------------
# Epochs 75  train loss 0.32737 train acc 0.92381 validate loss 0.96513 validate acc 0.70857
# --------------------------------------------------------------------------------
# Epochs 80  train loss 0.28076 train acc 0.94540 validate loss 0.97921 validate acc 0.72000
# --------------------------------------------------------------------------------
# Epochs 85  train loss 0.24010 train acc 0.96190 validate loss 1.03132 validate acc 0.67429
# --------------------------------------------------------------------------------
# Epochs 90  train loss 0.20443 train acc 0.97016 validate loss 1.02498 validate acc 0.70286
# --------------------------------------------------------------------------------
# Epochs 95  train loss 0.17383 train acc 0.97714 validate loss 1.05969 validate acc 0.68571
# --------------------------------------------------------------------------------
# Epochs 100 train loss 0.14875 train acc 0.97841 validate loss 1.04889 validate acc 0.70286
# --------------------------------------------------------------------------------

# %%
plot_graph(TN_model2_history)

# %% [markdown]
# ### วิเคราะห์กราฟ
#
# เมื่อนำข้อมูลของ Accuracy มา plot เป็นกราฟก็จะเห็นว่าความถูกต้องของ traning data เพิ่มเป็นประมาณ 98 % เรียกได้ว่า Model เรียนรู้ได้ดีขึ้น และ Accuracy ของ validation data ก็เพิ่มขึ้นเป็น 72 % ก็ถือว่าดีขึ้น

# %% [markdown]
# ### เพิ่ม Dropout
#
# คราวนี้เราจะลองลด Overfitting โดยการเพิ่ม Dropout ดูว่าจะได้ผลอย่างไร

# %%
class DropoutThaiNumberNN3(nn.Module):
    def __init__(self):
        super().__init__()
        self.fc1 = nn.Linear(28 * 28, 160)
        self.fc2 = nn.Linear(160, 80)
        self.fc3 = nn.Linear(80, 10)
        self.dropout = nn.Dropout(0.1)

    def forward(self, x):
        x = x.view(-1, 28 * 28)
        x = self.fc1(x)
        x = F.relu(x)
        x = self.dropout(x)
        x = self.fc2(x)
        x = F.relu(x)
        x = self.dropout(x)
        x = self.fc3(x)
        return x

# %%
n_epochs = 100
drop_model = DropoutThaiNumberNN3().to(device)  # Initialize a model
loss_fn = nn.CrossEntropyLoss()
optimizer = torch.optim.SGD(drop_model.parameters(), lr=0.01)

dropout_model, dropout_model_history = train(drop_model, n_epochs, loss_fn, optimizer, train_loader, validation_loader)
# Out:
# --------------------------------------------------------------------------------
# Epochs 5   train loss 2.26887 train acc 0.25206 validate loss 2.26080 validate acc 0.33143
# --------------------------------------------------------------------------------
# Epochs 10  train loss 2.13290 train acc 0.38476 validate loss 2.09306 validate acc 0.45714
# --------------------------------------------------------------------------------
# Epochs 15  train loss 1.71431 train acc 0.43746 validate loss 1.63052 validate acc 0.52571
# --------------------------------------------------------------------------------
# Epochs 20  train loss 1.35117 train acc 0.56127 validate loss 1.31774 validate acc 0.59429
# --------------------------------------------------------------------------------
# Epochs 25  train loss 1.19079 train acc 0.62730 validate loss 1.18038 validate acc 0.63429
# --------------------------------------------------------------------------------
# Epochs 30  train loss 1.05759 train acc 0.67810 validate loss 1.11596 validate acc 0.62286
# --------------------------------------------------------------------------------
# Epochs 35  train loss 0.96203 train acc 0.70413 validate loss 1.06333 validate acc 0.66286
# --------------------------------------------------------------------------------
# Epochs 40  train loss 0.88569 train acc 0.73651 validate loss 1.03682 validate acc 0.65714
# --------------------------------------------------------------------------------
# Epochs 45  train loss 0.79854 train acc 0.75556 validate loss 0.99846 validate acc 0.69143
# --------------------------------------------------------------------------------
# Epochs 50  train loss 0.71784 train acc 0.78984 validate loss 0.97206 validate acc 0.70286
# --------------------------------------------------------------------------------
# Epochs 55  train loss 0.65452 train acc 0.81206 validate loss 0.95773 validate acc 0.71429
# --------------------------------------------------------------------------------
# Epochs 60  train loss 0.58215 train acc 0.82794 validate loss 0.95399 validate acc 0.70286
# --------------------------------------------------------------------------------
# Epochs 65  train loss 0.53252 train acc 0.84317 validate loss 0.94878 validate acc 0.70857
# --------------------------------------------------------------------------------
# Epochs 70  train loss 0.48567 train acc 0.86794 validate loss 0.95632 validate acc 0.69714
# --------------------------------------------------------------------------------
# Epochs 75  train loss 0.43369 train acc 0.87238 validate loss 0.92650 validate acc 0.73143
# --------------------------------------------------------------------------------
# Epochs 80  train loss 0.39028 train acc 0.89206 validate loss 0.92532 validate acc 0.73143
# --------------------------------------------------------------------------------
# Epochs 85  train loss 0.34729 train acc 0.90413 validate loss 0.93731 validate acc 0.72571
# --------------------------------------------------------------------------------
# Epochs 90  train loss 0.31621 train acc 0.91619 validate loss 0.93273 validate acc 0.70286
# --------------------------------------------------------------------------------
# Epochs 95  train loss 0.28841 train acc 0.93079 validate loss 0.93093 validate acc 0.71429
# --------------------------------------------------------------------------------
# Epochs 100 train loss 0.25435 train acc 0.93968 validate loss 0.94912 validate acc 0.73714
# --------------------------------------------------------------------------------

# %%
plot_graph(dropout_model_history)

# %% [markdown]
# จะเห็นว่าความถูกต้องสูงขึ้น และ overfitting ลดลง เล็กน้อยเท่านั้น

# %% [markdown]
# ### Image Augmentation
#
# เราจะปรับปรุงต่อโดยใช้เทคนิคเพิ่มความหลากหลายโดยใช้ Image Augmentation โดยใช้คำสั่ง RandomAffine ใน Pytorch โดยคำสั่งนี้จะสั่งให้ random โดยทำ operation ของ TorchVision มาใช้ ได้แก่ degrees คือ การหมุนภาพระหว่าง -10 ถึง 10 องศา translate คือ การเลื่อนซ้ายขวาบนล่าง ก็ใช้ประมาณ 10 % แต่ scale คือ การขยายภาพ จะไม่ใช้ จึงให้ค่าเป็นเท่าเดิม

# %%
train_transform = transforms.Compose([
    transforms.Resize((28, 28)),
    transforms.Grayscale(),
    # add RandomAffine
    transforms.RandomAffine(degrees=(-10, 10), translate=(0.0, 0.1), scale=(1, 1)),
    transforms.ToTensor(),
])

val_transform = transforms.Compose([
    transforms.Resize((28, 28)),
    transforms.Grayscale(),
    transforms.ToTensor(),
])

# %% [markdown]
# คราวนี้มาลองดูภาพที่สร้างขึ้นจาก transform โดยมีการทำ Data Augmentation จะเห็นได้ว่าเปลี่ยนไปจากเดิม

# %%
path = glob("curriculum/Dataset/thai-handwritten-dataset/*/*")[30]
img = Image.open(path)

transformed_img = train_transform(img).squeeze(0)

plt.imshow(transformed_img, cmap="gray")
plt.show()

# %% [markdown]
# พอเราสร้างชุดข้อมูลใหม่ ก็จะต้องมาสร้าง dataset ชุดใหม่ด้วย

# %%
train_thaidigit_dataset = ThaiHandNumData("data/train/", transform=train_transform)
validation_thaidigit_dataset = ThaiHandNumData("data/test/", transform=val_transform)

# %%
train_dataloader = DataLoader(train_thaidigit_dataset, batch_size=16, shuffle=True)
validation_dataloader = DataLoader(validation_thaidigit_dataset, batch_size=16, shuffle=False)

# %% [markdown]
# คราวนี้ก็ลงมือ train เนื่องจากเราทำ Data Augmentation ก็เปรียบเสมือนกับมีข้อมูลเพิ่มขึ้น ดังนั้นจะเพิ่ม epoch เป็น 150 รอบ

# %%
# Let's train the model with augmented data
n_epochs = 150
augmented_model = DropoutThaiNumberNN3().to(device)  # Initialize the model
loss_fn = nn.CrossEntropyLoss()
optimizer = torch.optim.SGD(augmented_model.parameters(), lr=0.01)

augmented_model, augmented_model_history = train(
    augmented_model, n_epochs, loss_fn, optimizer, train_dataloader, validation_dataloader
)
# Out:
# --------------------------------------------------------------------------------
# Epochs 5   train loss 2.28225 train acc 0.17714 validate loss 2.27978 validate acc 0.25143
# --------------------------------------------------------------------------------
# Epochs 10  train loss 2.19822 train acc 0.32889 validate loss 2.18803 validate acc 0.39429
# --------------------------------------------------------------------------------
# Epochs 15  train loss 1.87285 train acc 0.39365 validate loss 1.85617 validate acc 0.39429
# --------------------------------------------------------------------------------
# Epochs 20  train loss 1.58866 train acc 0.45778 validate loss 1.62520 validate acc 0.43429
# --------------------------------------------------------------------------------
# Epochs 25  train loss 1.43354 train acc 0.52000 validate loss 1.53809 validate acc 0.45143
# --------------------------------------------------------------------------------
# Epochs 30  train loss 1.36294 train acc 0.55302 validate loss 1.44078 validate acc 0.47429
# --------------------------------------------------------------------------------
# Epochs 35  train loss 1.26025 train acc 0.59302 validate loss 1.37155 validate acc 0.51429
# --------------------------------------------------------------------------------
# Epochs 40  train loss 1.20665 train acc 0.61206 validate loss 1.29777 validate acc 0.58286
# --------------------------------------------------------------------------------
# Epochs 45  train loss 1.11119 train acc 0.64952 validate loss 1.34804 validate acc 0.54857
# --------------------------------------------------------------------------------
# Epochs 50  train loss 1.06868 train acc 0.65524 validate loss 1.28106 validate acc 0.56000
# --------------------------------------------------------------------------------
# Epochs 55  train loss 1.03503 train acc 0.66921 validate loss 1.19051 validate acc 0.62286
# --------------------------------------------------------------------------------
# Epochs 60  train loss 0.98963 train acc 0.69016 validate loss 1.12932 validate acc 0.61143
# --------------------------------------------------------------------------------
# Epochs 65  train loss 0.95281 train acc 0.69587 validate loss 1.11770 validate acc 0.62286
# --------------------------------------------------------------------------------
# Epochs 70  train loss 0.89164 train acc 0.71492 validate loss 1.04176 validate acc 0.65714
# --------------------------------------------------------------------------------
# Epochs 75  train loss 0.85669 train acc 0.71746 validate loss 1.03639 validate acc 0.66857
# --------------------------------------------------------------------------------
# Epochs 80  train loss 0.80372 train acc 0.74286 validate loss 0.99957 validate acc 0.67429
# --------------------------------------------------------------------------------
# Epochs 85  train loss 0.81662 train acc 0.74667 validate loss 0.93745 validate acc 0.67429
# --------------------------------------------------------------------------------
# Epochs 90  train loss 0.80426 train acc 0.74730 validate loss 0.91426 validate acc 0.71429
# --------------------------------------------------------------------------------
# Epochs 95  train loss 0.78010 train acc 0.74603 validate loss 0.96491 validate acc 0.67429
# --------------------------------------------------------------------------------
# Epochs 100 train loss 0.74231 train acc 0.77587 validate loss 0.89644 validate acc 0.69143
# --------------------------------------------------------------------------------
# Epochs 105 train loss 0.70571 train acc 0.77143 validate loss 0.91887 validate acc 0.70286
# --------------------------------------------------------------------------------
# Epochs 110 train loss 0.69500 train acc 0.78286 validate loss 0.87359 validate acc 0.72000
# --------------------------------------------------------------------------------
# Epochs 115 train loss 0.67094 train acc 0.78667 validate loss 0.87690 validate acc 0.73143
# --------------------------------------------------------------------------------
# Epochs 120 train loss 0.64318 train acc 0.79556 validate loss 0.83521 validate acc 0.73143
# --------------------------------------------------------------------------------
# Epochs 125 train loss 0.61291 train acc 0.79683 validate loss 0.83074 validate acc 0.74857
# --------------------------------------------------------------------------------
# Epochs 130 train loss 0.60744 train acc 0.80254 validate loss 0.85169 validate acc 0.74286
# --------------------------------------------------------------------------------
# Epochs 135 train loss 0.57980 train acc 0.80952 validate loss 0.85588 validate acc 0.72571
# --------------------------------------------------------------------------------
# Epochs 140 train loss 0.58397 train acc 0.81397 validate loss 0.80967 validate acc 0.75429
# --------------------------------------------------------------------------------
# Epochs 145 train loss 0.55567 train acc 0.82032 validate loss 0.83940 validate acc 0.73143
# --------------------------------------------------------------------------------
# Epochs 150 train loss 0.53473 train acc 0.82476 validate loss 0.82046 validate acc 0.74286
# --------------------------------------------------------------------------------

# %%
import pandas as pd
# Create evaluation function for the model
def evaluate(val_dir, model, device):
    model.to(device)
    model.eval()
    paths = glob(os.path.join(val_dir, "*", "*"))
    predictions = []
    for idx, path in enumerate(paths):
        img = 1 - transform(Image.open(path)).to(device)
        pred = model(img)
        predictions.append({
            "path": path,
            "prediction": int(pred.argmax(dim=1).item()),
            "label": int(Path(path).parent.name)
        })

    results = pd.DataFrame(predictions)
    # Calculate accuracy
    accuracy = (results.prediction == results.label).sum() / len(results)
    print(f"Accuracy: {accuracy * 100:.2f}%")
    return results

# %%
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
pred_df = evaluate("data/test/", augmented_model, device)
pred_df.head(3)
# Out:
# Accuracy: 74.29%
#                                                 path  prediction  label
# 0  data/test/6/376b5857-d33b-4eab-9491-1c34674171...           6      6
# 1  data/test/6/ddfe8d4f-f032-4d2f-9248-96385754c6...           6      6
# 2  data/test/6/23_6db9fc09-96ed-44a9-8052-cfad0e2...           6      6

# %%
plot_graph(augmented_model_history)

# %% [markdown]
# ### วิเคราะห์กราฟ
#
# จากกราฟจะเห็นได้ว่า overfitting ลดลงอย่างชัดเจนแม้ Accuracy จะได้เพียง 73.71 ซึ่งถือว่ายังไม่น่าพอใจ แต่เรายังใช้เทคนิคต่างๆ ในการปรับปรุงได้อีก โดยหากปรับปรุงให้ดีแล้ว น่าจะได้กราฟประมาณนี้
#
# <div>
# <br>
# <img src="https://github.com/khthana/AI_resource/blob/main/thainum_final.JPG?raw=true" width="900"/><div>
# <br>

# %% [markdown]
# ### การประเมิน model โดยใช้ confusion matrix
#
# ในการประเมิน model จะมีอยู่ด้วยกันหลายวิธีการ วิธีการหนึ่งเรียกว่า confusion matrix ซึ่งมักจะใช้กับงานที่เป็น Classification วิธีการ คือ นำผลการทำนาย กับ label หรือข้อมูลจริงทุกข้อมูล มา plot เป็น matrix ซึ่งข้อมูลที่ทำนายได้ถูกจะอยู่ตรงเส้นทะแยงมุม และจะทำให้เห็นว่าข้อมูลที่ผิด มักจะผิดที่ตัวใดบ้าง ซึ่งอาจจะนำข้อมูลนี้มาปรับปรุงโมเดลต่อไป
#
# นอกเหนือจากการใช้ confusion matrix ก็จะมีการประเมินต่างๆ ที่ควรจะรู้จักดังนี้
# - Precision (ความแม่นยำ): เปอร์เซ็นต์ของตัวอย่างที่ทำนายว่าเป็นบวกที่เป็นบวกจริง คำนวณจาก True Positives / (True Positives+False Positives)
# - Recall (ความครอบคลุม): เปอร์เซ็นต์ของตัวอย่างบวกที่ถูกทำนายถูกต้อง คำนวณจาก True Positives / (True Positives+False Negatives)
# - F1-Score: ค่าคะแนนที่เป็น Harmonic Mean ระหว่าง Precision และ Recall คำนวณจาก 2 x (Precision×Recall​)/(Precision+Recall)

# %%
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay
# Confusion matrix
cm = confusion_matrix(pred_df.label, pred_df.prediction, labels=range(10))
display = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=range(10))
display.plot()
plt.show()

# %% [markdown]
# ## การถอด parameter ออกมาแสดง
#
# ในกรณีที่เราอยากรู้ว่าในแต่ละ neuron มีพารามิเตอร์อะไรบ้าง นอกเหนือจากการใช้คำสั่ง state_dict() แล้ว เรายังสามารถจะนำ model parameter ของ layer ที่ 1 (fc1) ของโมเดล DropoutThaiNumberNN3 มา plot เป็น image ขนาด 28x28 ได้ด้วย เนื่องจาก weight มีขนาด 28x28 อยู่แล้ว เพียงแต่ถูกยืดอยู่ เราก็เพียงแต่นำมาจัดเรียงเป็น 28x28 ก็สามารถนำมาแสดงเป็นภาพได้ ทำให้เราสามารถเห็นข้อมูลภายใน neuron ซี่งจะเรียกข้อมูลนี้ว่า feature
#
# โดยเราจะต้องทำการ extract weights จาก layer fc1 แล้ว reshape weights นั้นให้เป็นขนาด 28x28 จากนั้นใช้ library เช่น matplotlib ในการ plot ภาพนี้
#
# ในกรณีของ layer fc1 ในโมเดลนี้ เป็น fully connected layer (หรือ linear layer) ที่มี input size 28*28 = 784 ดังนั้น weights ของ fc1 จะมีขนาด (160, 784) ซึ่งหมายความว่าแต่ละ neuron ใน fc1 จะมี weight vector ที่ยาว 784 ดังนั้น เราสามารถเลือก neuron ใด neuron หนึ่งจาก fc1 แล้ว reshape weight vector ของมันให้เป็นขนาด 28x28 เพื่อ plot เป็นภาพ

# %%
# Extract the weights of the first layer (fc1)
fc1_weights = augmented_model.fc1.weight.data

# Select the weights of the first neuron (or any neuron you want to visualize)
neuron_idx = 1  # Index of the neuron to visualize
weight_vector = fc1_weights[neuron_idx]

# Reshape the weight vector to 28x28
weight_image = weight_vector.view(28, 28).cpu().numpy()

# Plot the image
plt.imshow(weight_image, cmap='gray')
plt.title(f'Weights of neuron {neuron_idx} in fc1')
plt.colorbar()
plt.show()

# %%
# Extract the weights of the first layer (fc1)
fc1_weights = augmented_model.fc1.weight.data

# Number of neurons in fc1
num_neurons = fc1_weights.shape[0]

# Prepare a grid to store all images
grid_height = 10
grid_width = 16
image_height = 28
image_width = 28

# Create an empty array to hold the grid image
grid_image = np.zeros((grid_height * image_height, grid_width * image_width))

# Fill the grid with the weight images
for i in range(num_neurons):
    weight_vector = fc1_weights[i]
    weight_image = weight_vector.view(image_height, image_width).cpu().numpy()

    row = i // grid_width
    col = i % grid_width

    grid_image[row * image_height: (row + 1) * image_height,
               col * image_width: (col + 1) * image_width] = weight_image

# Plot the grid image
plt.figure(figsize=(12, 12))
plt.imshow(grid_image, cmap='gray')
plt.title('Weights of all neurons in fc1')
plt.colorbar()
plt.show()

# %% [markdown]
# รูปด้านบนอาจจะดูไม่ค่อยรู้เรื่อง เพราะข้อมูลเป็นตัวเลข และ การทำงานไม่ใช่ Convolution แต่ในบางงานที่เป็นรูปภาพ รูปของ feature map สามารถบอกสิ่งที่เกิดขึ้นในการทำงานของ Neural Network ได้
#
# <img src="https://miro.medium.com/v2/resize:fit:4800/format:webp/1*LlRAQHT0ktl_33VUnDhoIg.png">
#
# <img src="https://miro.medium.com/v2/resize:fit:4426/format:webp/1*_uk1cKXslKo1gDHOWzljXA.png">

# %% [markdown]
# # Save Model
#
# เอาละ! มาถึงตรงนี้ เราก็มี model ไว้สำหรับใช้งานแล้ว เนื่องจากการ train model ค่อนข้างจะเสียเวลามาก ดังนั้นหากต้องทำทุกครั้งน่าจะไม่ดี จึงควรจะ save model เอาไว้เพื่อนำมาใช้งานภายหลัง
#
# ในการ save model ก็คือ การ save state_dict นั่นเอง

# %%
augmented_model.state_dict()
# Out:
# OrderedDict([('fc1.weight',
#               tensor([[ 0.0101, -0.0192,  0.0055,  ..., -0.0463,  0.0060, -0.0311],
#                       [-0.0429, -0.0105,  0.0047,  ..., -0.0167,  0.0408, -0.0201],
#                       [-0.0140, -0.0156,  0.0007,  ..., -0.0044, -0.0231, -0.0069],
#                       ...,
#                       [ 0.0146,  0.0257,  0.0102,  ...,  0.0028, -0.0214, -0.0093],
#                       [ 0.0215,  0.0255, -0.0101,  ..., -0.0043, -0.0223, -0.0129],
#                       [-0.0042, -0.0258,  0.0330,  ...,  0.0196, -0.0375, -0.0510]])),
#              ('fc1.bias',
#               tensor([-0.1446, -0.0504, -0.1189,  0.1352, -0.2129, -0.1303,  0.0079,  0.0094,
#                       -0.4202, -0.1573,  0.0106,  0.0024,  0.0332,  0.2297, -0.0746, -0.0148,
#                       -0.0417,  0.0567,  0.1735, -0.0691,  0.0156,  0.1872, -0.0730,  0.0606,
#                        0.0151,  0.1309,  0.0180, -0.0752, -0.0764,  0.0158,  0.0405, -0.0549,
#                       -0.0337, -0.1494, -0.2622,  0.1969, -0.0573, -0.0266,  0.0285, -0.3668,
#                        0.0906, -0.0216,  0.0417,  0.0485,  0.1011,  0.0915, -0.1197, -0.3673,
#                        0.1450, -0.1549, -0.0202, -0.0439, -0.0447, -0.0888,  0.0225, -0.1075,
#                        0.0521, -0.0941, -0.1897,  0.0626, -0.0198,  0.0331,  0.0629,  0.0835,
#                       -0.0389, -0.1738, -0.1001,  0.0991, -0.0081,  0.1562, -0.0371, -0.0340,
#                        0.0188, -0.0880, -0.2111, -0.0472, -0.0813,  0.1025, -0.1925, -0.0181,
#                       -0.0472,  0.0704, -0.1676, -0.2334,  0.0791,  0.0241, -0.2785,  0.0487,
#                        0.1495,  0.0463, -0.1032, -0.0657,  0.0271,  0.1252,  0.0135,  0.1391,
#                        0.0446, -0.2008, -0.0743,  0.0082, -0.1693,  0.0345, -0.0678, -0.0232,
#                        0.0596, -0.1068, -0.1615,  0.0405,  0.0049, -0.0065, -0.2512, -0.0186,
#                        0.0305,  0.2021,  0.0189, -0.2595,  0.1129, -0.1735, -0.0705, -0.0974,
#                       -0.0712, -0.0482,  0.0162, -0.2260,  0.0534,  0.0139, -0.0028, -0.1997,
#                       -0.0478,  0.0548, -0.0068,  0.0604, -0.0505, -0.0543,  0.0375, -0.0204,
#                        0.0130,  0.1930, -0.2435,  0.0278,  0.1618, -0.0098,  0.0448,  0.0179,
#                       -0.0011,  0.0137, -0.1206, -0.0473, -0.1805,  0.0690, -0.1365,  0.0334,
#                        0.0221, -0.1431,  0.0252, -0.1867, -0.1238,  0.0210,  0.0025, -0.1952])),
#              ('fc2.weight',
#               tensor([[-0.0550, -0.0655, -0.0530,  ...,  0.0218,  0.0781,  0.0535],
#                       [-0.0990, -0.0141,  0.0165,  ...,  0.1443, -0.0761,  0.0395],
#                       [-0.0353, -0.0538,  0.0742,  ..., -0.0108, -0.0186,  0.0695],
#                       ...,
#                       [ 0.0801,  0.0977, -0.0185,  ..., -0.1273, -0.0857, -0.0454],
#                       [-0.0299, -0.0479, -0.0675,  ...,  0.0655, -0.0381,  0.0699],
#                       [ 0.0741,  0.0241, -0.0562,  ..., -0.0891, -0.1050, -0.0132]])),
#              ('fc2.bias',
#               tensor([-0.0490,  0.2552, -0.0012,  0.2033, -0.1119, -0.1895,  0.0852,  0.0749,
#                       -0.0304, -0.1255, -0.1499,  0.1228,  0.1219,  0.4119,  0.0150,  0.0042,
#                        0.0629, -0.1162, -0.0183,  0.1145, -0.0585,  0.0875,  0.1166, -0.0058,
#                        0.0555,  0.3293,  0.0109,  0.0539,  0.0572,  0.1250,  0.0363, -0.0948,
#                       -0.0545, -0.0218,  0.2021,  0.2768,  0.0031,  0.0495, -0.0350, -0.0145,
#                       -0.0050,  0.1487,  0.1357, -0.1497,  0.1403,  0.0640, -0.1994, -0.1432,
#                        0.0906, -0.1064, -0.0693, -0.1139,  0.0934,  0.0576, -0.0409, -0.0484,
#                       -0.1140,  0.3431,  0.0361,  0.0766,  0.0120, -0.0319, -0.0228, -0.1584,
#                        0.0934, -0.2173, -0.0180, -0.0602,  0.0607, -0.0812,  0.0550, -0.0383,
#                        0.1099, -0.0540,  0.1523, -0.1304, -0.1013, -0.0829, -0.0133, -0.0157])),
#              ('fc3.weight',
#               tensor([[ 1.9155e-01,  4.6075e-01,  4.0962e-02,  4.2216e-01, -8.7550e-02,
#                        -4.7667e-01,  1.1497e-01,  7.7606e-02, -2.1504e-01, -1.7311e-01,
#                        -4.9773e-01,  1.9978e-01,  2.2469e-02,  5.2654e-01,  5.0547e-02,
#                        -2.8972e-02, -1.3590e-01, -2.4722e-01, -2.1620e-02,  8.3131e-02,
#                        -1.7729e-01,  3.5566e-01,  8.0183e-02, -8.8180e-02,  1.4292e-01,
#                         2.6302e-01,  5.8783e-02,  2.4163e-01,  1.4748e-01,  5.0586e-01,
#                        -6.7968e-02, -1.8132e-01, -3.0468e-01, -1.1764e-01,  4.1332e-01,
#                         1.3527e-01,  1.4449e-01,  1.2868e-01, -4.7391e-02,  6.5051e-03,
#                         1.7285e-01,  3.5452e-01,  2.0515e-01, -3.8856e-01,  9.2168e-02,
#                        -2.5613e-01, -4.9192e-01, -3.6431e-01,  3.0967e-01, -2.7672e-01,
#                         3.5486e-02, -2.1477e-01, -1.4244e-01, -5.5051e-02, -8.8016e-02,
#                        -2.9190e-02, -3.0171e-01,  5.7841e-01, -1.1179e-01, -9.3544e-02,
#                        -8.5266e-02, -4.8614e-01, -1.1858e-01, -4.8765e-01, -2.2787e-01,
#                        -3.8420e-01, -1.9662e-01, -8.7090e-02,  1.3197e-01, -3.5930e-01,
#                         1.7364e-01, -5.2001e-01, -5.8004e-02, -3.0187e-01,  5.4659e-02,
#                        -2.5264e-01,  7.8582e-03,  9.5230e-02,  3.5348e-02, -2.7180e-02],
#                       [ 6.0461e-02,  4.1060e-01, -5.5385e-03, -2.4992e-01, -2.3661e-01,
#                        -1.5537e-01,  1.4547e-01, -6.7859e-02, -1.2399e-01,  1.9387e-01,
#                        -2.8268e-01,  2.8408e-01, -3.5740e-02,  4.0850e-01,  3.3196e-01,
#                        -1.2289e-01, -3.9530e-01, -3.0673e-01, -6.3009e-02, -1.3744e-01,
#                        -1.1011e-01,  1.0146e-01, -5.1166e-02,  9.0580e-02,  5.5122e-02,
#                        -8.7459e-02,  3.5324e-02, -3.2992e-03,  7.3857e-02,  4.7673e-03,
#                         2.5184e-03,  8.5731e-02, -3.9108e-02,  2.5302e-01,  2.7484e-01,
#                         2.6959e-01, -4.8411e-02,  1.5603e-01,  2.2222e-02, -1.4725e-01,
#                        -5.0902e-02,  2.0969e-01,  2.9786e-01, -3.2024e-01, -3.5379e-02,
#                         8.0671e-02,  2.5263e-01,  1.4567e-01, -4.3067e-01,  3.6819e-01,
#                        -8.1689e-03,  1.1431e-01, -2.5364e-01, -7.0940e-02,  8.9193e-02,
#                         1.9201e-01,  2.5412e-01,  4.1692e-01,  2.8360e-01, -4.2638e-01,
#                        -8.3093e-02,  1.8861e-01, -2.6252e-02, -3.1179e-01, -7.0671e-02,
#                        -1.8436e-01, -2.9994e-01, -4.6978e-03, -3.5062e-01, -1.2273e-01,
#                         1.7418e-01,  3.0869e-01,  7.2137e-02, -1.8931e-01, -6.1657e-02,
#                        -1.8955e-01, -1.1611e-01,  1.7108e-01,  4.3726e-02, -3.8415e-01],
#                       [ 1.7169e-01,  7.4210e-02, -7.5062e-02, -3.6987e-01,  2.3392e-01,
#                         2.0255e-01,  3.1254e-01,  5.0221e-01,  2.6457e-01,  2.9863e-01,
#                        -1.7245e-01, -2.9038e-02,  6.3943e-02,  7.2932e-02, -2.1769e-01,
#                        -6.0548e-02, -3.5564e-01, -4.3078e-01,  3.4298e-02, -2.8168e-02,
#                         1.7123e-01, -2.1376e-01, -1.7585e-01, -4.3184e-02, -2.0835e-01,
#                        -3.6323e-01, -5.7140e-02, -2.8445e-01,  1.1878e-01, -3.5702e-01,
#                         2.4270e-01, -1.0202e-01,  2.8133e-01, -1.3175e-01, -3.3577e-02,
#                        -3.0357e-01,  7.7871e-02,  6.3055e-02, -4.0127e-01,  1.1543e-01,
#                        -3.8144e-02,  2.5954e-01,  4.2002e-01, -3.8279e-01,  1.0669e-01,
#                        -3.2706e-01,  2.7551e-01,  3.7703e-01, -1.9115e-01,  2.1450e-01,
#                         6.1916e-02,  1.6458e-01, -3.9317e-01,  1.0682e-01,  3.2400e-03,
#                         3.0822e-01,  2.2067e-01, -2.3485e-01, -3.1697e-01, -5.0364e-01,
#                        -2.5408e-01,  3.5519e-01, -2.4515e-01, -1.7024e-01, -3.3948e-01,
#                        -2.6017e-01,  1.1831e-01, -1.9919e-02,  2.2156e-01, -1.7323e-01,
#                        -5.8190e-03,  2.9309e-01,  1.9341e-03,  5.0559e-01,  1.9501e-01,
#                         6.4885e-02,  2.9888e-01, -3.4220e-02, -5.1258e-02, -1.0128e-01],
#                       [ 4.0032e-02, -3.1243e-01,  7.2746e-02,  1.1436e-01, -2.9545e-01,
#                        -4.1828e-01,  3.8473e-01,  4.4347e-01, -4.1285e-01,  3.1951e-02,
#                        -1.2486e-01, -1.7588e-01,  2.3116e-01,  1.3084e-01, -3.9290e-01,
#                         3.8832e-02, -2.9909e-01, -3.9558e-01,  8.0268e-02, -2.6767e-01,
#                         1.7341e-01,  1.8922e-01, -1.6868e-01,  1.1059e-01, -1.9067e-02,
#                         3.7236e-01,  7.3217e-02, -3.6327e-01,  3.4697e-01, -3.0625e-01,
#                         1.7330e-01, -4.9585e-02, -2.1580e-01, -3.3465e-01, -3.5077e-01,
#                        -1.3207e-01,  1.3745e-01, -2.8989e-01, -2.8949e-01, -1.0350e-01,
#                         1.5165e-01, -3.2559e-02, -1.3480e-01, -4.5567e-01, -9.0332e-02,
#                        -6.2397e-02,  2.2233e-01,  4.3252e-01, -1.8060e-01, -3.2216e-01,
#                         3.9159e-02,  1.2096e-01,  2.8066e-01, -8.5354e-02, -4.9482e-02,
#                         7.6290e-02, -1.9008e-01, -3.2803e-01,  1.3440e-01,  5.2466e-01,
#                        -2.0621e-01,  2.5336e-01, -2.9092e-01, -8.9852e-02,  4.5433e-01,
#                        -3.4816e-01,  2.6174e-01, -1.6966e-03,  2.8729e-01, -4.0564e-02,
#                        -1.3271e-01,  3.2519e-01, -8.6740e-02,  1.6851e-01,  4.6617e-01,
#                         8.8770e-02, -8.4023e-02, -1.2256e-01, -2.0063e-02, -4.4134e-01],
#                       [-2.8654e-01, -2.8039e-01,  1.6326e-02, -4.8501e-02,  1.5803e-01,
#                         2.5980e-01,  4.0523e-03, -6.0617e-01, -4.2043e-02,  9.1156e-02,
#                         3.0012e-01,  1.2995e-01,  2.6054e-01, -1.7234e-01,  2.0249e-01,
#                         1.0531e-01,  2.5262e-01,  4.9945e-01, -8.3331e-03, -9.5739e-03,
#                         1.5168e-01,  1.1265e-01,  6.9369e-02, -4.7166e-02, -2.2649e-01,
#                        -2.1382e-01, -1.6078e-01,  3.3876e-01, -2.7357e-01,  4.6429e-02,
#                         3.0328e-02, -1.4806e-01, -1.1915e-02,  1.9505e-01,  1.8718e-01,
#                         1.4793e-01,  3.7624e-02,  2.1739e-02,  1.6402e-01,  8.2971e-02,
#                        -2.8323e-02, -2.7590e-01, -4.4692e-01,  4.6050e-01,  1.5240e-01,
#                        -1.3358e-01,  1.4780e-01,  8.6747e-02, -1.8390e-01,  9.8713e-02,
#                        -2.3663e-02, -8.6823e-02,  1.0039e-01, -6.2353e-02, -4.0532e-02,
#                         1.3580e-01,  2.2649e-02, -7.9253e-02,  9.1994e-02, -1.6380e-01,
#                        -5.9083e-02,  2.5795e-01,  1.5852e-01,  3.2199e-01,  1.1684e-03,
#                         5.6296e-01,  2.2887e-01,  3.4860e-02, -4.1093e-01,  1.7124e-01,
#                        -2.6453e-01,  8.8011e-02,  2.3623e-01,  1.0423e-01, -6.3354e-01,
#                         2.7682e-01,  2.6079e-01,  3.5028e-01, -9.3119e-02,  3.3076e-01],
#                       [ 2.0801e-01, -1.2431e-01, -7.2070e-03, -1.5904e-01, -1.7502e-01,
#                         3.1648e-01, -3.5906e-01, -3.5759e-01, -1.9842e-01, -3.8436e-02,
#                         2.8939e-01,  1.0847e-01, -2.0504e-01, -5.3816e-01,  3.4545e-01,
#                         9.4512e-02, -6.7436e-02,  4.7829e-01,  1.3852e-01, -3.7211e-01,
#                         3.1018e-01, -8.7711e-02,  1.5128e-01,  1.7224e-02,  2.1034e-01,
#                        -4.4517e-01, -1.4304e-01,  2.2211e-01, -3.5266e-01, -4.6896e-02,
#                        -1.0823e-01,  2.8853e-01, -9.3225e-02,  2.8227e-01, -1.7131e-01,
#                        -3.9759e-01, -6.3398e-02, -6.8507e-02,  4.1359e-01, -2.9875e-02,
#                         1.0971e-01,  1.3307e-01, -3.1168e-01,  5.2296e-01, -4.3624e-01,
#                         1.0533e-01,  4.3198e-01, -3.0412e-01,  2.1913e-01,  2.4418e-01,
#                        -8.6785e-02,  3.0245e-01, -1.1034e-01,  4.9711e-02, -5.1146e-02,
#                         2.4550e-01,  1.9013e-01,  6.8750e-03,  2.2995e-01, -1.5381e-02,
#                         3.0215e-01, -8.7399e-02,  3.5681e-01,  4.6276e-01, -1.3026e-01,
#                         5.4422e-01, -1.8722e-01, -4.0773e-02, -3.5427e-01,  4.0328e-01,
#                         4.9645e-02, -1.5001e-01, -4.4043e-01, -4.3920e-01, -2.4842e-01,
#                         5.2993e-02, -1.3737e-01,  4.8226e-01,  1.0766e-01,  4.6193e-01],
#                       [-3.1253e-01,  4.4691e-01,  1.5740e-01, -7.2538e-02,  6.5602e-02,
#                         4.3753e-02, -9.4007e-02,  2.3172e-01,  7.2063e-01,  2.5927e-01,
#                        -5.5579e-01, -1.2067e-02,  1.5526e-01,  3.2448e-01, -3.1459e-02,
#                         1.5848e-01, -4.4168e-02, -4.6584e-01,  4.3441e-02,  3.8696e-01,
#                        -4.2366e-01, -3.0071e-01, -1.5870e-01,  4.0826e-02, -6.1002e-01,
#                        -1.9961e-01,  2.2289e-02,  5.5012e-02, -5.9772e-01, -1.4854e-01,
#                        -1.0549e-01,  1.9012e-01,  7.8715e-02, -4.5944e-01,  4.1105e-01,
#                         4.2651e-01, -1.9211e-01,  2.0237e-01, -2.4965e-01, -6.4976e-02,
#                        -4.9970e-01,  4.1965e-01,  4.5721e-01, -1.4691e-01,  4.6409e-01,
#                        -3.5311e-01, -6.2861e-02, -2.7726e-01, -2.5174e-01,  4.9239e-01,
#                         4.1695e-02, -1.1314e-01, -8.6333e-04, -9.6532e-02,  7.1238e-02,
#                        -3.0937e-01, -2.2782e-01,  4.3167e-01, -4.5185e-01, -3.0770e-01,
#                         7.4515e-02,  2.9836e-01,  4.5849e-02, -2.4680e-01,  2.1781e-02,
#                        -2.8601e-01, -4.7682e-01, -7.3710e-02, -2.9061e-01,  1.5269e-01,
#                        -1.2858e-01,  2.3629e-01,  1.1850e-01,  2.3566e-01, -3.9083e-01,
#                        -5.1189e-01, -1.4704e-01, -4.5166e-03,  2.4928e-03,  2.1321e-01],
#                       [ 1.6275e-01, -4.6818e-01, -1.0445e-01,  1.0349e-02,  2.0131e-01,
#                         3.7520e-01,  1.0058e-01,  3.1566e-01, -1.1421e-01,  7.4913e-02,
#                         3.1239e-01, -4.0033e-01, -3.1886e-03, -3.2749e-01, -3.8601e-01,
#                        -1.5884e-01,  5.3774e-01,  1.0959e-01, -2.4124e-02,  3.5986e-01,
#                        -2.2722e-01, -2.4423e-02,  5.1367e-02, -8.8293e-02,  1.7514e-01,
#                         1.7783e-01,  2.8120e-02,  7.1479e-02,  3.3881e-01,  1.3646e-01,
#                        -1.5163e-01, -1.2695e-02, -1.1809e-01,  7.1785e-02, -2.8736e-01,
#                        -2.8942e-01, -8.9222e-02, -1.4765e-02,  1.4408e-01, -4.6142e-02,
#                         7.9055e-02, -4.3141e-01, -2.4822e-01, -1.5316e-01, -2.3481e-01,
#                         3.5216e-01, -3.5648e-01,  2.2981e-01,  3.2564e-01,  4.2031e-03,
#                         1.7923e-02,  1.3274e-01,  1.8136e-01, -7.7657e-02,  8.1634e-02,
#                        -2.6811e-01,  1.9508e-01, -6.6941e-01, -9.4051e-02,  5.3781e-01,
#                        -1.8705e-01, -1.1277e-02, -2.0360e-01,  2.3028e-01,  3.7644e-01,
#                        -2.1758e-01,  3.5537e-01,  3.6976e-02,  3.1091e-01, -2.4390e-01,
#                        -1.8177e-01,  4.4562e-02,  1.3632e-01,  1.0822e-01,  2.4668e-01,
#                         1.1464e-01, -3.5757e-02, -4.8991e-01,  2.2082e-02, -1.8857e-01],
#                       [-1.1912e-01, -1.2896e-01,  6.2453e-02,  3.6998e-02,  3.0249e-01,
#                         2.4398e-01,  8.9822e-02, -1.5765e-01,  1.8398e-02,  9.6736e-02,
#                         1.5726e-01,  7.1068e-02,  7.7730e-02,  1.0176e-01,  1.8187e-01,
#                         1.4240e-01,  3.6149e-01,  3.3731e-01,  8.6462e-02,  3.3064e-01,
#                         6.1723e-02, -1.5022e-01,  2.9119e-01, -8.9121e-02,  5.8661e-02,
#                         6.0003e-03, -4.4443e-02,  1.7184e-01,  1.6364e-03,  3.1208e-01,
#                         9.1387e-02,  8.0758e-02,  1.7807e-02,  2.2661e-01, -6.5511e-02,
#                        -3.7236e-02, -4.2207e-02,  8.0650e-02,  3.0949e-01, -4.9070e-02,
#                        -6.2742e-02, -3.5497e-01, -3.8330e-04,  6.7875e-02,  1.5904e-01,
#                         1.4100e-01, -2.1749e-01,  3.7773e-02,  2.3331e-01, -2.2377e-01,
#                        -1.0557e-02,  1.7399e-03, -4.8057e-02, -4.9724e-02,  9.4329e-02,
#                         4.7285e-03, -6.7673e-02,  5.9874e-02, -3.7344e-02,  1.7097e-02,
#                         1.5674e-01, -3.4168e-01,  1.8167e-01,  3.0380e-01,  1.4490e-02,
#                         8.5532e-02, -4.8700e-02, -8.5361e-02, -2.1063e-02,  2.4171e-01,
#                         1.0277e-01, -5.3528e-02, -1.1742e-01,  1.5675e-01, -1.2609e-01,
#                         1.9874e-01,  1.1013e-02,  2.2068e-01,  1.2187e-01,  2.6629e-01],
#                       [ 8.6630e-02, -2.4384e-01,  6.8864e-02,  2.5355e-01, -1.6461e-01,
#                        -2.9389e-01, -3.7656e-01, -5.3189e-01, -6.6034e-02, -4.7986e-01,
#                         4.9311e-01,  7.7113e-02, -3.5937e-01, -3.8261e-01,  1.1006e-01,
#                         5.5105e-02,  4.5550e-02,  3.3410e-01, -1.0926e-01, -3.2184e-01,
#                        -4.7620e-02, -6.5967e-02, -4.3809e-01, -3.0251e-02,  3.0043e-01,
#                         3.8854e-01,  1.9558e-02, -4.9747e-02,  1.2463e-01, -4.5634e-02,
#                         8.8460e-03,  2.1586e-02, -8.9522e-02,  9.7569e-02, -2.1401e-01,
#                        -1.3645e-01, -8.4663e-02, -1.8065e-01, -2.7950e-01,  5.2596e-02,
#                         1.6837e-01, -2.1215e-01, -3.6982e-01,  4.7714e-01, -3.9039e-01,
#                         3.5553e-01, -1.1792e-01, -8.1752e-02,  1.7286e-01, -7.9049e-03,
#                        -4.6122e-02, -3.1443e-02,  3.4488e-01, -8.8319e-02,  5.7854e-02,
#                        -2.0738e-01, -4.1581e-02, -2.8902e-01,  2.5148e-01,  5.2623e-01,
#                         2.1725e-01, -4.2086e-01,  2.5433e-01,  2.0208e-01,  3.6795e-01,
#                         2.8821e-01,  1.5054e-01,  1.0305e-01,  4.0982e-01, -5.0376e-02,
#                         3.0641e-01, -2.9139e-01,  2.0364e-01, -4.6952e-01,  3.1244e-01,
#                         1.5684e-01, -4.8496e-02, -2.8832e-01, -5.4719e-02, -5.2169e-02]])),
#              ('fc3.bias',
#               tensor([ 0.6423,  0.3037, -0.4696,  0.1317, -0.1130, -0.6231,  0.0290, -0.0828,
#                        0.1070, -0.0500]))])

# %%
augmented_model.state_dict()["fc1.weight"].shape, augmented_model.state_dict()["fc1.bias"].shape
# Out:
# (torch.Size([160, 784]), torch.Size([160]))

# %%
save_path = "thai_digit.pth"
torch.save(augmented_model.state_dict(), save_path)

# %% [markdown]
# จากนั้นก็ต้อง download มาเก็บไว้ มิฉะนั้น google colab จะลบข้อมูลออกหมด

# %% [markdown]
# # Load Model
#
# เมื่อต้องการนำ Model ที่ save เก็บไว้มาใช้อีกครั้ง ให้ทำขั้นตอนเหมือนกับที่ผ่านมา ยกเว้นไม่ต้อง train แต่โหลดข้อมูลจากไฟล์เข้าสู่ model ได้เลย

# %%
model = DropoutThaiNumberNN3()
model.load_state_dict(torch.load("thai_digit.pth"))
# Out:
# <All keys matched successfully>

# %% [markdown]
# # สรุป
#
# ในบทเรียนนี้เราได้เรียนการนำ Pytorch มาใช้งาน โดยเน้นที่ Classification และกล่าวถึงการทำงานของ Logistic Regression, Softmax และ Cross Entropy Loss ซึ่งใช้ในกระบวนการ Classification นอกจากนั้นยังได้กล่างถึงเรื่องของ Optimization การเกิด Overfitting และแนวทางการแก้ไข ตลอดจนการประเมินผลโมเดล การ save และ load โมเดล ซึ่งเป็นพื้นฐานของ deep learning ต่อไป

# %% [markdown]
# # Optional
#
# หากนักเรียนคนใดต้องการ Dataset สำหรับทดลองสร้าง model เพิ่มเติม จะมี Dataset ต่อไปนี้

# %% [markdown]
# ## Fasion MNIST dataset
#
# ชุดข้อมูล Fashion-MNIST คือชุดรูปภาพสินค้าแฟชั่น จากเว็บไซต์ Zalando ประกอบด้วยรูปภาพสำหรับฝึกฝนโมเดล 60,000 รูป และรูปภาพสำหรับทดสอบอีก 10,000 รูป รูปภาพแต่ละรูปมีขนาด 28x28 พิกเซล เป็นภาพขาวดำ และมีการติดป้ายกำกับประเภทของเสื้อผ้า 1 ใน 10 ประเภท
#
# รูปภาพแต่ละรูปมีความสูง 28 พิกเซล กว้าง 28 พิกเซล ดังนั้นจะมีพิกเซลทั้งหมด 784 พิกเซล แต่ละพิกเซลจะมีค่าตั้งแต่ 0 ถึง 255 โดยค่าที่สูงกว่าหมายถึงความมืดมากกว่า ค่าเหล่านี้แทนระดับความสว่างของจุดนั้น ๆ ชุดข้อมูลสำหรับฝึกฝนและทดสอบจะมี 785 คอลัมน์ คอลัมน์แรกจะเป็นหมายเลขประเภทของเสื้อผ้า (ตามที่ระบุไว้ด้านบน) คอลัมน์ที่เหลือจะเป็นค่าของแต่ละพิกเซลในภาพนั้น
#
# ข้อมูลแต่ละตัวอย่างสำหรับฝึกฝนและทดสอบจะมีการกำหนดประเภทไว้ดังนี้:
#
# 0 T-shirt/top 1 Trouser 2 Pullover 3 Dress 4 Coat 5 Sandal 6 Shirt 7 Sneaker 8 Bag 9 Ankle boot

# %% [markdown]
# ### Import และ โหลดข้อมูล

# %%
import torch
import torch.nn as nn
import torch.optim as optim
from torchvision import datasets, transforms
from torch.utils.data import DataLoader
import matplotlib.pyplot as plt

# Data loading and preprocessing
transform = transforms.Compose([transforms.ToTensor(), transforms.Normalize((0.5,), (0.5,))])

train_set = datasets.FashionMNIST(root='./data', train=True, download=True, transform=transform)
test_set = datasets.FashionMNIST(root='./data', train=False, download=True, transform=transform)

train_loader = DataLoader(train_set, batch_size=64, shuffle=True)
test_loader = DataLoader(test_set, batch_size=64, shuffle=False)

# %%
import matplotlib.pyplot as plt
images, labels = next(iter(train_loader))
image = images[10]
label = labels[10]
image = image.permute(1, 2, 0)
image = image * 0.5 + 0.5
plt.imshow(image)
plt.title(f'Label: {label}')
plt.show()

# %% [markdown]
# ## Horses or Humans Dataset
#
# ชุดข้อมูลนี้ประกอบด้วยภาพเรนเดอร์ 500 ภาพของม้าหลายสายพันธุ์ในท่าทางต่างๆ และสถานที่ต่างๆ นอกจากนี้ยังมีภาพเรนเดอร์ของมนุษย์ 527 ภาพในท่าทางและพื้นหลังที่แตกต่างกัน มีความหลากหลายของมนุษย์ ดังนั้นจึงมีทั้งผู้ชายและผู้หญิง รวมถึงชาวเอเชีย แอฟริกันใต้ เอเชียใต้ และผิวขาวอยู่ในชุดข้อมูลฝึกอบรม ชุดข้อมูลการตรวจสอบเพิ่มตัวเลขอีกหกตัวเพื่อให้แน่ใจว่าข้อมูลมีความกว้าง

# %%
# Step 1: Install and import necessary libraries
import os
import zipfile
import torch
from torchvision import datasets, transforms
from torch.utils.data import DataLoader

# Step 2: Download the dataset
# !wget --no-check-certificate \
    https://storage.googleapis.com/learning-datasets/horse-or-human.zip \
    -O /tmp/horse-or-human.zip

# !wget --no-check-certificate \
    https://storage.googleapis.com/learning-datasets/validation-horse-or-human.zip \
    -O /tmp/validation-horse-or-human.zip

# Step 3: Extract the datasets
local_zip = '/tmp/horse-or-human.zip'
zip_ref = zipfile.ZipFile(local_zip, 'r')
zip_ref.extractall('/tmp/horse-or-human')
zip_ref.close()

local_zip = '/tmp/validation-horse-or-human.zip'
zip_ref = zipfile.ZipFile(local_zip, 'r')
zip_ref.extractall('/tmp/validation-horse-or-human')
zip_ref.close()

# Step 4: Prepare the data
data_dir_train = '/tmp/horse-or-human'
data_dir_val = '/tmp/validation-horse-or-human'

# Define transforms for training and validation data
train_transforms = transforms.Compose([
    transforms.Resize((300, 300)),
    transforms.ToTensor(),
    transforms.Normalize([0.5, 0.5, 0.5], [0.5, 0.5, 0.5])
])

val_transforms = transforms.Compose([
    transforms.Resize((300, 300)),
    transforms.ToTensor(),
    transforms.Normalize([0.5, 0.5, 0.5], [0.5, 0.5, 0.5])
])

# Load the datasets with ImageFolder
train_data = datasets.ImageFolder(data_dir_train, transform=train_transforms)
val_data = datasets.ImageFolder(data_dir_val, transform=val_transforms)

# Define the dataloaders
train_loader = DataLoader(train_data, batch_size=20, shuffle=True)
val_loader = DataLoader(val_data, batch_size=20, shuffle=False)

# Print the class names and number of samples
print(f'Train dataset classes: {train_data.classes}')
print(f'Number of training samples: {len(train_data)}')
print(f'Number of validation samples: {len(val_data)}')
# Out:
# --2024-07-13 07:39:32--  https://storage.googleapis.com/learning-datasets/horse-or-human.zip
# Resolving storage.googleapis.com (storage.googleapis.com)... 173.194.193.207, 142.250.152.207, 173.194.194.207, ...
# Connecting to storage.googleapis.com (storage.googleapis.com)|173.194.193.207|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 149574867 (143M) [application/zip]
# Saving to: ‘/tmp/horse-or-human.zip’
#
# /tmp/horse-or-human 100%[===================>] 142.65M   135MB/s    in 1.1s
#
# 2024-07-13 07:39:33 (135 MB/s) - ‘/tmp/horse-or-human.zip’ saved [149574867/149574867]
#
# --2024-07-13 07:39:33--  https://storage.googleapis.com/learning-datasets/validation-horse-or-human.zip
# Resolving storage.googleapis.com (storage.googleapis.com)... 173.194.193.207, 142.250.152.207, 173.194.194.207, ...
# Connecting to storage.googleapis.com (storage.googleapis.com)|173.194.193.207|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 11480187 (11M) [application/zip]
# Saving to: ‘/tmp/validation-horse-or-human.zip’
#
# /tmp/validation-hor 100%[===================>]  10.95M  39.6MB/s    in 0.3s
#
# 2024-07-13 07:39:34 (39.6 MB/s) - ‘/tmp/validation-horse-or-human.zip’ saved [11480187/11480187]
#
# Train dataset classes: ['horses', 'humans']
# Number of training samples: 1027
# Number of validation samples: 256

# %%
import matplotlib.pyplot as plt
image, label = train_data[10]
image = image.permute(1, 2, 0)
image = image * 0.5 + 0.5
plt.imshow(image)
plt.title(f'Label: {train_data.classes[label]}')
plt.show()

# %% [markdown]
# # Exercise 1
#
# จากชุดข้อมูลลายมือเขียนภาษาไทย 0-9 ให้ปรับแต่ง Model โดยใช้เทคนิคต่างๆ (เฉพาะที่เรียนมา) เช่น ขนาด pixel, batch size, ชั้นและจำนวนของ Neuron, Optimization Algorithm, Loss Function, Activation Function, Learning Rate, Data Augmentaion, Dropout, Regularization, Cross Validation
#
# โดยมีเป้าหมายให้ Training Accuracy และ Validation Accuracy มากที่สุด โดยมี Overfit น้อยที่สุด
#
# ให้ capture กราฟและผลการทำงาน (epoch print) พร้อมทั้งอธิบายการปรับ Hyperparameter ที่เลือกใช้พร้อมเหตุผล ส่งเป็นไฟล์ PDF

# %% [markdown]
# ## Exercise 2
#
# ให้ใช้ link ต่อไปนี้ เพื่อทำชิ้นงาน
#
# https://github.com/NextGen-AI-Camp/curriculum/tree/main/Week%234/NN%233/NextGen_AI_Camp_Neural_Network3_Exercise2.ipynb
#
# ใน Notebook จะสร้างข้อมูลในรูปแบบ Spiral โดยข้อมูลจะมีจำนวน 300 ตำแหน่ง แบ่งออกเป็น 3 Class ข้อมูลจะอยู่ใน X และ Label จะอยู่ใน y จากนั้นจะนำไปสร้างเป็น Dataset และแบ่งเป็น train_dataset, val_dataset และ นำไปสร้างเป็น DataLoader อีกต่อหนึ่งเป็น train_loader และ val_loader
#
# ใน Notebook จะมี function plot_decision_boundary ซึ่งต้องการ Parameter 3 ตัว คือ model, X และ y เพื่อแสดงขอบเขตของแต่ละคลาส
# ให้ทำตาม TODO ให้ครบ
# ให้ส่งเป็นไฟล์ .ipynb โดยตั้งชื่อไฟล์ขึ้นต้นเป็นเลขของค่าย 3 หลัก ภายในไฟล์ให้ใส่ E-Mail ด้วย เผื่อมีความผิดพลาด
